# %%
import scanpy as sc
import pandas as pd
import numpy as np
import anndata
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib as mpl
# enables correct plotting of text
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.9.2
# matplotlib          3.7.2
# numpy               1.24.4
# pandas              1.5.3
# scanpy              1.9.3
# scipy               1.10.1
# seaborn             0.12.2
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.0.0
# anyio                       NA
# arrow                       1.2.3
# asttokens                   NA
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.12.1
# backcall                    0.2.0
# brotli                      1.0.9
# certifi                     2023.11.17
# cffi                        1.15.1
# charset_normalizer          3.2.0
# colorama                    0.4.6
# comm                        0.1.4
# cycler                      0.10.0
# cython_runtime              NA
# ...

# %%
sc.settings.set_figure_params(dpi=120)

# %%
import importlib.util
import sys
spec = importlib.util.spec_from_file_location("module.name", "/nfs/team205/kk18/function/python/utils.py")
utils = importlib.util.module_from_spec(spec)
sys.modules["module.name"] = utils
spec.loader.exec_module(utils)

# %%
sc.settings.set_figure_params(dpi=80,dpi_save=300)

# %% [markdown]
# # Variables

# %%
figdir = '/nfs/team205/heart/fetal_ms_figures/raw_plots_kk'
adata_path_dir = '/nfs/team205/heart/anndata_objects/Foetal/Immune/MoMP_Aug2023'

# %% [markdown]
# # Read in anndata object

# %%
adata = sc.read_h5ad(f'{adata_path_dir}/MultiVI-post_foetal_Mono-MP_withContCov-CCCov_13Mar2023_feature-select-0003.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 7674 × 142283
#     obs: 'sangerID', 'combinedID', 'donor', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'n_genes', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'HB_score', 'multiplexed', 'batch_key', 'region', 'FACSgate', 'sex', 'week', 'trimester', 'fine_grain', 'mid_grain', 'coarse_grain', 'heart_or_greatvessels', 'cycling', 'S_score', 'G2M_score', 'phase', 'stress_score', 'hb1_score', '_indices', '_scvi_batch', '_scvi_labels', 'fine_grain_withcycling', 't', 'seg', 'edge', 't_sd', 'milestones', 'fine_grain_mod'
#     var: 'modality', 'gene_name_scRNA-0', 'gene_id', 'n_cells'
# ...

# %%
# get regulon score data, gene expression based
adata_auc = adata.uns['adata_auc_gene'].copy()
adata_auc.uns['draw_graph'] = adata.uns['draw_graph']
print(adata_auc.X.data[:5])
adata_auc
# Out:
# ...
# AnnData object with n_obs × n_vars = 1899 × 280
#     obs: 'sangerID', 'combinedID', 'donor', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'n_genes', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'HB_score', 'multiplexed', 'batch_key', 'region', 'FACSgate', 'sex', 'week', 'trimester', 'fine_grain', 'mid_grain', 'coarse_grain', 'heart_or_greatvessels', 'cycling', 'S_score', 'G2M_score', 'phase', 'stress_score', 'hb1_score', '_indices', '_scvi_batch', '_scvi_labels', 'fine_grain_withcycling', 't', 'seg', 'edge', 't_sd', 'milestones'
#     uns: 'draw_graph'
#     obsm: 'MultiVI_latent', 'X_R', 'X_draw_graph_fa', 'X_palantir', 'X_umap', 'X_umap13', '_scvi_extra_categorical_covs', '_scvi_extra_continuous_covs'

# %% [markdown]
# # Plotting

# %%
markers = ['FLI1_+','MEF2C_+']
markers = [x for x in markers if x in adata_auc.var_names]

plt.rcParams['figure.figsize'] = 1.7,3.5
sc.pl.draw_graph(adata_auc,color=markers,cmap='inferno',wspace=0.45,frameon=False,show=False)
plt.savefig(f"{figdir}/Force-directed-graph_MoMP_YSMP-marker-regulon-scores.pdf", bbox_inches="tight",dpi=300)
