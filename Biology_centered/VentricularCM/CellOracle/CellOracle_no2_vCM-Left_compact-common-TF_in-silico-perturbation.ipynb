# %%
# Parameters
working_dir = "/nfs/team205/heart/Vitro/TF_selection/foetal_vCM_left_compact-vs-trabeculated_downstream/CO_in-silico-perturbation_papermill"
path_to_oracle_object = "/nfs/team205/heart/anndata_objects/Foetal/vCM/post_scFate/foetal_vCM_onlyLeft.celloracle.oracle"
path_to_oracle_links = "/nfs/team205/heart/anndata_objects/Foetal/vCM/post_scFate/vCM_onlyLeft_links.celloracle.links"
n_grid = 40
min_mass = 0.011
path_to_TFs = "/nfs/team205/heart/Vitro/TF_selection/foetal_vCM_left_compact-vs-trabeculated_downstream/TF_selection_df_compact-common-up_2Feb2024.csv"
path_to_res_dict = "/nfs/team205/heart/anndata_objects/Foetal/vCM/post_scFate/vCM_onlyLeft_compact-common_silico_perturbation_2Feb2024.pkl"
path_to_plots = "/nfs/team205/heart/Vitro/TF_selection/foetal_vCM_left_compact-vs-trabeculated_downstream/CO_in-silico-perturbation_papermill/figures_pm/compact-common_2Feb2024"

# %% [markdown]
# ref: https://morris-lab.github.io/CellOracle.documentation/notebooks/04_Network_analysis/Network_analysis_with_Paul_etal_2015_data.html

# %% [markdown]
# # Import libraries

# %%
import os
import sys

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns

# %%
import celloracle as co
co.__version__
# Out:
# /nfs/team205/kk18/miniconda3/envs/celloracle_env/lib/python3.8/site-packages/loompy/bus_file.py:68: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_to_dna(twobit: int, size: int) -> str:
# /nfs/team205/kk18/miniconda3/envs/celloracle_env/lib/python3.8/site-packages/loompy/bus_file.py:85: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def dna_to_twobit(dna: str) -> int:
# /nfs/team205/kk18/miniconda3/envs/celloracle_env/lib/python3.8/site-packages/loompy/bus_file.py:102: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_1hamming(twobit: int, size: int) -> List[int]:
# WARNING:matplotlib.font_manager:Matplotlib is building the font cache; this may take a moment.
# '0.14.0'

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# celloracle          0.14.0
# matplotlib          3.6.3
# numpy               1.24.3
# pandas              1.5.3
# scanpy              1.9.5
# seaborn             0.13.0
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# Bio                         1.81
# PIL                         10.0.1
# anndata                     0.9.2
# anyio                       NA
# appdirs                     1.4.4
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.13.0
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# biothings_client            0.3.0
# bottleneck                  1.3.5
# brotli                      NA
# certifi                     2023.07.22
# cffi                        1.15.1
# charset_normalizer          2.0.4
# colorama                    0.4.6
# comm                        0.1.4
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.0
# decorator                   5.1.1
# defusedxml                  0.7.1
# diskcache                   5.6.3
# exceptiongroup              1.1.3
# executing                   2.0.0
# fastjsonschema              NA
# filelock                    3.12.4
# fqdn                        NA
# genomepy                    0.16.1
# gimmemotifs                 0.17.0
# goatools                    1.3.9
# h5py                        3.10.0
# hypergeom_ufunc             NA
# idna                        3.4
# igraph                      0.10.8
# importlib_metadata          NA
# importlib_resources         NA
# invgauss_ufunc              NA
# ipykernel                   6.25.2
# ipywidgets                  8.1.1
# isoduration                 NA
# iteround                    NA
# jedi                        0.19.1
# jinja2                      3.1.2
# joblib                      1.2.0
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.19.1
# jsonschema_specifications   NA
# jupyter_events              0.8.0
# jupyter_server              2.8.0
# jupyterlab_server           2.25.0
# kiwisolver                  1.4.4
# llvmlite                    0.41.0
# logomaker                   NA
# loguru                      0.7.2
# loompy                      3.0.7
# louvain                     0.8.0
# markupsafe                  2.1.3
# mkl                         2.4.0
# mpl_toolkits                NA
# mygene                      3.2.2
# mysql                       NA
# natsort                     8.4.0
# nbformat                    5.9.2
# nbinom_ufunc                NA
# ncf_ufunc                   NA
# nct_ufunc                   NA
# ncx2_ufunc                  NA
# networkx                    3.1
# norns                       NA
# numba                       0.58.0
# numexpr                     2.8.4
# numpy_groupies              0.9.22
# overrides                   NA
# packaging                   23.1
# parso                       0.8.3
# patsy                       0.5.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                3.10.0
# prometheus_client           NA
# prompt_toolkit              3.0.39
# psutil                      5.9.6
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     13.0.0
# pybedtools                  0.9.1
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pyfaidx                     0.7.2.2
# pygments                    2.16.1
# pyparsing                   3.0.9
# pysam                       0.20.0
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.10.1
# send2trash                  NA
# setuptools                  68.2.2
# six                         1.16.0
# skewnorm_ufunc              NA
# sklearn                     1.3.0
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.3
# statsmodels                 0.14.0
# texttable                   1.7.0
# threadpoolctl               2.2.0
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.11.2
# typing_extensions           NA
# uri_template                NA
# urllib3                     1.26.16
# velocyto                    0.17.17
# wcwidth                     0.2.8
# webcolors                   1.13
# websocket                   1.6.4
# xdg                         NA
# xgboost                     2.0.0
# xxhash                      NA
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.1
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.12.3
# jupyter_client      8.4.0
# jupyter_core        5.4.0
# jupyterlab          4.0.7
# notebook            7.0.6
# -----
# Python 3.8.18 (default, Sep 11 2023, 13:40:15) [GCC 11.2.0]
# Linux-5.4.0-169-generic-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-02-03 00:23
# </pre>
# </details>

# %%
import importlib.util
import sys
spec = importlib.util.spec_from_file_location("module.name", "/nfs/team205/kk18/function/python/utils.py")
utils = importlib.util.module_from_spec(spec)
sys.modules["module.name"] = utils
spec.loader.exec_module(utils)

# %%
sc.settings.set_figure_params(dpi=120)

# %% [markdown]
# # Make out directory

# %%
if not os.path.exists(path_to_plots):
    # Create the directory
    os.makedirs(path_to_plots)
    print("Directory created successfully")
else:
    print("Directory already exists")
# Out:
# Directory created successfully

# %% [markdown]
# # Load oracle object

# %%
# Load
oracle = co.load_hdf5(path_to_oracle_object)

# %%
n_cell = oracle.adata.shape[0]
print(f"cell number is :{n_cell}")

k = int(0.025*n_cell)
print(f"Auto-selected k is :{k}")
# Out:
# cell number is :16451
# Auto-selected k is :411

# %%
# %matplotlib inline
# Check clustering data
sc.pl.draw_graph(oracle.adata, color='fine_grain_time-binned')

# %% [markdown]
# # In silico TF perturbation analysis

# %%
# Read data from txt file
df = pd.read_csv(path_to_TFs)
list_of_TFs = list(df['TF'])

# select TFs which are in the oracle object
list_of_TFs = [x for x in list_of_TFs if x in oracle.adata.var_names]

print(len(list_of_TFs))
list_of_TFs[:5]
# Out:
# 66
# ['ARID3A', 'ATF1', 'BACH2', 'BHLHE40', 'CUX1']

# %%
# Check gene expressions
# will be saved to a separated file
sc.settings.set_figure_params(dpi=80)
sc.pl.draw_graph(oracle.adata, color=list_of_TFs, ncols=6,
                 layer="imputed_count", use_raw=False, cmap="RdPu",
                 show=False, save='_TF_expression.png'
                )
# Out:
# WARNING: saving figure to file figures/draw_graph_fa_TF_expression.png
# [<AxesSubplot: title={'center': 'ARID3A'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ATF1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'BACH2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'BHLHE40'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'CUX1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ESRRA'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ESRRB'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'FOXN3'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'FOXO1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'GATA4'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'GATA6'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'GTF2IRD1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'HAND2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'HEY2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'HIF1A'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'HMBOX1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'KLF12'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'KLF6'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'LCORL'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'MAX'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'MAZ'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'MBNL2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'MEF2A'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'MEF2C'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'MEF2D'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'MEIS2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'MXI1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'NCOA1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'NFATC2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'NFE2L1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'NFIA'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'NFIB'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'NFIC'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'NPAS2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'NR3C1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'NR4A1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'PBX1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'PLAG1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'PPARA'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'PRDM16'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'RORA'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'SMAD3'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'SREBF2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'TBX20'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'TFCP2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'TGIF2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'THRA'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'USF2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'YY1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ZBTB16'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ZBTB20'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ZNF148'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ZNF280D'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ZNF654'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ZSCAN18'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'AHCTF1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'CREB1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'FOXK1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'PHF21A'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'SOX5'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'UBP1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ZNF141'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ELF2'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'POU2F1'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'ZNF586'}, xlabel='FA1', ylabel='FA2'>,
#  <AxesSubplot: title={'center': 'IRX3'}, xlabel='FA1', ylabel='FA2'>]

# %% [markdown]
# # Calculating pseudotime gradient vectors

# %%
from celloracle.applications import Gradient_calculator
# Instantiate Gradient calculator object
gradient = Gradient_calculator(oracle_object=oracle, pseudotime_key="t")
gradient.calculate_p_mass(smooth=0.8, n_grid=n_grid, n_neighbors=200)
gradient.calculate_mass_filter(min_mass=min_mass, plot=True)

# convert the pseudotime data into grid points.
# For this calculation we can chose one of two methods.
gradient.transfer_data_into_grid(args={"method": "knn", "n_knn":50})

# Calculate graddient
gradient.calculate_gradient()
# Show results
scale_dev = 40
gradient.visualize_results(scale=scale_dev, s=5)
# Visualize results
fig, ax = plt.subplots(figsize=[6, 6])
gradient.plot_dev_flow_on_grid(scale=scale_dev, ax=ax)

# %% [markdown]
# # Perturbation

# %%
from celloracle.applications import Oracle_development_module

# not showing plots
matplotlib.use('Agg')

# Get cell index list for the cells of interest
clusters = ['VentricularCardiomyocytesLeftCompact_t1',
 'VentricularCardiomyocytesLeftCompact_t2',
 'VentricularCardiomyocytesLeftCompact_t3']
cell_idx = np.where(oracle.adata.obs["fine_grain_time-binned"].isin(clusters))[0]

# Check index
print(cell_idx)

dev_dict = {}
for goi in list_of_TFs:
    print(goi)
    
    # Enter perturbation conditions to simulate signal propagation after the perturbation.
    oracle.simulate_shift(perturb_condition={goi: 0.0}, # this is KO simulation so expression=0
                          n_propagation=3)
    
    # Get transition probability
    oracle.estimate_transition_prob(n_neighbors=200,
                                    knn_random=True,
                                    sampled_fraction=1)

    # Calculate embedding
    oracle.calculate_embedding_shift(sigma_corr=0.05)
    
    # prepare grid
    oracle.calculate_p_mass(smooth=0.8, n_grid=n_grid, n_neighbors=200)
    oracle.calculate_mass_filter(min_mass=min_mass, plot=False)
    
    # plot vector field
    fig, ax = plt.subplots(1, 2,  figsize=[13, 6])
    scale_simulation = 0.1
    # Show quiver plot
    oracle.plot_simulation_flow_on_grid(scale=scale_simulation, ax=ax[0])
    ax[0].set_title(f"Simulated cell identity shift vector: {goi} KO")
    # Show quiver plot that was calculated with randomized graph.
    oracle.plot_simulation_flow_random_on_grid(scale=scale_simulation, ax=ax[1])
    ax[1].set_title(f"Randomized simulation vector")
    plt.savefig(f'{path_to_plots}/{goi}_simulation_vector.pdf')
    
    # Plot vector field with cell cluster
    fig, ax = plt.subplots(figsize=[8, 8])
    oracle.plot_cluster_whole(ax=ax, s=10)
    oracle.plot_simulation_flow_on_grid(scale=scale_simulation, ax=ax, show_background=False)
    plt.savefig(f'{path_to_plots}/{goi}_simulation_vector_with-clusters.pdf')
    
    
    dev = Oracle_development_module()
    # Load development flow
    dev.load_differentiation_reference_data(gradient_object=gradient)

    # Load simulation result
    dev.load_perturb_simulation_data(oracle_object=oracle,
                                     cell_idx_use=cell_idx, # Enter cell id list
                                     name="Lineage_Compact" # Name of this cell group. You can enter any name.
                                     )

    # Calculation
    dev.calculate_inner_product()
    dev.calculate_digitized_ip(n_bins=10)
    
    # save to the dictionary
    dev_dict[goi] = dev.copy()
    
    
    # Let's visualize the results
    vm = 0.01
    dev.visualize_development_module_layout_0(s=5,
                                              scale_for_simulation=scale_simulation,
                                              s_grid=50,
                                              scale_for_pseudotime=scale_dev,
                                              vm=vm)
    plt.savefig(f'{path_to_plots}/{goi}_results.pdf')
# Out:
# [    0     2     4 ... 16447 16448 16450]
# ARID3A
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ATF1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# BACH2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# BHLHE40
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# CUX1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ESRRA
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ESRRB
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# FOXN3
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# FOXO1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# GATA4
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# GATA6
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# GTF2IRD1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# HAND2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# HEY2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# HIF1A
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# HMBOX1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# KLF12
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# KLF6
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# LCORL
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MAX
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MAZ
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MBNL2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MEF2A
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MEF2C
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MEF2D
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MEIS2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MXI1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# NCOA1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# NFATC2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# NFE2L1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# NFIA
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# NFIB
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# NFIC
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# NPAS2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# NR3C1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# NR4A1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# PBX1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# PLAG1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# PPARA
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# PRDM16
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# RORA
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# SMAD3
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# SREBF2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# TBX20
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# TFCP2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# TGIF2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# THRA
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# USF2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# YY1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ZBTB16
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ZBTB20
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ZNF148
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ZNF280D
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ZNF654
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ZSCAN18
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# AHCTF1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# CREB1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# FOXK1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# PHF21A
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# SOX5
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# UBP1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ZNF141
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ELF2
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# POU2F1
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ZNF586
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# IRX3
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
# save
utils.save_pkl(dev_dict, path_to_res_dict)
