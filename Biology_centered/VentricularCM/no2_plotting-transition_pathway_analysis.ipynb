# %% [markdown]
# ref: https://yoseflab.github.io/Hotspot/CD4_Tutorial.html

# %%
# Parameters
working_dir = "/nfs/team205/heart/Vitro/TF_selection"
path_to_adata_gex_dir = "/nfs/team205/heart/anndata_objects/Vitro/post_multiVI_full-features"
path_to_adata_peak_tfidf = "/nfs/team205/heart/anndata_objects/Foetal/multiome_ATAC/ArchR/project_output/PeakMatrix/Foetal_Peaks_tfidf.h5ad"
group_key = "t_binned"
group_a = "t3"
group_b = "t1"
time_key = "t"
subset_object = False
geneset_list = ["MSigDB_Hallmark_2020","GO_Biological_Process_2023"]

path_to_eRegulon_signatures_gene = "/nfs/team205/heart/pyscenic/plus/eRegulon_signatures/vCM_onlyLeft_Gene_eRegulon_signatures.pkl"
path_to_eRegulon_signatures_region = "/nfs/team205/heart/pyscenic/plus/eRegulon_signatures/vCM_onlyLeft_Region_eRegulon_signatures.pkl"

path_to_DAR_compact = '/nfs/team205/heart/anndata_objects/Foetal/multiome_ATAC/ArchR/project_output/MarkerPeaks/vCM_Left_Compact-vs-Trab.csv'
path_to_DAR_trab = '/nfs/team205/heart/anndata_objects/Foetal/multiome_ATAC/ArchR/project_output/MarkerPeaks/vCM_Left_Trab-vs-Compact.csv'
path_to_eRegulon_metadata = "/nfs/team205/heart/pyscenic/plus/eRegulon_metadata/vCM_onlyLeft_eRegulon_metadata_filtered.csv" # filtered metadata

path_to_gene_signatures = '/nfs/team205/heart/Vitro/TF_selection/foetal_vCM_left_compact-vs-trabeculated_downstream/gene_signatures.pkl'

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import anndata

import matplotlib.pyplot as plt
import matplotlib as mpl
# enables correct plotting of text
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42 
import seaborn as sns

import hotspot

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.9.2
# hotspot             1.1.1
# matplotlib          3.7.2
# numpy               1.24.4
# pandas              1.5.3
# scanpy              1.9.3
# seaborn             0.12.2
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.0.0
# anyio                       NA
# arrow                       1.2.3
# asttokens                   NA
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.12.1
# backcall                    0.2.0
# brotli                      1.0.9
# certifi                     2023.11.17
# cffi                        1.15.1
# charset_normalizer          3.2.0
# colorama                    0.4.6
# comm                        0.1.4
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.6.8
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   1.2.0
# fastjsonschema              NA
# fqdn                        NA
# h5py                        3.9.0
# idna                        3.4
# igraph                      0.10.6
# importlib_metadata          NA
# importlib_resources         NA
# ipykernel                   6.25.1
# isoduration                 NA
# jedi                        0.19.0
# jinja2                      3.1.2
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.0
# jsonschema                  4.19.0
# jsonschema_specifications   NA
# jupyter_events              0.7.0
# jupyter_server              2.7.1
# jupyterlab_server           2.24.0
# kiwisolver                  1.4.5
# leidenalg                   0.10.1
# llvmlite                    0.40.1
# markupsafe                  2.1.3
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.57.1
# overrides                   NA
# packaging                   23.1
# parso                       0.8.3
# patsy                       0.5.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# plotly                      5.16.1
# prometheus_client           NA
# prompt_toolkit              3.0.39
# psutil                      5.9.5
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.16.1
# pynndescent                 0.5.10
# pyparsing                   3.0.9
# pythonjsonlogger            NA
# pytz                        2023.3
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# ruamel                      NA
# scipy                       1.10.1
# send2trash                  NA
# six                         1.16.0
# sklearn                     1.3.0
# sniffio                     1.3.0
# socks                       1.7.1
# sphinxcontrib               NA
# stack_data                  0.6.2
# statsmodels                 0.14.0
# texttable                   1.6.7
# threadpoolctl               3.2.0
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.9.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.0.4
# wcwidth                     0.2.6
# webcolors                   1.13
# websocket                   1.6.2
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.1
# zstandard                   0.19.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.12.0
# jupyter_client      8.3.0
# jupyter_core        4.12.0
# jupyterlab          4.0.5
# notebook            7.0.2
# -----
# Python 3.8.17 (default, Jul  5 2023, 21:04:15) [GCC 11.2.0]
# Linux-5.4.0-171-generic-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-02-22 22:51
# </pre>
# </details>

# %%
import importlib.util
import sys
spec = importlib.util.spec_from_file_location("module.name", "/nfs/team205/kk18/function/python/utils.py")
utils = importlib.util.module_from_spec(spec)
sys.modules["module.name"] = utils
spec.loader.exec_module(utils)

spec = importlib.util.spec_from_file_location("module.name", "/nfs/team205/kk18/function/python/regulon_plot.py")
regulon_plot = importlib.util.module_from_spec(spec)
sys.modules["module.name"] = regulon_plot
spec.loader.exec_module(regulon_plot)

spec = importlib.util.spec_from_file_location("module.name", "/nfs/team205/kk18/function/python/tissueaxis.py")
tissueaxis = importlib.util.module_from_spec(spec)
sys.modules["module.name"] = tissueaxis
spec.loader.exec_module(tissueaxis)

# %%
sc.settings.set_figure_params(dpi=80,dpi_save=300)

# %%
figdir = '/nfs/team205/heart/fetal_ms_figures/raw_plots_kk'

# %% [markdown]
# # Function

# %% [markdown]
# # Read in gene signatures and define target genes

# %%
gene_signatures = utils.read_pkl(path_to_gene_signatures)
for k,v in gene_signatures.items():
    print(f'{k}: {len(v)} genes')
# Out:
# compact_specific_up: 130 genes
# trab_specific_up: 107 genes
# common_up: 336 genes
# compact_specific_down: 185 genes
# trab_specific_down: 384 genes
# common_down: 738 genes

# %% [markdown]
# # Pathway analysis

# %%
import gseapy as gp

# %% [markdown]
# * Using three major pathways: 'MSigDB_Hallmark_2020','GO_Biological_Process_2023'

# %%
key = 'compact_specific_up'
adj_pval_thresh = 0.1
metrics = 'n_genes'
n_rank_plot = 10

enr = gp.enrichr(gene_list=gene_signatures[key],
                 gene_sets=geneset_list,
                 organism='human', # don't forget to set organism to the one you desired! e.g. Yeast
                 outdir=None, # don't write to disk
                )
enr.results['n_genes'] = [int(x.split('/')[0]) for x in enr.results['Overlap']]

for geneset in geneset_list:
    # select based on thresholds
    df = enr.results[enr.results['Gene_set'] == geneset]
    df = df[df['Adjusted P-value'] < adj_pval_thresh]
    if len(df)>0:
        print(geneset)
        df = df.sort_values(metrics,ascending=False)
        display(df[:30])
        
        # plot
        plt.rcParams['axes.grid'] = False
        plt.rcParams['figure.figsize'] = 4,2
        plt.barh(width=df[:n_rank_plot][metrics],
                 y=[x.split(' (')[0] for x in df[:n_rank_plot]['Term']],
                 color='darkred')
        plt.gca().invert_yaxis()
        plt.xlabel(metrics)
        plt.title(f'{key}, {geneset}')
        plt.margins(y=0.03)
        plt.savefig(f'{figdir}/Pathway-enr_vCM-left_{key}_{geneset}.pdf', bbox_inches="tight",dpi=300)
        plt.show()
# Out:
# MSigDB_Hallmark_2020
#                Gene_set                     Term Overlap   P-value  \
# 0  MSigDB_Hallmark_2020                  Hypoxia   7/200  0.000337
# 1  MSigDB_Hallmark_2020               Myogenesis   7/200  0.000337
# 2  MSigDB_Hallmark_2020  Estrogen Response Early   6/200  0.001982
# 3  MSigDB_Hallmark_2020               Glycolysis   6/200  0.001982
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.006237            0                     0    5.802224
# 1          0.006237            0                     0    5.802224
# 2          0.018337            0                     0    4.907549
# 3          0.018337            0                     0    4.907549
#
#    Combined Score                                      Genes  n_genes
# 0       46.388736   ERO1A;SCARB1;WSB1;NDRG1;PPFIA4;PAM;VEGFA        7
# 1       46.388736  CKMT2;DES;SLC6A8;CD36;COX6A2;PPFIA4;CRYAB        7
# 2       30.541899     SCARB1;B4GALT1;GAB2;AFF1;DHRS3;SLC19A2        6
# 3       30.541899       ERO1A;EGLN3;B4GALT1;PPFIA4;PAM;VEGFA        6
# GO_Biological_Process_2023
#                       Gene_set  \
# 38  GO_Biological_Process_2023
# 37  GO_Biological_Process_2023
# 43  GO_Biological_Process_2023
# 39  GO_Biological_Process_2023
# 40  GO_Biological_Process_2023
# 41  GO_Biological_Process_2023
# 42  GO_Biological_Process_2023
#
#                                                  Term Overlap   P-value  \
# 38                       Lipid Transport (GO:0006869)   6/108  0.000075
# 37       Organophosphate Ester Transport (GO:0015748)    4/25  0.000019
# 43                Phospholipid Transport (GO:0015914)    4/59  0.000588
# 39  Regulation Of Type B Pancreatic Cell Prolifera...     2/5  0.000414
# 40                    Cholesterol Import (GO:0070508)     2/5  0.000414
# 41  Positive Regulation Of Cholesterol Storage (GO...     2/5  0.000414
# 42     Venous Blood Vessel Morphogenesis (GO:0048845)     2/5  0.000414
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 38          0.040023            0                     0    9.377609
# 37          0.020768            0                     0   30.006047
# 43          0.089996            0                     0   11.437229
# 39          0.073884            0                     0  103.473958
# 40          0.073884            0                     0  103.473958
# 41          0.073884            0                     0  103.473958
# 42          0.073884            0                     0  103.473958
#
#     Combined Score                                    Genes  n_genes
# 38       89.101479  SCARB1;RBP7;PRELID2;OSBPL2;CD36;PITPNC1        6
# 37      325.585948            SCARB1;PRELID2;OSBPL2;PITPNC1        4
# 43       85.075032            SCARB1;PRELID2;OSBPL2;PITPNC1        4
# 39      806.046068                              NR4A1;NR4A3        2
# 40      806.046068                              SCARB1;CD36        2
# 41      806.046068                            SCARB1;SREBF2        2
# 42      806.046068                              TBX20;VEGFA        2

# %%
key = 'trab_specific_up'
adj_pval_thresh = 0.1
metrics = 'n_genes'
n_rank_plot = 10

enr = gp.enrichr(gene_list=gene_signatures[key],
                 gene_sets=geneset_list,
                 organism='human', # don't forget to set organism to the one you desired! e.g. Yeast
                 outdir=None, # don't write to disk
                )
enr.results['n_genes'] = [int(x.split('/')[0]) for x in enr.results['Overlap']]

for geneset in geneset_list:
    # select based on thresholds
    df = enr.results[enr.results['Gene_set'] == geneset]
    df = df[df['Adjusted P-value'] < adj_pval_thresh]
    if len(df)>0:
        print(geneset)
        df = df.sort_values(metrics,ascending=False)
        display(df[:30])
        
        # plot
        plt.rcParams['axes.grid'] = False
        plt.rcParams['figure.figsize'] = 4,3
        plt.barh(width=df[:n_rank_plot][metrics],
                 y=[x.split(' (')[0] for x in df[:n_rank_plot]['Term']],
                 color='darkred')
        plt.gca().invert_yaxis()
        plt.xlabel(metrics)
        plt.title(f'{key}, {geneset}')
        plt.margins(y=0.03)
        plt.savefig(f'{figdir}/Pathway-enr_vCM-left_{key}_{geneset}.pdf', bbox_inches="tight",dpi=300)
        plt.show()
# Out:
# MSigDB_Hallmark_2020
#                Gene_set        Term Overlap   P-value  Adjusted P-value  \
# 0  MSigDB_Hallmark_2020  Myogenesis   8/200  0.000012          0.000231
#
#    Old P-value  Old Adjusted P-value  Odds Ratio  Combined Score  \
# 0            0                     0    8.291667        93.84269
#
#                                       Genes  n_genes
# 0  ACTA1;DTNA;SGCD;MB;CDH13;NAV2;MYOM2;SGCG        8

# %%
key = 'common_up'
adj_pval_thresh = 0.1
metrics = 'n_genes'
n_rank_plot = 10

enr = gp.enrichr(gene_list=gene_signatures[key],
                 gene_sets=geneset_list,
                 organism='human', # don't forget to set organism to the one you desired! e.g. Yeast
                 outdir=None, # don't write to disk
                )
enr.results['n_genes'] = [int(x.split('/')[0]) for x in enr.results['Overlap']]

for geneset in geneset_list:
    # select based on thresholds
    df = enr.results[enr.results['Gene_set'] == geneset]
    df = df[df['Adjusted P-value'] < adj_pval_thresh]
    if len(df)>0:
        print(geneset)
        df = df.sort_values(metrics,ascending=False)
        display(df[:30])
        
        # plot
        plt.rcParams['axes.grid'] = False
        plt.rcParams['figure.figsize'] = 4,3
        plt.barh(width=df[:n_rank_plot][metrics],
                 y=[x.split(' (')[0] for x in df[:n_rank_plot]['Term']],
                 color='darkred')
        plt.gca().invert_yaxis()
        plt.xlabel(metrics)
        plt.title(f'{key}, {geneset}')
        plt.margins(y=0.03)
        plt.savefig(f'{figdir}/Pathway-enr_vCM-left_{key}_{geneset}.pdf', bbox_inches="tight",dpi=300)
        plt.show()
# Out:
# MSigDB_Hallmark_2020
#                Gene_set                     Term Overlap       P-value  \
# 1  MSigDB_Hallmark_2020               Myogenesis  15/200  1.558227e-06
# 0  MSigDB_Hallmark_2020           UV Response Dn  14/144  1.500811e-07
# 2  MSigDB_Hallmark_2020                  Hypoxia  13/200  3.561255e-05
# 3  MSigDB_Hallmark_2020  Estrogen Response Early  11/200  5.924531e-04
# 4  MSigDB_Hallmark_2020          Mitotic Spindle  10/199  2.041276e-03
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 1          0.000031            0                     0    4.920182
# 0          0.000006            0                     0    6.533110
# 2          0.000475            0                     0    4.192000
# 3          0.005925            0                     0    3.487586
# 4          0.016330            0                     0    3.160808
#
#    Combined Score                                              Genes  n_genes
# 1       65.792483  MEF2A;MYBPC3;MYOM1;SVIL;LAMA2;PDE4DIP;LDB3;SOR...       15
# 0      102.648816  NRP1;WDR37;CELF2;COL11A1;NR3C1;KALRN;IGF1R;INP...       14
# 2       42.937872  BNIP3L;KDM3A;ZNF292;RORA;AK4;KLHL24;NR3C1;GYS1...       13
# 3       25.917088  NCOR2;SVIL;GJA1;ABLIM1;ADCY9;DLC1;ITPK1;JAK2;R...       11
# 4       19.578612  ARFGEF1;ABR;AKAP13;NIN;DST;ALS2;MYO9B;ACTN4;SY...       10
# GO_Biological_Process_2023
#                       Gene_set  \
# 86  GO_Biological_Process_2023
# 44  GO_Biological_Process_2023
# 45  GO_Biological_Process_2023
# 40  GO_Biological_Process_2023
# 97       31.693839                         MYBPC3;RYR2;INSR;RBM20;TTN        5
# 53      112.594721                     KCNQ1;DMD;CACNA1C;SCN5A;SLC4A3        5
# 42      588.944004                    CACNB2;GJA1;KCNQ1;CACNA1C;SCN5A        5
# 56      106.085260                      RYR2;GJA1;KCNQ1;CACNA1C;SCN5A        5
# 47      218.064714                      RYR2;CASQ2;ATP2A2;DMD;CACNA1C        5
# 49      183.624129                        RYR2;CASQ2;DMD;CACNA1C;TRDN        5
# 50      136.462425                   RYR2;ATP2A2;CTNNA3;CACNA1C;SCN5A        5
# 59      131.000135                           PYGB;GYS1;PPP1R3C;PRKAG2        4
# 94       45.083493                              SVIL;DMD;CFLAR;LARGE1        4
# 87       49.993997                                WNK2;AKAP9;DMD;ANK3        4

# %%
key = 'compact_specific_down'
adj_pval_thresh = 0.1
metrics = 'n_genes'
n_rank_plot = 10

enr = gp.enrichr(gene_list=gene_signatures[key],
                 gene_sets=geneset_list,
                 organism='human', # don't forget to set organism to the one you desired! e.g. Yeast
                 outdir=None, # don't write to disk
                )
enr.results['n_genes'] = [int(x.split('/')[0]) for x in enr.results['Overlap']]

for geneset in geneset_list:
    # select based on thresholds
    df = enr.results[enr.results['Gene_set'] == geneset]
    df = df[df['Adjusted P-value'] < adj_pval_thresh]
    if len(df)>0:
        print(geneset)
        df = df.sort_values(metrics,ascending=False)
        display(df[:30])
        
        # plot
        plt.rcParams['axes.grid'] = False
        plt.rcParams['figure.figsize'] = 4,3
        plt.barh(width=df[:n_rank_plot][metrics],
                 y=[x.split(' (')[0] for x in df[:n_rank_plot]['Term']],
                 color='darkred')
        plt.gca().invert_yaxis()
        plt.xlabel(metrics)
        plt.title(f'{key}, {geneset}')
        plt.margins(y=0.03)
        plt.show()
# Out:
# MSigDB_Hallmark_2020
#                Gene_set                               Term Overlap  \
# 0  MSigDB_Hallmark_2020                     UV Response Dn  10/144
# 1  MSigDB_Hallmark_2020  Epithelial Mesenchymal Transition  10/200
# 3  MSigDB_Hallmark_2020                    Mitotic Spindle   6/199
# 4  MSigDB_Hallmark_2020      TNF-alpha Signaling via NF-kB   6/200
# 2  MSigDB_Hallmark_2020                    Notch Signaling    3/32
#
#         P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0  9.455637e-07          0.000032            0                     0
# 1  1.771981e-05          0.000301            0                     0
# 3  1.064380e-02          0.074060            0                     0
# 4  1.089115e-02          0.074060            0                     0
# 2  3.170589e-03          0.035933            0                     0
#
#    Odds Ratio  Combined Score  \
# 0    8.392751      116.419910
# 1    5.902256       64.575559
# 3    3.407879       15.481237
# 4    3.390140       15.322770
# 2   11.246305       64.709418
#
#                                                Genes  n_genes
# 0  COL3A1;COL1A2;PRKAR2B;PIK3R3;PTPRM;PRKCA;ATP2B...       10
# 1  FBN2;VCAN;COL3A1;COL1A2;IGFBP2;PMEPA1;VEGFC;SL...       10
# 3               DOCK4;STAU1;PALLD;RASAL2;KIFAP3;MID1        6
# 4              BTG1;TSC22D1;PMEPA1;INHBA;ATP2B1;IER3        6
# 2                                MAML2;ST3GAL6;PRKCA        3
# GO_Biological_Process_2023
#                       Gene_set  \
# 34  GO_Biological_Process_2023
# 41  GO_Biological_Process_2023
# 36  GO_Biological_Process_2023
# 45  GO_Biological_Process_2023
# 43  GO_Biological_Process_2023
# 40  GO_Biological_Process_2023
# 60  GO_Biological_Process_2023
# 48  GO_Biological_Process_2023
# 44  GO_Biological_Process_2023
# 86  GO_Biological_Process_2023
# 93  GO_Biological_Process_2023
# 38  GO_Biological_Process_2023
# 63  GO_Biological_Process_2023
# 58  GO_Biological_Process_2023
# 72  GO_Biological_Process_2023
# 89  GO_Biological_Process_2023
# 35  GO_Biological_Process_2023
# 62  GO_Biological_Process_2023
# 61  GO_Biological_Process_2023
# 84  GO_Biological_Process_2023
# 82  GO_Biological_Process_2023
# 94  GO_Biological_Process_2023
# 37  GO_Biological_Process_2023
# 39  GO_Biological_Process_2023
# 49  GO_Biological_Process_2023
# 42  GO_Biological_Process_2023
# 92  GO_Biological_Process_2023
# 83  GO_Biological_Process_2023
# 75  GO_Biological_Process_2023
# 74  GO_Biological_Process_2023
#
#                                                  Term Overlap   P-value  \
# 34                     Heart Development (GO:0007507)  10/171  0.000004
# 41  Negative Regulation Of Multicellular Organisma...   9/231  0.000310
# 36                         Axon Guidance (GO:0007411)   8/149  0.000076
# 45            Regulation Of Angiogenesis (GO:0045765)   8/205  0.000660
# 43           Actin Filament Organization (GO:0007015)   7/144  0.000392
# 40  Transmembrane Receptor Protein Serine/Threonin...   7/130  0.000210
# 60        Circulatory System Development (GO:0072359)   6/132  0.001444
# 48   Positive Regulation Of Angiogenesis (GO:0045766)   6/119  0.000845
# 44  Positive Regulation Of Vasculature Development...   6/104  0.000414
# 86             Cytoskeleton Organization (GO:0007010)   5/111  0.003731
# 93  Positive Regulation Of Cell Projection Organiz...   5/118  0.004837
# 38     Cardiac Muscle Tissue Development (GO:0048738)    5/52  0.000117
# 63  Regulation Of Endothelial Cell Proliferation (...    5/93  0.001728
# 58  Regulation Of Endothelial Cell Migration (GO:0...    5/88  0.001352
# 72                 BMP Signaling Pathway (GO:0030509)    4/61  0.002452
# 89       Regulation Of Heart Contraction (GO:0008016)    4/69  0.003836
# 35      Regulation Of Cardiac Conduction (GO:1903779)    4/21  0.000037
# 62                      Neuron Migration (GO:0001764)    4/55  0.001673
# 61      Mesenchymal Cell Differentiation (GO:0048762)    4/54  0.001562
# 84        Neuropeptide Signaling Pathway (GO:0007218)    4/68  0.003640
# 82     Cellular Response To BMP Stimulus (GO:0071773)    4/66  0.003268
# 94   Positive Regulation Of Neurogenesis (GO:0050769)    4/75  0.005168
# 37  Cardiac Conduction System Development (GO:0003...    4/25  0.000077
# 39                   Negative Chemotaxis (GO:0050919)    4/31  0.000183
# 49  Positive Regulation Of Blood Vessel Endothelia...    4/46  0.000854
# 42        Ventricular Septum Development (GO:0003281)    4/37  0.000369
# 92  Positive Regulation Of Myeloid Cell Differenti...    3/36  0.004442
# 83  Regulation Of Lamellipodium Assembly (GO:0010591)    3/33  0.003464
# 75     Negative Regulation Of Chemotaxis (GO:0050922)    3/31  0.002893
# 74  Positive Regulation Of Lamellipodium Organizat...    3/31  0.002893
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
#
# 42      104.730491                              GJA5;SLIT2;TBX5;ZFPM2        4
# 92       53.521736                                 INHBA;FOXO3;MAPK14        3
# 83       61.586695                                   AUTS2;AVIL;SLIT2        3
# 75       68.091721                                SEMA3C;SEMA3A;SLIT2        3
# 74       68.091721                                 CARMIL1;AUTS2;AVIL        3

# %%
key = 'common_down'
adj_pval_thresh = 0.1
metrics = 'n_genes'
n_rank_plot = 10

enr = gp.enrichr(gene_list=gene_signatures[key],
                 gene_sets=geneset_list,
                 organism='human', # don't forget to set organism to the one you desired! e.g. Yeast
                 outdir=None, # don't write to disk
                )
enr.results['n_genes'] = [int(x.split('/')[0]) for x in enr.results['Overlap']]

for geneset in geneset_list:
    # select based on thresholds
    df = enr.results[enr.results['Gene_set'] == geneset]
    df = df[df['Adjusted P-value'] < adj_pval_thresh]
    if len(df)>0:
        print(geneset)
        df = df.sort_values(metrics,ascending=False)
        display(df[:30])
        
        # plot
        plt.rcParams['axes.grid'] = False
        plt.rcParams['figure.figsize'] = 4,3
        plt.barh(width=df[:n_rank_plot][metrics],
                 y=[x.split(' (')[0] for x in df[:n_rank_plot]['Term']],
                 color='darkred')
        plt.gca().invert_yaxis()
        plt.xlabel(metrics)
        plt.title(f'{key}, {geneset}')
        plt.margins(y=0.03)
        plt.show()
# Out:
# MSigDB_Hallmark_2020
#                 Gene_set                               Term Overlap  \
# 0   MSigDB_Hallmark_2020                     Myc Targets V1  77/200
# 1   MSigDB_Hallmark_2020          Oxidative Phosphorylation  55/200
# 2   MSigDB_Hallmark_2020                        E2F Targets  32/200
# 3   MSigDB_Hallmark_2020                    G2-M Checkpoint  30/200
# 4   MSigDB_Hallmark_2020                   mTORC1 Signaling  26/200
# 5   MSigDB_Hallmark_2020                       Adipogenesis  24/200
# 10  MSigDB_Hallmark_2020                    Mitotic Spindle  19/199
# 9   MSigDB_Hallmark_2020              Fatty Acid Metabolism  18/158
# 13  MSigDB_Hallmark_2020  Epithelial Mesenchymal Transition  18/200
# 17  MSigDB_Hallmark_2020                         Glycolysis  17/200
# 16  MSigDB_Hallmark_2020                         Myogenesis  17/200
# 7   MSigDB_Hallmark_2020          Unfolded Protein Response  16/113
# 14  MSigDB_Hallmark_2020                     UV Response Up  15/158
# 15  MSigDB_Hallmark_2020                          Apoptosis  15/161
# 12  MSigDB_Hallmark_2020                         DNA Repair  15/150
# 8   MSigDB_Hallmark_2020           PI3K/AKT/mTOR  Signaling  15/105
# 21  MSigDB_Hallmark_2020                            Hypoxia  13/200
# 22  MSigDB_Hallmark_2020             Estrogen Response Late  13/200
# 23  MSigDB_Hallmark_2020                    Apical Junction  13/200
# 11  MSigDB_Hallmark_2020                  Androgen Response  12/100
# 6   MSigDB_Hallmark_2020    Reactive Oxygen Species Pathway   11/49
# 18  MSigDB_Hallmark_2020                        Pperoxisome  10/104
# 19  MSigDB_Hallmark_2020                  Protein Secretion    8/96
# 24  MSigDB_Hallmark_2020                 TGF-beta Signaling    5/54
# 20  MSigDB_Hallmark_2020                    Notch Signaling    4/32
#
#          P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 
# 15  BTG2;CDKN1B;TNFRSF12A;GPX4;GADD45A;CAV1;SOD2;S...       15
# 12  DUT;GPX4;TAF10;AK1;SSRP1;TYMS;RBX1;NME1;GUK1;D...       15
# 8   ACTR2;ARF1;CDKN1B;DUSP3;YWHAB;PTPN11;ACACA;HSP...       15
# 21  CDKN1B;CAVIN1;HSPA5;TIPARP;CITED2;CAV1;ENO3;PN...       13
# 22  FARP1;SLC16A1;CAV1;IDH2;EMP2;KRT19;FABP5;CCND1...       13
# 23  GAMT;ITGB1;ACTB;MYL12B;GNAI2;ACTG1;CLDN6;TJP1;...       13
# 11  LMAN1;XRCC6;KRT19;CCND1;XRCC5;LIFR;DBI;PA2G4;B...       12
# 6   PDLIM1;NDUFA6;GPX4;NDUFB4;NDUFS2;TXN;SOD2;PRDX...       11
# 18  GSTK1;FIS1;SCP2;CNBP;IDH2;ISOC1;PABPC1;SOD2;YW...       10
# 19        CD63;LMAN1;ARF1;GNAS;ATP1A1;AP2M1;COPE;SOD1        8
# 24                          FKBP1A;TJP1;ID2;SKIL;RHOA        5
# 20                             TCF7L2;CCND1;SKP1;RBX1        4
# GO_Biological_Process_2023
#                        Gene_set  \
# 233  GO_Biological_Process_2023
# 153  GO_Biological_Process_2023
# 116  GO_Biological_Process_2023
# 171  GO_Biological_Process_2023
# 105  GO_Biological_Process_2023
# 95   GO_Biological_Process_2023
# 131  GO_Biological_Process_2023
# 56   GO_Biological_Process_2023
# 59   GO_Biological_Process_2023
# 175  GO_Biological_Process_2023
# 60   GO_Biological_Process_2023
# 93   GO_Biological_Process_2023
# 53   GO_Biological_Process_2023
# 90   GO_Biological_Process_2023
# 243  GO_Biological_Process_2023
# 250  GO_Biological_Process_2023
# 61   GO_Biological_Process_2023
# 110  GO_Biological_Process_2023
# 91   GO_Biological_Process_2023
# 99   GO_Biological_Process_2023
# 84   GO_Biological_Process_2023
# 92   GO_Biological_Process_2023
# 67   GO_Biological_Process_2023
# 184  GO_Biological_Process_2023
# 176  GO_Biological_Process_2023
# 138  GO_Biological_Process_2023
# 88   GO_Biological_Process_2023
# 204  GO_Biological_Process_2023
# 270  GO_Biological_Process_2023
# 55   GO_Biological_Process_2023
#
#                                                   Term  Overlap       P-value  \
# 233  Positive Regulation Of DNA-templated Transcrip...  65/1243  2.858379e-03
# 153  Negative Regulation Of DNA-templated Transcrip...  59/1025  4.836385e-04
# 116       Regulation Of Apoptotic Process (GO:0042981)   47/705  7.076666e-05
# 171  Regulation Of Cell Population Proliferation (G...   46/766  8.466678e-04
# 105  Positive Regulation Of Cellular Process (GO:00...   43/594  2.167412e-05
# 95   Ubiquitin-Dependent Protein Catabolic Process ...   33/367  2.474878e-06
# 131  Negative Regulation Of Nucleic Acid-Templated ...   33/456  1.936134e-04
# 56                        mRNA Processing (GO:0006397)   33/214  3.147555e-12
# 59         mRNA Splicing, Via Spliceosome (GO:0000398)   32/211  1.060583e-11
# 175  Negative Regulation Of Apoptotic Process (GO:0...   32/482  1.050137e-03
# 60              Regulation Of Translation (GO:0006417)   31/202  1.633342e-11
# 93   Proteasome-Mediated Ubiquitin-Dependent Protei...   31/319  9.783264e-07
# 95        34.244153  VCP;PSMD14;UBE2D2;NEDD8;FBXO21;RNF5;PSMA7;UBE2...
# 131       17.823397  EIF4A2;SET;CDKN1B;CTBP2;CITED2;CHD4;PTPRK;PHB2...
# 56       130.688520  TCERG1;SF3B2;RBM8A;SF3B6;HNRNPU;HTATSF1;SNRPD2...
# 59       122.106157  SF3B2;RBM8A;SF3B6;HNRNPU;HTATSF1;SNRPD2;PUF60;...
# 175       12.996251  ITGB1;SET;PRKDC;CITED2;GSTP1;PARK7;HIGD1A;PHB2...
# 60       121.587269  EIF4A2;BTG2;PRKDC;TYMS;BZW2;BZW1;RBM3;EIF4H;IG...
# 93        39.972737  VCP;PSMD14;RNF5;PSMA7;ANAPC11;HSP90B1;PSMD8;PS...
# 53       151.619844  TCERG1;SF3B2;RBM8A;HNRNPU;ADARB2;RBM3;SNRPD2;P...
# 90        46.525672  BTG2;VCP;SET;PRKDC;HMGB3;PARK7;HMGB1;TYMS;PTMS...
# 243        9.946163  DNMT1;PRKDC;CITED2;PDCD5;AKR1B1;PARK7;ACTG1;RB...
# 250        9.721909  CD81;HNRNPU;AKR1B1;ACTB;GNAI2;PRDX3;CCND2;NKX2...
# 61       127.063415  SF3B2;RBM8A;SF3B6;HNRNPU;HTATSF1;SNRPD2;SNRPD1...
# 110       24.744336  COL18A1;LMOD2;CDC42;CNN1;STMN1;MYO6;SERPINH1;X...
# 91        47.969469  MRPS34;MRPL14;MRPS30;MRPL34;MRPL57;MRPL41;MRPL...
# 99        33.883177  KDM5B;HNRNPU;DDX21;NUCKS1;CHD4;ZNHIT1;TRIM28;B...
# 84        63.875931  PARK7;PHB2;RTN4;BAG1;POLR2E;CCT8;TBL1X;CCT7;SO...
# 92        48.906838  VCP;PSMD14;RNF5;PSMA7;PSMD8;PSMB6;PSMB7;ZNRF1;...
# 67       104.254970  CPSF6;PRKDC;XRCC5;PTGES3;EIF2S2;LSM4;SRPK1;MRP...
# 184       14.112988  CCT2;TRAPPC1;GPX4;HSPA4;PTGES3;TRAPPC5;FN1;CYB...
# 176       14.521391  ARF1;TMED9;NPM1;NUTF2;PTTG1IP;SEPTIN9;DNAJC15;...
# 138       19.217067  RNGTT;RBM8A;PABPC4;MRPL27;HNRNPU;MRPS21;MRPL14...
# 88        56.433806  NPM1;VCP;CDKN1B;SSB;PRKDC;TIPARP;PRMT1;RDX;ATG...
# 204       13.083715  MEF2C;BTG2;DNMT1;YTHDF2;TIPARP;CITED2;CHD4;PAR...
# 270        9.541592  CUTA;ARF1;TMED9;NPM1;CD81;LRBA;CAV1;ITSN1;EMP2...
# 55       233.505188  NDUFB9;NDUFA8;NDUFB8;NDUFA7;NDUFA6;NDUFA11;NDU...
#
#      n_genes
# 233       65
# 153       59
# 116       47
# 171       46
# 105       43
# 95        33
# 131       33
# 56        33
# 59        32
# 175       32
# 60        31
# 93        31
# 53        31
# 90        30
# 243       30
# 250       30
# 61        29
# 110       27
# 91        26
# 99        26
# 84        26
# 92        25
# 67        24
# 184       24
# 176       24
# 138       24
# 88        24
# 204       24
# 270       23
# 55        21
