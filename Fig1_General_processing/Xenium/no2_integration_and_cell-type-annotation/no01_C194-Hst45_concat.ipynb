# %%
import scanpy as sc
import numpy as np
import pandas as pd
import os
# import rapids_singlecell as rsc
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import session_info
session_info.show()
# Out:
# /home/kk837/.conda/envs/generic_env/lib/python3.10/site-packages/session_info/main.py:213: UserWarning: The '__version__' attribute is deprecated and will be removed in MarkupSafe 3.1. Use feature detection, or `importlib.metadata.version("markupsafe")`, instead.
#   mod_version = _find_version(mod.__version__)
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# matplotlib          3.10.1
# numpy               2.1.3
# pandas              2.2.3
# scanpy              1.11.1
# seaborn             0.13.2
# session_info        v1.0.1
# tqdm                4.67.1
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 11.1.0
# anndata             0.11.4
# asciitree           NA
# asttokens           NA
# charset_normalizer  3.4.1
# cloudpickle         3.1.1
# comm                0.2.2
# cycler              0.12.1
# cython_runtime      NA
# dask                2024.11.2
# dateutil            2.9.0.post0
# debugpy             1.8.13
# decorator           5.2.1
# exceptiongroup      1.2.2
# executing           2.2.0
# h5py                3.13.0
# igraph              0.11.8
# importlib_metadata  NA
# ipykernel           6.29.5
# jedi                0.19.2
# jinja2              3.1.6
# joblib              1.4.2
# kiwisolver          1.4.8
# legacy_api_wrap     NA
# leidenalg           0.10.2
# llvmlite            0.44.0
# markupsafe          3.0.2
# mpl_toolkits        NA
# msgpack             1.1.0
# natsort             8.4.0
# numba               0.61.0
# numcodecs           0.13.1
# packaging           24.2
# parso               0.8.4
# patsy               1.0.1
# platformdirs        4.3.7
# prompt_toolkit      3.0.50
# psutil              7.0.0
# pure_eval           0.2.3
# pyarrow             19.0.1
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              3.2.3
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.19.1
# pyparsing           3.2.3
# pytz                2025.2
# scipy               1.15.2
# six                 1.17.0
# sklearn             1.5.2
# stack_data          0.6.3
# statsmodels         0.14.4
# tblib               3.1.0
# texttable           1.7.0
# threadpoolctl       3.6.0
# tlz                 1.0.0
# toolz               1.0.0
# tornado             6.4.2
# traitlets           5.14.3
# typing_extensions   NA
# wcwidth             0.2.13
# yaml                6.0.2
# zarr                2.18.3
# zipp                NA
# zmq                 26.3.0
# zoneinfo            NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.34.0
# jupyter_client      8.6.3
# jupyter_core        5.7.2
# -----
# Python 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Linux-4.18.0-553.45.1.el8_10.x86_64-x86_64-with-glibc2.28
# -----
# Session information updated at 2025-05-29 11:15
# </pre>
# </details>

# %%
sc.settings.set_figure_params(dpi=120)

# %% [markdown]
# # Read in

# %%
objects_dir = '/home/kk837/rds/rds-teichlab-C9woKbOCf2Y/kk837/Foetal/anndata_objects/Xenium'

# %%
sample_id_1 = 'C194-HEA-0-FFPE-1'
path_adata_1 = f'{objects_dir}/{sample_id_1}_5K_filtered_raw.h5ad'

sample_id_2 = 'Hst45-HEA-0-FFPE-1'
path_adata_2 = f'{objects_dir}/{sample_id_2}_5K_filtered_raw.h5ad'

# %%
adata_1 = sc.read_h5ad(path_adata_1)
adata_1
# Out:
# AnnData object with n_obs × n_vars = 144916 × 5001
#     obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'n_genes'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     obsm: 'spatial'

# %%
adata_2 = sc.read_h5ad(path_adata_2)
adata_2
# Out:
# AnnData object with n_obs × n_vars = 217361 × 5001
#     obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'n_genes'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     obsm: 'spatial'

# %% [markdown]
# # Concatenate

# %%
# tidy obs columns
adata_1.obs = adata_1.obs[['cell_id', 'x_centroid', 'y_centroid', 'transcript_counts',
       'control_probe_counts', 'genomic_control_counts',
       'control_codeword_counts', 'unassigned_codeword_counts',
       'deprecated_codeword_counts', 'total_counts', 'cell_area',
       'nucleus_area', 'nucleus_count', 'segmentation_method',
       'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts',
       'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes',
       'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts',
       'n_genes']]
adata_1.obs['tissue_block_id'] = sample_id_1

adata_2.obs = adata_2.obs[['cell_id', 'x_centroid', 'y_centroid', 'transcript_counts',
       'control_probe_counts', 'genomic_control_counts',
       'control_codeword_counts', 'unassigned_codeword_counts',
       'deprecated_codeword_counts', 'total_counts', 'cell_area',
       'nucleus_area', 'nucleus_count', 'segmentation_method',
       'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts',
       'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes',
       'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts',
       'n_genes']]
adata_2.obs['tissue_block_id'] = sample_id_2

# %%
# concatenate
adata = adata_1.concatenate(adata_2, 
            join='inner', 
            batch_key=None, 
            index_unique=None)
adata.obs['tissue_block_id'].value_counts()
# Out:
# /tmp/ipykernel_1481351/366024108.py:2: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata = adata_1.concatenate(adata_2,
# /home/kk837/.conda/envs/generic_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/kk837/.conda/envs/generic_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# tissue_block_id
# Hst45-HEA-0-FFPE-1    217361
# C194-HEA-0-FFPE-1     144916
# Name: count, dtype: int64

# %% [markdown]
# # Update obs_names and save

# %%
adata.obs_names = adata.obs['tissue_block_id'].astype('str') + '_' + adata.obs_names.astype('str')
adata.obs.head()
# Out:
#                                  cell_id  x_centroid   y_centroid  \
# C194-HEA-0-FFPE-1_aaaafiob-1  aaaafiob-1  782.026245  1025.860474
# C194-HEA-0-FFPE-1_aaaajopp-1  aaaajopp-1  784.114746  1034.308350
# C194-HEA-0-FFPE-1_aaaanald-1  aaaanald-1  791.200500  1028.298462
# C194-HEA-0-FFPE-1_aaabdjka-1  aaabdjka-1  819.555664  1032.847168
# C194-HEA-0-FFPE-1_aaabglmg-1  aaabglmg-1  819.384583  1007.732910
#
#                               transcript_counts  control_probe_counts  \
# C194-HEA-0-FFPE-1_aaaafiob-1                754                     0
# C194-HEA-0-FFPE-1_aaaajopp-1                145                     0
# C194-HEA-0-FFPE-1_aaaanald-1                569                     0
# C194-HEA-0-FFPE-1_aaabdjka-1                659                     0
# C194-HEA-0-FFPE-1_aaabglmg-1                 83                     0
#
#                               genomic_control_counts  control_codeword_counts  \
# C194-HEA-0-FFPE-1_aaaafiob-1                       0                        0
# C194-HEA-0-FFPE-1_aaaajopp-1                       0                        0
# C194-HEA-0-FFPE-1_aaaanald-1                       0                        0
# C194-HEA-0-FFPE-1_aaabdjka-1                       0                        0
# C194-HEA-0-FFPE-1_aaabglmg-1                       0                        0
#
#                               unassigned_codeword_counts  \
# C194-HEA-0-FFPE-1_aaaafiob-1                           0
# C194-HEA-0-FFPE-1_aaaajopp-1                           0
# C194-HEA-0-FFPE-1_aaaanald-1                           0
# C194-HEA-0-FFPE-1_aaabdjka-1                           1
# C194-HEA-0-FFPE-1_aaabglmg-1                           0
#
#                               deprecated_codeword_counts  total_counts  ...  \
# C194-HEA-0-FFPE-1_aaaafiob-1                           0         754.0  ...
# C194-HEA-0-FFPE-1_aaaajopp-1                           0         145.0  ...
# C194-HEA-0-FFPE-1_aaaanald-1                           0         569.0  ...
# C194-HEA-0-FFPE-1_aaabdjka-1                           0         659.0  ...
# C194-HEA-0-FFPE-1_aaabglmg-1                           0          83.0  ...
#
#                               n_genes_by_counts  log1p_n_genes_by_counts  \
# C194-HEA-0-FFPE-1_aaaafiob-1                510                 6.236370
# C194-HEA-0-FFPE-1_aaaajopp-1                120                 4.795791
# C194-HEA-0-FFPE-1_aaaanald-1                369                 5.913503
# C194-HEA-0-FFPE-1_aaabdjka-1                449                 6.109248
# C194-HEA-0-FFPE-1_aaabglmg-1                 67                 4.219508
#
#                               log1p_total_counts pct_counts_in_top_10_genes  \
# C194-HEA-0-FFPE-1_aaaafiob-1            6.626718                   8.620690
# C194-HEA-0-FFPE-1_aaaajopp-1            4.983607                  20.689655
# C194-HEA-0-FFPE-1_aaaanald-1            6.345636                  17.223199
# C194-HEA-0-FFPE-1_aaabdjka-1            6.492240                  10.318665
# C194-HEA-0-FFPE-1_aaabglmg-1            4.430817                  31.325301
#
#                               pct_counts_in_top_20_genes  \
# C194-HEA-0-FFPE-1_aaaafiob-1                   14.323607
# C194-HEA-0-FFPE-1_aaaajopp-1                   31.034483
# C194-HEA-0-FFPE-1_aaaanald-1                   23.374341
# C194-HEA-0-FFPE-1_aaabdjka-1                   16.691958
# C194-HEA-0-FFPE-1_aaabglmg-1                   43.373494
#
#                               pct_counts_in_top_50_genes  \
# C194-HEA-0-FFPE-1_aaaafiob-1                   26.525199
# C194-HEA-0-FFPE-1_aaaajopp-1                   51.724138
# C194-HEA-0-FFPE-1_aaaanald-1                   35.852373
# C194-HEA-0-FFPE-1_aaabdjka-1                   28.831563
# C194-HEA-0-FFPE-1_aaabglmg-1                   79.518072
#
#                               pct_counts_in_top_150_genes  n_counts  n_genes  \
# C194-HEA-0-FFPE-1_aaaafiob-1                    52.254642     754.0      510
# C194-HEA-0-FFPE-1_aaaajopp-1                   100.000000     145.0      120
# C194-HEA-0-FFPE-1_aaaanald-1                    61.511424     569.0      369
# C194-HEA-0-FFPE-1_aaabdjka-1                    54.628225     659.0      449
# C194-HEA-0-FFPE-1_aaabglmg-1                   100.000000      83.0       67
#
#                                 tissue_block_id
# C194-HEA-0-FFPE-1_aaaafiob-1  C194-HEA-0-FFPE-1
# C194-HEA-0-FFPE-1_aaaajopp-1  C194-HEA-0-FFPE-1
# C194-HEA-0-FFPE-1_aaaanald-1  C194-HEA-0-FFPE-1
# C194-HEA-0-FFPE-1_aaabdjka-1  C194-HEA-0-FFPE-1
# C194-HEA-0-FFPE-1_aaabglmg-1  C194-HEA-0-FFPE-1
#
# [5 rows x 24 columns]

# %% [markdown]
# # Save

# %%
path_adata = f'{objects_dir}/C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_raw.h5ad'

# %%
# save
adata.write(path_adata)
adata.obs.head()
# Out:
#                                  cell_id  x_centroid   y_centroid  \
# C194-HEA-0-FFPE-1_aaaafiob-1  aaaafiob-1  782.026245  1025.860474
# C194-HEA-0-FFPE-1_aaaajopp-1  aaaajopp-1  784.114746  1034.308350
# C194-HEA-0-FFPE-1_aaaanald-1  aaaanald-1  791.200500  1028.298462
# C194-HEA-0-FFPE-1_aaabdjka-1  aaabdjka-1  819.555664  1032.847168
# C194-HEA-0-FFPE-1_aaabglmg-1  aaabglmg-1  819.384583  1007.732910
#
#                               transcript_counts  control_probe_counts  \
# C194-HEA-0-FFPE-1_aaaafiob-1                754                     0
# C194-HEA-0-FFPE-1_aaaajopp-1                145                     0
# C194-HEA-0-FFPE-1_aaaanald-1                569                     0
# C194-HEA-0-FFPE-1_aaabdjka-1                659                     0
# C194-HEA-0-FFPE-1_aaabglmg-1                 83                     0
#
#                               genomic_control_counts  control_codeword_counts  \
# C194-HEA-0-FFPE-1_aaaafiob-1                       0                        0
# C194-HEA-0-FFPE-1_aaaajopp-1                       0                        0
# C194-HEA-0-FFPE-1_aaaanald-1                       0                        0
# C194-HEA-0-FFPE-1_aaabdjka-1                       0                        0
# C194-HEA-0-FFPE-1_aaabglmg-1                       0                        0
#
#                               unassigned_codeword_counts  \
# C194-HEA-0-FFPE-1_aaaafiob-1                           0
# C194-HEA-0-FFPE-1_aaaajopp-1                           0
# C194-HEA-0-FFPE-1_aaaanald-1                           0
# C194-HEA-0-FFPE-1_aaabdjka-1                           1
# C194-HEA-0-FFPE-1_aaabglmg-1                           0
#
#                               deprecated_codeword_counts  total_counts  ...  \
# C194-HEA-0-FFPE-1_aaaafiob-1                           0         754.0  ...
# C194-HEA-0-FFPE-1_aaaajopp-1                           0         145.0  ...
# C194-HEA-0-FFPE-1_aaaanald-1                           0         569.0  ...
# C194-HEA-0-FFPE-1_aaabdjka-1                           0         659.0  ...
# C194-HEA-0-FFPE-1_aaabglmg-1                           0          83.0  ...
#
#                               n_genes_by_counts  log1p_n_genes_by_counts  \
# C194-HEA-0-FFPE-1_aaaafiob-1                510                 6.236370
# C194-HEA-0-FFPE-1_aaaajopp-1                120                 4.795791
# C194-HEA-0-FFPE-1_aaaanald-1                369                 5.913503
# C194-HEA-0-FFPE-1_aaabdjka-1                449                 6.109248
# C194-HEA-0-FFPE-1_aaabglmg-1                 67                 4.219508
#
#                               log1p_total_counts pct_counts_in_top_10_genes  \
# C194-HEA-0-FFPE-1_aaaafiob-1            6.626718                   8.620690
# C194-HEA-0-FFPE-1_aaaajopp-1            4.983607                  20.689655
# C194-HEA-0-FFPE-1_aaaanald-1            6.345636                  17.223199
# C194-HEA-0-FFPE-1_aaabdjka-1            6.492240                  10.318665
# C194-HEA-0-FFPE-1_aaabglmg-1            4.430817                  31.325301
#
#                               pct_counts_in_top_20_genes  \
# C194-HEA-0-FFPE-1_aaaafiob-1                   14.323607
# C194-HEA-0-FFPE-1_aaaajopp-1                   31.034483
# C194-HEA-0-FFPE-1_aaaanald-1                   23.374341
# C194-HEA-0-FFPE-1_aaabdjka-1                   16.691958
# C194-HEA-0-FFPE-1_aaabglmg-1                   43.373494
#
#                               pct_counts_in_top_50_genes  \
# C194-HEA-0-FFPE-1_aaaafiob-1                   26.525199
# C194-HEA-0-FFPE-1_aaaajopp-1                   51.724138
# C194-HEA-0-FFPE-1_aaaanald-1                   35.852373
# C194-HEA-0-FFPE-1_aaabdjka-1                   28.831563
# C194-HEA-0-FFPE-1_aaabglmg-1                   79.518072
#
#                               pct_counts_in_top_150_genes  n_counts  n_genes  \
# C194-HEA-0-FFPE-1_aaaafiob-1                    52.254642     754.0      510
# C194-HEA-0-FFPE-1_aaaajopp-1                   100.000000     145.0      120
# C194-HEA-0-FFPE-1_aaaanald-1                    61.511424     569.0      369
# C194-HEA-0-FFPE-1_aaabdjka-1                    54.628225     659.0      449
# C194-HEA-0-FFPE-1_aaabglmg-1                   100.000000      83.0       67
#
#                                 tissue_block_id
# C194-HEA-0-FFPE-1_aaaafiob-1  C194-HEA-0-FFPE-1
# C194-HEA-0-FFPE-1_aaaajopp-1  C194-HEA-0-FFPE-1
# C194-HEA-0-FFPE-1_aaaanald-1  C194-HEA-0-FFPE-1
# C194-HEA-0-FFPE-1_aaabdjka-1  C194-HEA-0-FFPE-1
# C194-HEA-0-FFPE-1_aaabglmg-1  C194-HEA-0-FFPE-1
#
# [5 rows x 24 columns]

# %%
adata.X.data[:5]
# Out:
# array([5., 1., 1., 2., 2.], dtype=float32)
