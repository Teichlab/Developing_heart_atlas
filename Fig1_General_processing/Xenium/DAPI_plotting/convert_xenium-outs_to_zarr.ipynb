# %%
import matplotlib.pyplot as plt
import scanpy as sc
import numpy as np
import pandas as pd
import os

import spatialdata as sd
from spatialdata_io import xenium
# Out:
# /home/kk837/.conda/envs/generic_env/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(

# %%
sc.settings.set_figure_params(dpi=80)

# %% [markdown]
# # Load Xenium data and save as zarr file

# %%
xenium_dir = '/rfs/project/rfs-iCNyzSAaucw/jc2226/heart_team_data/xenium/20241113__133901__JK_HEA5K_Hs_heart_vessels'
# !ls {xenium_dir}
# Out:
# output-XETG00155__0038587__C194-HEA-0-FFPE-1__20241113__134112
# output-XETG00155__0038587__Hst45-HEA-0-FFPE-1__20241113__134112
# output-XETG00155__0038587__Hst60-HEA-0-FFPE-1__20241113__134112
# output-XETG00155__0038592__AH13-HEA-36-FFPE-1__20241113__134112
# output-XETG00155__0038592__AH14-HEA-29-FFPE-2__20241113__134112
# output-XETG00155__0038592__AH14-HEA-36-FFPE-1__20241113__134112

# %%
save_dir = '/rfs/project/rfs-iCNyzSAaucw/kk837/data_objects/Foetal/Xenium'
# !ls {save_dir}
# Out:
# C194-HEA-0-FFPE-1_5K_filtered_lognorm.h5ad
# C194-HEA-0-FFPE-1_5K_filtered_raw.h5ad
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_Cardiomyocytes_annotations.csv
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_celltype-sel_raw.h5ad
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_MyeloidCells_mixture_annotations.csv
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_NeuralCells_mixture_annotations.csv
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_raw.h5ad
# Hst45-HEA-0-FFPE-1_5K_filtered_lognorm.h5ad
# Hst45-HEA-0-FFPE-1_5K_filtered_raw.h5ad
# subsets_archive
# TACCO
# zarr

# %%
os.makedirs(f'{save_dir}/zarr',exist_ok=True)

# %%
# %%time
for filename in ['output-XETG00155__0038587__C194-HEA-0-FFPE-1__20241113__134112',
                 'output-XETG00155__0038587__Hst45-HEA-0-FFPE-1__20241113__134112']:
    print(f'##### {filename} #####')
    xenium_path = f'{xenium_dir}/{filename}'
    
    # load xenium data
    sdata = xenium(xenium_path)
    print(sdata)
    
    # save
    sdata.write(f'{save_dir}/zarr/{filename}.zarr')
    print('')
# Out:
# ##### output-XETG00155__0038587__C194-HEA-0-FFPE-1__20241113__134112 #####
# INFO     reading
#          /rfs/project/rfs-iCNyzSAaucw/jc2226/heart_team_data/xenium/20241113__133901__JK_HEA5K_Hs_heart_vessels/out
#          put-XETG00155__0038587__C194-HEA-0-FFPE-1__20241113__134112/cell_feature_matrix.h5
# <timed exec>:7: DeprecationWarning: The default value of `cells_as_circles` will change to `False` in the next release. Please pass `True` explicitly to maintain the current behavior.
# /home/kk837/.conda/envs/generic_env/lib/python3.10/site-packages/spatialdata_io/_utils.py:48: UserWarning: The "cell_id" column in the cells metadata table does not match the "cell_id" column in the annotation table. This could be due to trying to read a new version that is not supported yet. Please report this issue.
#   return f(*args, **kwargs)
# ...

# %%
# %%time
for filename in [
                 # 'output-XETG00155__0038587__C194-HEA-0-FFPE-1__20241113__134112',
                 'output-XETG00155__0038587__Hst45-HEA-0-FFPE-1__20241113__134112'
]:
    print(f'##### {filename} #####')
    xenium_path = f'{xenium_dir}/{filename}'
    
    # load xenium data
    sdata = xenium(xenium_path)
    print(sdata)
    
    # save
    sdata.write(f'{save_dir}/zarr/{filename}.zarr')
    print('')
# Out:
# ##### output-XETG00155__0038587__Hst45-HEA-0-FFPE-1__20241113__134112 #####
# INFO     reading
#          /rfs/project/rfs-iCNyzSAaucw/jc2226/heart_team_data/xenium/20241113__133901__JK_HEA5K_Hs_heart_vessels/out
#          put-XETG00155__0038587__Hst45-HEA-0-FFPE-1__20241113__134112/cell_feature_matrix.h5
# <timed exec>:9: DeprecationWarning: The default value of `cells_as_circles` will change to `False` in the next release. Please pass `True` explicitly to maintain the current behavior.
# /home/kk837/.conda/envs/generic_env/lib/python3.10/site-packages/spatialdata_io/_utils.py:48: UserWarning: The "cell_id" column in the cells metadata table does not match the "cell_id" column in the annotation table. This could be due to trying to read a new version that is not supported yet. Please report this issue.
#   return f(*args, **kwargs)
# ...
