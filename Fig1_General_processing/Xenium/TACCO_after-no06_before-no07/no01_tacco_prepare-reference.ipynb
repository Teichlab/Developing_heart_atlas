# %%
import numpy as np
import pandas as pd
import scanpy as sc

# %%
import session_info
session_info.show()
# Out:
# /home/kk837/.conda/envs/generic_env/lib/python3.10/site-packages/session_info/main.py:213: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   mod_version = _find_version(mod.__version__)
# /home/kk837/.conda/envs/generic_env/lib/python3.10/site-packages/session_info/main.py:213: UserWarning: The '__version__' attribute is deprecated and will be removed in MarkupSafe 3.1. Use feature detection, or `importlib.metadata.version("markupsafe")`, instead.
#   mod_version = _find_version(mod.__version__)
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# numpy               2.1.3
# pandas              2.2.3
# scanpy              1.11.5
# session_info        v1.0.1
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# Cython              3.1.1
# PIL                 11.1.0
# anndata             0.11.4
# asciitree           NA
# asttokens           NA
# charset_normalizer  3.4.1
# cloudpickle         3.1.1
# comm                0.2.2
# cycler              0.12.1
# cython              3.1.1
# cython_runtime      NA
# dask                2024.11.2
# dateutil            2.9.0.post0
# debugpy             1.8.13
# decorator           5.2.1
# defusedxml          0.7.1
# exceptiongroup      1.2.2
# executing           2.2.0
# h5py                3.13.0
# igraph              0.11.8
# importlib_metadata  NA
# ipykernel           6.29.5
# jedi                0.19.2
# jinja2              3.1.6
# joblib              1.4.2
# kiwisolver          1.4.8
# legacy_api_wrap     NA
# leidenalg           0.10.2
# llvmlite            0.44.0
# markupsafe          3.0.2
# matplotlib          3.10.1
# mpl_toolkits        NA
# msgpack             1.1.0
# natsort             8.4.0
# numba               0.61.0
# numcodecs           0.13.1
# numexpr             2.13.1
# packaging           24.2
# parso               0.8.4
# platformdirs        4.3.7
# prompt_toolkit      3.0.50
# psutil              7.0.0
# pure_eval           0.2.3
# pyarrow             19.0.1
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              3.2.3
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.19.1
# pyparsing           3.2.3
# pytz                2025.2
# scipy               1.15.2
# six                 1.17.0
# sklearn             1.5.2
# stack_data          0.6.3
# tblib               3.1.0
# texttable           1.7.0
# threadpoolctl       3.6.0
# tlz                 1.0.0
# toolz               1.0.0
# tornado             6.4.2
# traitlets           5.14.3
# typing_extensions   NA
# wcwidth             0.2.13
# yaml                6.0.2
# zarr                2.18.3
# zipp                NA
# zmq                 26.3.0
# zoneinfo            NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.34.0
# jupyter_client      8.6.3
# jupyter_core        5.7.2
# -----
# Python 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Linux-4.18.0-553.111.1.el8_10.x86_64-x86_64-with-glibc2.28
# -----
# Session information updated at 2026-04-14 06:22
# </pre>
# </details>

# %%
import importlib.util
import sys
spec = importlib.util.spec_from_file_location("module.name", "/rfs/project/rfs-iCNyzSAaucw/kk837/function/python/utils.py")
utils = importlib.util.module_from_spec(spec)
sys.modules["module.name"] = utils
spec.loader.exec_module(utils)
# Out:
# /rfs/project/rfs-iCNyzSAaucw/kk837/function/python/utils.py:356: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   if sc.__version__.startswith("1.4"):

# %% [markdown]
# # Variables

# %%
data_object_dir = '/rfs/project/rfs-iCNyzSAaucw/kk837/data_objects/Foetal/Xenium'
# !ls {data_object_dir}
# Out:
# C194-HEA-0-FFPE-1_5K_filtered_lognorm.h5ad
# C194-HEA-0-FFPE-1_5K_filtered_raw.h5ad
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_Cardiomyocytes_annotations.csv
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_celltype-sel_raw.h5ad
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_MyeloidCells_mixture_annotations.csv
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_NeuralCells_mixture_annotations.csv
# C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_raw.h5ad
# Hst45-HEA-0-FFPE-1_5K_filtered_lognorm.h5ad
# Hst45-HEA-0-FFPE-1_5K_filtered_raw.h5ad
# subsets_archive

# %% [markdown]
# # Read in HD adata

# %%
adata = sc.read_h5ad(f'{data_object_dir}/C194-HEA-0-FFPE-1_Hst45-HEA-0-FFPE-1_concat_5K_filtered_celltype-sel_raw.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 341592 × 5001
#     obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'n_genes', 'tissue_block_id', 'celltypist_coarse', 'conf_score_coarse', 'celltypist_coarse_fin', 'celltypist_coarse2midmod', 'conf_score_coarse2midmod', 'celltypist_mid_fin', 'celltypist_midmod2fine', 'conf_score_midmod2fine', 'pca_harmony_leiden_0.2', 'pca_harmony_leiden_0.3', 'pca_harmony_leiden_0.4', 'pca_harmony_leiden_0.5', 'pca_harmony_leiden_0.8', 'pca_harmony_leiden_1.0', 'pca_harmony_leiden_1.5', 'pca_harmony_leiden_2.0', 'pca_harmony_leiden_3.0', 'multi_celltypes_coarse', 'fine_grain_12Jun2025', 'sliding_window_assignment', 'window_col', 'window_row', 'globalX', 'globalY', 'tt_prediction', 'coarse_grain_pre', 'coarse_grain_pre_2'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts-0', 'mean_counts-0', 'log1p_mean_counts-0', 'pct_dropout_by_counts-0', 'total_counts-0', 'log1p_total_counts-0', 'n_cells_by_counts-1', 'mean_counts-1', 'log1p_mean_counts-1', 'pct_dropout_by_counts-1', 'total_counts-1', 'log1p_total_counts-1'
#     uns: 'celltypist_coarse2midmod_colors', 'celltypist_coarse_colors', 'celltypist_mid_fin_colors', 'coarse_grain_pre_2_colors', 'dendrogram_pca_harmony_leiden_1.0', 'fine_grain_12Jun2025_colors', 'multi_celltypes_coarse_colors', 'pca', 'pca_harmony', 'pca_harmony_leiden_0.2', 'pca_harmony_leiden_0.2_colors', 'pca_harmony_leiden_0.3', 'pca_harmony_leiden_0.3_colors', 'pca_harmony_leiden_0.4', 'pca_harmony_leiden_0.4_colors', 'pca_harmony_leiden_0.5', 'pca_harmony_leiden_0.5_colors', 'pca_harmony_leiden_0.8', 'pca_harmony_leiden_0.8_colors', 'pca_harmony_leiden_1.0', 'pca_harmony_leiden_1.0_colors', 'pca_harmony_leiden_1.5', 'pca_harmony_leiden_1.5_colors', 'pca_harmony_leiden_2.0', 'pca_harmony_leiden_2.0_colors', 'pca_harmony_leiden_3.0', 'pca_harmony_leiden_3.0_colors', 'tissue_block_id_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap_pca_harmony', 'spatial'
#     varm: 'PCs'
#     obsp: 'pca_harmony_connectivities', 'pca_harmony_distances'

# %%
adata.obs['coarse_grain_pre_2'].value_counts()
# Out:
# coarse_grain_pre_2
# VentricularCardiomyocytes    128532
# unclassified_mixture         101190
# MesenchymalCells              61655
# AtrialCardiomyocytes          39138
# EpicardialCells                3904
# EndothelialCells               3360
# NeuralCells                    1877
# MyeloidCells                   1623
# LymphoidCells                   313
# Name: count, dtype: int64

# %% [markdown]
# # Read in single-cell/nuc RNA-seq data

# %%
adata_scn = sc.read_h5ad('/rfs/project/rfs-iCNyzSAaucw/kk837/data_objects/Foetal/RNA/Feb28ObjectRaw_finegrain_updated.h5ad')
adata_scn
# Out:
# AnnData object with n_obs × n_vars = 297473 × 36601
#     obs: 'latent_RT_efficiency', 'latent_cell_probability', 'latent_scale', 'sangerID', 'combinedID', 'donor', 'region', 'age', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'n_genes', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'HB_score', 'donor_by_library-prep', 'multiplexed', 'SOC | status', 'SOC | log_prob_singleton', 'SOC | log_prob_doublet', 'batch_key', '_scvi_batch', 'FACSgate', 'fine_grain', 'mid_grain', 'coarse_grain', 'sex', 'week', 'trimester', 'heart_or_greatvessels', 'cycling', 'S_score', 'G2M_score', 'phase', '_scvi_labels', 'stress_score', 'hb1_score'
#     var: 'gene_name_scRNA-0', 'gene_id'
#     uns: 'FACSgate_colors', '_scvi_manager_uuid', '_scvi_uuid', 'age_colors', 'cell_or_nuclei_colors', 'coarse_grain_colors', 'cycling_colors', 'donor_colors', 'fine_grain_colors', 'heart_or_greatvessels_colors', 'hvg', 'kit_10x_colors', 'mid_grain_colors', 'modality_colors', 'neighbors', 'phase_colors', 'region_colors', 'sex_colors', 'trimester_colors', 'umap', 'week_colors'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs', '_scvi_extra_continuous', '_scvi_extra_continuous_covs', 'latent_gene_encoding'
#     obsp: 'connectivities', 'distances'

# %%
# modify mid_grain (to separate CCS cells)
acm_obsnames = adata_scn.obs_names[adata_scn.obs['fine_grain'].isin(['AtrialCardiomyocytesCycling',
                                                                     'AtrialCardiomyocytesLeft',
                                                                     'AtrialCardiomyocytesRight',
                                                                     'AtrioventricularNodePacemakerCells',
                                                                    'SinoatrialNodePacemakerCells'])]
vcm_obsnames = adata_scn.obs_names[adata_scn.obs['fine_grain'].isin(['VentricularCardiomyocytesCycling',
                                                             'VentricularCardiomyocytesLeftCompact',
                                                             'VentricularCardiomyocytesLeftTrabeculated',
                                                             'VentricularCardiomyocytesRightCompact',
                                                             'VentricularCardiomyocytesRightTrabeculated',
                                                             'VentricularConductionSystemDistal',
                                                             'VentricularConductionSystemProximal'])]

adata_scn.obs['mid_grain_mod'] = adata_scn.obs['mid_grain'].astype('str').copy()
adata_scn.obs.loc[acm_obsnames,'mid_grain_mod'] = 'AtrialCardiomyocytes'
adata_scn.obs.loc[vcm_obsnames,'mid_grain_mod'] = 'VentricularCardiomyocytes'
adata_scn.obs['mid_grain_mod'].value_counts()
# Out:
# mid_grain_mod
# Fibroblasts                    102791
# VentricularCardiomyocytes       53268
# MuralCells                      28497
# AtrialCardiomyocytes            21616
# LymphoidCells                   21084
# MyeloidCells                    19962
# PericardialCells                16811
# BloodVesselEndothelialCells     11352
# EndocardialCells                 9346
# EpicardialCells                  4186
# Glia                             3541
# Neurons                          2608
# LymphaticEndothelialCells        2411
# Name: count, dtype: int64

# %% [markdown]
# # Subsample scnRNA-seq data based on cell number of Xenium data and number of fine_grain cell types

# %% [markdown]
# - For each cell type label, subsample scnRNA-seq data to be same cell number as the Xenium classified data or smaller number
# - For each cell type label, split the Xenium cell number into the number of fine_grain cell types (in scnRNAseq). That number will be the max_n for subsampling per fine_grain.
# - For cell types which doesn't exist in Xenium data, keep all the cells

# %%
set(adata.obs['coarse_grain_pre_2'])
# Out:
# {'AtrialCardiomyocytes',
#  'EndothelialCells',
#  'EpicardialCells',
#  'LymphoidCells',
#  'MesenchymalCells',
#  'MyeloidCells',
#  'NeuralCells',
#  'VentricularCardiomyocytes',
#  'unclassified_mixture'}

# %%
set(adata_scn.obs['coarse_grain'])
# Out:
# {'Cardiomyocytes',
#  'Endothelium',
#  'Epicardium',
#  'Leukocytes',
#  'Mesenchymal',
#  'Neural'}

# %%
set(adata_scn.obs['mid_grain_mod'])
# Out:
# {'AtrialCardiomyocytes',
#  'BloodVesselEndothelialCells',
#  'EndocardialCells',
#  'EpicardialCells',
#  'Fibroblasts',
#  'Glia',
#  'LymphaticEndothelialCells',
#  'LymphoidCells',
#  'MuralCells',
#  'MyeloidCells',
#  'Neurons',
#  'PericardialCells',
#  'VentricularCardiomyocytes'}

# %%
celltype_dict = {
    'AtrialCardiomyocytes':['mid_grain_mod',['AtrialCardiomyocytes']],
     'EndothelialCells':['mid_grain_mod',['BloodVesselEndothelialCells','LymphaticEndothelialCells','EndocardialCells']],
     'EpicardialCells':['coarse_grain',['Epicardium']],
     'MesenchymalCells':['coarse_grain',['Mesenchymal']],
     'MyeloidCells':['mid_grain_mod',['MyeloidCells']],
    'LymphoidCells':['mid_grain_mod',['LymphoidCells']],
     'NeuralCells':['coarse_grain',['Neural']],
     'VentricularCardiomyocytes':['mid_grain_mod',['VentricularCardiomyocytes']],
}

# %%
set(adata.obs['coarse_grain_pre_2']) - set(celltype_dict.keys())
# Out:
# {'unclassified_mixture'}

# %%
adata_ref_list = []
for celltype,subset_info in celltype_dict.items():
    if celltype!='not_found':
        print(f'### {celltype} ###')
        xenium_sub = adata[adata.obs['coarse_grain_pre_2']==celltype]
        scn_sub = adata_scn[adata_scn.obs[subset_info[0]].isin(subset_info[1])]
        max_n = round(xenium_sub.shape[0]/len(set(scn_sub.obs['fine_grain'])))
        print(f'max_n for subsampling per fine-grain: {max_n}')
        # subsampling
        scn_sub = utils.sctk_subsample(scn_sub,fraction=1,groupby='fine_grain',max_n=max_n)
        print('value_counts of scnRNAseq, per fine-grain')
        print(scn_sub.obs['fine_grain'].value_counts())
        # concatenate
        xenium_sub.obs['reference_type'] = 'Xenium'
        scn_sub.obs['reference_type'] = 'scnRNAseq'
        ad_concat = xenium_sub.concatenate(scn_sub, 
                                       join='inner', 
                                       batch_key=None,
                                       index_unique=None
                                      )
        ad_concat.obs['reference_celltype'] = celltype
        print('value_counts of reference type')
        print(ad_concat.obs['reference_type'].value_counts())
        adata_ref_list.append(ad_concat)
        del xenium_sub,scn_sub,max_n,ad_concat
    else:
        print(f'### {subset_info} ###')
        scn_sub = adata_scn[adata_scn.obs[subset_info[0]].isin(subset_info[1])]
        max_n = 1000
        print(f'max_n for subsampling per fine-grain: {max_n}')
        scn_sub = utils.sctk_subsample(scn_sub,fraction=1,groupby='fine_grain',max_n=max_n)
        print('value_counts of scnRNAseq, per fine-grain')
        print(scn_sub.obs['fine_grain'].value_counts())
        scn_sub.obs['reference_type'] = 'scnRNAseq'
        scn_sub.obs['reference_celltype'] = '_'.join(subset_info[1])
        print(scn_sub.obs['reference_type'].value_counts())
        adata_ref_list.append(scn_sub)
        del scn_sub,max_n
    print('')
# Out:
# ### AtrialCardiomyocytes ###
# max_n for subsampling per fine-grain: 7828
# value_counts of scnRNAseq, per fine-grain
# fine_grain
# AtrialCardiomyocytesRight             7828
# AtrialCardiomyocytesLeft              6606
# AtrialCardiomyocytesCycling           2396
# SinoatrialNodePacemakerCells           981
# AtrioventricularNodePacemakerCells     937
# Name: count, dtype: int64
# /tmp/ipykernel_710009/3873780781.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   xenium_sub.obs['reference_type'] = 'Xenium'
# /tmp/ipykernel_710009/3873780781.py:16: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   ad_concat = xenium_sub.concatenate(scn_sub,
# value_counts of reference type
# reference_type
# Xenium       39138
# scnRNAseq    18748
# Name: count, dtype: int64
#
# ### EndothelialCells ###
# max_n for subsampling per fine-grain: 373
# value_counts of scnRNAseq, per fine-grain
# fine_grain
# GreatVesselArterialEndothelialCells    373
# GreatVesselVenousEndothelialCells      373
# CoronaryArterialEndothelialCells       373
# CoronaryVenousEndothelialCells         373
# CoronaryCapillaryEndothelialCells      373
# EndocardialCells                       373
# EndocardialCushionCells                373
# ValveEndothelialCells                  373
# LymphaticEndothelialCells              373
# Name: count, dtype: int64
# /tmp/ipykernel_710009/3873780781.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   xenium_sub.obs['reference_type'] = 'Xenium'
# /tmp/ipykernel_710009/3873780781.py:16: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   ad_concat = xenium_sub.concatenate(scn_sub,
# value_counts of reference type
# reference_type
# Xenium       3360
# scnRNAseq    3357
# Name: count, dtype: int64
#
# ### EpicardialCells ###
# max_n for subsampling per fine-grain: 1952
# value_counts of scnRNAseq, per fine-grain
# fine_grain
# MesothelialEpicardialCells    1952
# EpicardiumDerivedCells        1347
# Name: count, dtype: int64
# /tmp/ipykernel_710009/3873780781.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   xenium_sub.obs['reference_type'] = 'Xenium'
# /tmp/ipykernel_710009/3873780781.py:16: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   ad_concat = xenium_sub.concatenate(scn_sub,
# value_counts of reference type
# reference_type
# Xenium       3904
# scnRNAseq    3299
# Name: count, dtype: int64
#
# ### MesenchymalCells ###
# max_n for subsampling per fine-grain: 4404
# value_counts of scnRNAseq, per fine-grain
# fine_grain
# GreatVesselAdventitialFibroblasts       4404
# MyocardialInterstitialFibroblasts       4404
# Myofibroblasts                          4404
# SubEpicardialFibroblasts                4404
# GreatVesselSmoothMuscleCells            4404
# ValveInterstitialCells                  4404
# PericardialCellsIntermediate            4404
# CoronaryVesselAdventitialFibroblasts    3651
# CoronaryPericytes                       2131
# PericardialCellsFibrous                 2018
# CoronarySmoothMuscleCells               1895
# PericardialCellsParietal                1753
# DuctusArteriosusSmoothMuscleCells       1479
# LymphNodeFibroblasticReticularCells     1155
# Name: count, dtype: int64
# /tmp/ipykernel_710009/3873780781.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   xenium_sub.obs['reference_type'] = 'Xenium'
# /tmp/ipykernel_710009/3873780781.py:16: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   ad_concat = xenium_sub.concatenate(scn_sub,
# value_counts of reference type
# reference_type
# Xenium       61655
# scnRNAseq    44910
# Name: count, dtype: int64
#
# ### MyeloidCells ###
# max_n for subsampling per fine-grain: 135
# value_counts of scnRNAseq, per fine-grain
# fine_grain
# MonocytesMPOpos               135
# Monocytes                     135
# MonocyteDerivedCells          135
# MacrophagesCX3CR1pos          135
# MacrophagesTIMD4pos           135
# MacrophagesLYVE1pos           135
# MacrophagesATF3pos            135
# DendriticCellsType1           135
# DendriticCellsMature          135
# PlasmacytoidDendriticCells    135
# MastCells                     135
# Megakaryocytes                135
# Name: count, dtype: int64
# value_counts of reference type
# reference_type
# Xenium       1623
# scnRNAseq    1620
# Name: count, dtype: int64
#
# ### LymphoidCells ###
# /tmp/ipykernel_710009/3873780781.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   xenium_sub.obs['reference_type'] = 'Xenium'
# /tmp/ipykernel_710009/3873780781.py:16: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   ad_concat = xenium_sub.concatenate(scn_sub,
# max_n for subsampling per fine-grain: 39
# value_counts of scnRNAseq, per fine-grain
# fine_grain
# TCellsCD4pos           39
# TCellsCD8pos           39
# TregsCD4pos            39
# ProBCells              39
# BCells                 39
# BCellsMS4A1pos         39
# NaturalKillerCells     39
# InnateLymphoidCells    39
# Name: count, dtype: int64
# value_counts of reference type
# reference_type
# Xenium       313
# scnRNAseq    312
# Name: count, dtype: int64
#
# ### NeuralCells ###
# max_n for subsampling per fine-grain: 313
# /tmp/ipykernel_710009/3873780781.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   xenium_sub.obs['reference_type'] = 'Xenium'
# /tmp/ipykernel_710009/3873780781.py:16: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   ad_concat = xenium_sub.concatenate(scn_sub,
# value_counts of scnRNAseq, per fine-grain
# fine_grain
# NeuronPrecursors          313
# SympatheticNeurons        313
# SchwannCellPrecursors     313
# ParasympatheticNeurons    313
# SchwannCells              313
# ChromaffinCells           228
# Name: count, dtype: int64
# value_counts of reference type
# reference_type
# Xenium       1877
# scnRNAseq    1793
# Name: count, dtype: int64
#
# ### VentricularCardiomyocytes ###
# /tmp/ipykernel_710009/3873780781.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   xenium_sub.obs['reference_type'] = 'Xenium'
# /tmp/ipykernel_710009/3873780781.py:16: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   ad_concat = xenium_sub.concatenate(scn_sub,
# max_n for subsampling per fine-grain: 18362
# value_counts of scnRNAseq, per fine-grain
# fine_grain
# VentricularCardiomyocytesRightCompact         16215
# VentricularCardiomyocytesLeftCompact          15591
# VentricularCardiomyocytesCycling               8195
# VentricularCardiomyocytesLeftTrabeculated      6997
# VentricularCardiomyocytesRightTrabeculated     3101
# VentricularConductionSystemProximal            2209
# VentricularConductionSystemDistal               960
# Name: count, dtype: int64
# /tmp/ipykernel_710009/3873780781.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   xenium_sub.obs['reference_type'] = 'Xenium'
# /tmp/ipykernel_710009/3873780781.py:16: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   ad_concat = xenium_sub.concatenate(scn_sub,
# value_counts of reference type
# reference_type
# Xenium       128532
# scnRNAseq     53268
# Name: count, dtype: int64

# %%
len(adata_ref_list)
# Out:
# 8

# %%
# concatenate
adata_ref = adata_ref_list[0].concatenate(adata_ref_list[1:], 
                                       join='inner', 
                                       batch_key=None,
                                       index_unique=None
                                      )
ctab = pd.crosstab(adata_ref.obs['reference_celltype'],adata_ref.obs['reference_type'])
print(ctab.shape)
ctab
# Out:
# /tmp/ipykernel_710009/3795423091.py:2: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_ref = adata_ref_list[0].concatenate(adata_ref_list[1:],
# (8, 2)
# reference_type             Xenium  scnRNAseq
# reference_celltype
# AtrialCardiomyocytes        39138      18748
# EndothelialCells             3360       3357
# EpicardialCells              3904       3299
# LymphoidCells                 313        312
# MesenchymalCells            61655      44910
# MyeloidCells                 1623       1620
# NeuralCells                  1877       1793
# VentricularCardiomyocytes  128532      53268

# %% [markdown]
# # Save

# %%
import os
os.makedirs(f'{data_object_dir}/TACCO')

# %%
# save
print(adata_ref.X.data[:10])
print(adata_ref.shape)
adata_ref.write(f'{data_object_dir}/TACCO/reference_raw.h5ad')
# Out:
# [1. 1. 1. 3. 1. 5. 2. 1. 1. 2.]
# (367709, 5001)
