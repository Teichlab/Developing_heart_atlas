# %% [markdown]
# ## Import modules

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import scrublet as scr
import session_info

# %%
sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi = 160, color_map = 'RdPu', dpi_save = 180, vector_friendly = True, format = 'svg')
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# matplotlib          3.3.4
# numpy               1.20.1
# pandas              1.1.4
# scanpy              1.7.1
# scrublet            NA
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 8.1.2
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.1
# dateutil            2.8.1
# decorator           4.4.2
# fsspec              0.8.7
# get_version         2.1
# google              NA
# h5py                2.10.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# packaging           20.9
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pyarrow             0.16.0
# pygments            2.8.0
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2021.1
# requests            2.25.1
# ruamel              NA
# scipy               1.6.1
# send2trash          NA
# setuptools_scm      NA
# simplejson          3.17.2
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.22
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# uritemplate         3.0.1
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.1.2
# zmq                 22.0.3
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-112-generic-x86_64-with-glibc2.10
# -----
# Session information updated at 2023-03-14 16:45
# </pre>
# </details>

# %% [markdown]
# ## Functions

# %%
"""Functions for downstream work with outputs of remove-background."""

# to read cellbender outputs<br>
# https://github.com/broadinstitute/CellBender/issues/57

import tables
import numpy as np
import scipy.sparse as sp
from typing import Dict


def dict_from_h5(file: str) -> Dict[str, np.ndarray]:
    """Read in everything from an h5 file and put into a dictionary."""
    d = {}
    with tables.open_file(file) as f:
        # read in everything
        for array in f.walk_nodes("/", "Array"):
            d[array.name] = array.read()
    return d


def anndata_from_h5(file: str,
                    analyzed_barcodes_only: bool = True) -> 'anndata.AnnData':
    """Load an output h5 file into an AnnData object for downstream work.

    Args:
        file: The h5 file
        analyzed_barcodes_only: False to load all barcodes, so that the size of
            the AnnData object will match the size of the input raw count matrix.
            True to load a limited set of barcodes: only those analyzed by the
            algorithm. This allows relevant latent variables to be loaded
            properly into adata.obs and adata.obsm, rather than adata.uns.

    Returns:
        adata: The anndata object, populated with inferred latent variables
            and metadata.

    """

    try:
        import anndata
    except ImportError:
        raise ImportError('The anndata package must be installed to use the '
                          'function anndata_from_h5()')

    d = dict_from_h5(file)
    X = sp.csc_matrix((d.pop('data'), d.pop('indices'), d.pop('indptr')),
                      shape=d.pop('shape')).transpose().tocsr()

    if analyzed_barcodes_only:
        if 'barcodes_analyzed_inds' in d.keys():
            X = X[d['barcodes_analyzed_inds'], :]
            d['barcodes'] = d['barcodes'][d['barcodes_analyzed_inds']]
        elif 'barcode_indices_for_latents' in d.keys():
            X = X[d['barcode_indices_for_latents'], :]
            d['barcodes'] = d['barcodes'][d['barcode_indices_for_latents']]
        else:
            print('Warning: analyzed_barcodes_only=True, but the key '
                  '"barcodes_analyzed_inds" or "barcode_indices_for_latents" '
                  'is missing from the h5 file. '
                  'Will output all barcodes, and proceed as if '
                  'analyzed_barcodes_only=False')

    # Construct the count matrix.
    adata = anndata.AnnData(X=X,
                            obs={'barcode': d.pop('barcodes').astype(str)},
                            var={'gene_name': (d.pop('gene_names') if 'gene_names' in d.keys()
                                               else d.pop('name')).astype(str)})
    adata.obs.set_index('barcode', inplace=True)
    adata.var.set_index('gene_name', inplace=True)

    # Add other information to the adata object in the appropriate slot.
    for key, value in d.items():
        try:
            value = np.asarray(value)
            if len(value.shape) == 0:
                adata.uns[key] = value
            elif value.shape[0] == X.shape[0]:
                if (len(value.shape) < 2) or (value.shape[1] < 2):
                    adata.obs[key] = value
                else:
                    adata.obsm[key] = value
            elif value.shape[0] == X.shape[1]:
                if value.dtype.name.startswith('bytes'):
                    adata.var[key] = value.astype(str)
                else:
                    adata.var[key] = value
            else:
                adata.uns[key] = value
        except Exception:
            print('Unable to load data into AnnData: ', key, value, type(value))

    if analyzed_barcodes_only:
        for col in adata.obs.columns[adata.obs.columns.str.startswith('barcodes_analyzed')
                                     | adata.obs.columns.str.startswith('barcode_indices')]:
            try:
                del adata.obs[col]
            except Exception:
                pass

    return adata

# %%
# from https://github.com/Teichlab/mapcloud/blob/master/scripts/starsolo/postprocess.py

from statsmodels.stats.multitest import multipletests
# from emptydrops.matrix import CountMatrix
# from emptydrops import find_nonambient_barcodes
import scrublet as scr
import scanpy as sc
import pandas as pd
import numpy as np
import scipy

#some functions that Ni uses in scanpy scripts to run scrublet
#which in turn are inspired by my original notebook on the matter
#(extracted from scanpy_scripts 0.2.10 to get around scanpy version incompatibility)
def test_outlier(x, upper_mad_only=True):
	med = np.median(x)
	if upper_mad_only:
		mad = np.median(x[x>med] - med) * 1.4826
	else:
		mad = np.median(np.abs(x - med)) * 1.4826
	pvals = 1 - scipy.stats.norm.cdf(x, loc=med, scale=mad)
	bh_pvals = multipletests(pvals, method='fdr_bh')[1]
	return pvals, bh_pvals

def run_scrublet(adata, resolution_function=None):
	old_verbosity = sc.settings.verbosity
	sc.settings.verbosity = 1
	if resolution_function is None:
		resolution_function = lambda x: np.maximum(np.maximum(np.log10(x)-1, 0)**2, 0.1)
	scrub = scr.Scrublet(adata.X)
	#this has the potential to brick for poor quality data
	#if so, abort it and everything downstream
	try:
		ds, pd = scrub.scrub_doublets(verbose=False)
	except:
		return
	adata.obs['scrublet_score'] = ds

	adata_copy = adata.copy()
	sc.pp.filter_genes(adata_copy, min_cells=3)
	sc.pp.normalize_total(adata_copy, target_sum=1e4)
	sc.pp.log1p(adata_copy)
	sc.pp.highly_variable_genes(adata_copy, min_mean=0.0125, max_mean=3, min_disp=0.5, subset=True)
	sc.pp.scale(adata_copy, zero_center=False)
	sc.pp.pca(adata_copy, svd_solver='arpack', zero_center=False)
	sc.pp.neighbors(adata_copy, n_pcs=30)
	sc.tl.umap(adata_copy)
	sc.tl.leiden(adata_copy, resolution=1)
	for clst in np.unique(adata_copy.obs['leiden']):
		clst_size = sum(adata_copy.obs['leiden'] == clst)
		sc.tl.leiden(adata_copy, restrict_to=('leiden', [clst]), resolution=resolution_function(clst_size), key_added='leiden_R')
		adata_copy.obs['leiden'] = adata_copy.obs['leiden_R']
	clst_meds = []
	for clst in np.unique(adata_copy.obs['leiden']):
		k = adata_copy.obs['leiden'] == clst
		clst_med = np.median(adata_copy.obs.loc[k, 'scrublet_score'])
		adata_copy.obs.loc[k, 'cluster_scrublet_score'] = clst_med
		clst_meds.append(clst_med)
	clst_meds = np.array(clst_meds)
	pvals, bh_pvals = test_outlier(clst_meds)
	for i, clst in enumerate(np.unique(adata_copy.obs['leiden'])):
		k = adata_copy.obs['leiden'] == clst
		adata_copy.obs.loc[k, 'pval'] = pvals[i]
		adata_copy.obs.loc[k, 'bh_pval'] = bh_pvals[i]
	sc.settings.verbosity = old_verbosity
	#need to also export the clustering, for soupx purposes
	adata.obs['scrublet_leiden'] = adata_copy.obs['leiden']
	adata.obs['scrublet_score'] = adata_copy.obs['scrublet_score']
	adata.obs['cluster_scrublet_score'] = adata_copy.obs['cluster_scrublet_score']
	adata.obs['doublet_pval'] = adata_copy.obs['pval']
	adata.obs['doublet_bh_pval'] = adata_copy.obs['bh_pval']
	del adata_copy

# %% [markdown]
# ## Create anndata object

# %%
# read in metadata
metadata = pd.read_csv('/nfs/team205/heart/anndata_objects/Foetal/metadata/HeartTeamSamples_Mappeddata_20230314.csv', sep = ',', index_col = None)
metadata = metadata[metadata['Publication']=='Foetal']

# select healthy data
metadata = metadata[metadata['status']=='Trisomy21']


print(metadata['modality'].value_counts())
# Out:
# Multiome-ATAC    8
# Multiome-RNA     8
# Visium           4
# Name: modality, dtype: int64

# %%
# select modality
metadata = metadata[metadata['modality']=='Multiome-RNA']
metadata[['sangerID','combinedID', 'donor', 'donor_type', 'region', 'region_finest', 'age',
                'gender', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x','flushed']]
# Out:
#               sangerID                           combinedID  donor donor_type  \
# 492  BHF_F_Hea13188319  BHF_F_Hea13188319_BHF_F_Hea13187621  Hst42         na
# 493  BHF_F_Hea13188320  BHF_F_Hea13188320_BHF_F_Hea13187622  Hst42         na
# 494  BHF_F_Hea13188321  BHF_F_Hea13188321_BHF_F_Hea13187623  Hst42         na
# 495  BHF_F_Hea13188322  BHF_F_Hea13188322_BHF_F_Hea13187624  Hst42         na
# 496  BHF_F_Hea13188323  BHF_F_Hea13188323_BHF_F_Hea13187625  Hst42         na
# 498  BHF_F_Hea13188325  BHF_F_Hea13188325_BHF_F_Hea13187627  Hst44         na
# 499  BHF_F_Hea13188326  BHF_F_Hea13188326_BHF_F_Hea13187628  Hst44         na
# 500  BHF_F_Hea13188327  BHF_F_Hea13188327_BHF_F_Hea13187629  Hst44         na
#
#               region    region_finest      age gender facility cell_or_nuclei  \
# 492      Pericardium      Pericardium  PCW-14w     na   Sanger         Nuclei
# 493    Great vessels    Great vessels  PCW-14w     na   Sanger         Nuclei
# 494       Left atria       Left atria  PCW-14w     na   Sanger         Nuclei
# 495   Left ventricle   Left ventricle  PCW-14w     na   Sanger         Nuclei
# 496  Right ventricle  Right ventricle  PCW-14w     na   Sanger         Nuclei
# 498            Heart            Heart  PCW-13w     na   Sanger         Nuclei
# 499            Heart            Heart  PCW-13w     na   Sanger         Nuclei
# 500            Heart            Heart  PCW-13w     na   Sanger         Nuclei
#
#          modality      kit_10x flushed
# 492  Multiome-RNA  Multiome-v1      na
# 493  Multiome-RNA  Multiome-v1      na
# 494  Multiome-RNA  Multiome-v1      na
# 495  Multiome-RNA  Multiome-v1      na
# 496  Multiome-RNA  Multiome-v1      na
# 498  Multiome-RNA  Multiome-v1      na
# 499  Multiome-RNA  Multiome-v1      na
# 500  Multiome-RNA  Multiome-v1      na

# %%
########### editted: put id to var_names ###########

# read in
adatas=[]
for i in range(len(metadata)):
    print(metadata.iloc[i]['combinedID'])
    
    path=metadata.iloc[i]['CellBender_out']
    adatas.append(anndata_from_h5(path + '/' + path.split('/')[-1] + '_cellbender_out_filtered.h5', analyzed_barcodes_only=False))
    del path
    
    # replace var_names with ensembleID
    adatas[i].var.reset_index(inplace=True)
    if 'id' in adatas[i].var.columns:
        adatas[i].var.set_index('id',inplace=True)
    else:
        adatas[i].var.set_index('genes',inplace=True)
    
    # modify barcodes
    adatas[i].obs.index = metadata.iloc[i]['combinedID'] + '_' + adatas[i].obs.index 
    
    # add metadata
    for col in ['sangerID','combinedID', 'donor', 'donor_type', 'region', 'region_finest', 'age',
                'gender', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x','flushed']:
        adatas[i].obs[col] = metadata.iloc[i][col]


# concatenate
adata = adatas[0].concatenate(adatas[1:], index_unique = None, batch_key=None)
adata.shape
# Out:
# BHF_F_Hea13188319_BHF_F_Hea13187621
# BHF_F_Hea13188320_BHF_F_Hea13187622
# BHF_F_Hea13188321_BHF_F_Hea13187623
# BHF_F_Hea13188322_BHF_F_Hea13187624
# BHF_F_Hea13188323_BHF_F_Hea13187625
# BHF_F_Hea13188325_BHF_F_Hea13187627
# BHF_F_Hea13188326_BHF_F_Hea13187628
# BHF_F_Hea13188327_BHF_F_Hea13187629
# (190750, 36601)

# %%
for i in range(len(adatas)):
    print(adatas[i].var.columns)
# Out:
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')

# %%
adata.obs['combinedID'].value_counts()
# Out:
# BHF_F_Hea13188319_BHF_F_Hea13187621    50000
# BHF_F_Hea13188321_BHF_F_Hea13187623    38944
# BHF_F_Hea13188325_BHF_F_Hea13187627    23862
# BHF_F_Hea13188322_BHF_F_Hea13187624    17452
# BHF_F_Hea13188323_BHF_F_Hea13187625    17143
# BHF_F_Hea13188327_BHF_F_Hea13187629    16377
# BHF_F_Hea13188320_BHF_F_Hea13187622    14000
# BHF_F_Hea13188326_BHF_F_Hea13187628    12972
# Name: combinedID, dtype: int64

# %% [markdown]
# ## Run scrublet

# %%
# %%time

# per rxn
for i,ID in enumerate(adata.obs['combinedID'].unique()):
    print(ID)
    
    ad = adata[adata.obs['combinedID'] == ID].copy()
    run_scrublet(ad)
    if i==0:
        meta = ad.obs
    else:
        meta = pd.concat([meta, ad.obs])
    del ad
# Out:
# BHF_F_Hea13188319_BHF_F_Hea13187621
# BHF_F_Hea13188320_BHF_F_Hea13187622
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188321_BHF_F_Hea13187623
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188322_BHF_F_Hea13187624
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188323_BHF_F_Hea13187625
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188325_BHF_F_Hea13187627
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188326_BHF_F_Hea13187628
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188327_BHF_F_Hea13187629
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# CPU times: user 38min 57s, sys: 18min 16s, total: 57min 13s
# Wall time: 17min 13s

# %%
meta_scrub = meta[['scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval']].copy()
meta_scrub.shape
# Out:
# (190750, 5)

# %%
if meta_scrub.reindex(adata.obs.index).index.equals(adata.obs.index):
    adata.obs = pd.concat([adata.obs, meta_scrub.reindex(adata.obs.index)], axis=1)
else:
    raise Exception('Different barcodes in meta and adata')

# %%
adata.obs
# Out:
#                                                     latent_RT_efficiency  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...              3.323048
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...              3.279344
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...              3.230674
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...              3.286734
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...              3.200592
# ...                                                                  ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...              0.171034
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...              0.480254
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...              0.423560
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...              0.490171
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...              0.443100
#
#                                                     latent_cell_probability  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...                 1.000000
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...                 1.000000
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...                 1.000000
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...                 1.000000
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...                 1.000000
# ...                                                                     ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...                 0.833258
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...                 0.785225
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...                 0.828406
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...                 0.616162
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...                 0.764521
#
#                                                     latent_scale  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...  41678.355469
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...  41784.378906
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...  39091.187500
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...  39290.058594
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...  33462.207031
# ...                                                          ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...  13162.705078
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...   9918.803711
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...  10536.883789
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...   7934.595703
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...   9360.880859
#
#                                                              sangerID  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...  BHF_F_Hea13188319
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...  BHF_F_Hea13188319
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...  BHF_F_Hea13188319
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...  BHF_F_Hea13188319
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...  BHF_F_Hea13188319
# ...                                                               ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...  BHF_F_Hea13188327
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...  BHF_F_Hea13188327
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...  BHF_F_Hea13188327
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...  BHF_F_Hea13188327
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...  BHF_F_Hea13188327
#
#                                                                              combinedID  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...  BHF_F_Hea13188319_BHF_F_Hea13187621
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...  BHF_F_Hea13188319_BHF_F_Hea13187621
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...  BHF_F_Hea13188319_BHF_F_Hea13187621
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...  BHF_F_Hea13188319_BHF_F_Hea13187621
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...  BHF_F_Hea13188319_BHF_F_Hea13187621
# ...                                                                                 ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...  BHF_F_Hea13188327_BHF_F_Hea13187629
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...  BHF_F_Hea13188327_BHF_F_Hea13187629
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...  BHF_F_Hea13188327_BHF_F_Hea13187629
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...  BHF_F_Hea13188327_BHF_F_Hea13187629
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...  BHF_F_Hea13188327_BHF_F_Hea13187629
#
#                                                     donor donor_type  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...  Hst42         na
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...  Hst42         na
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...  Hst42         na
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...  Hst42         na
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...  Hst42         na
# ...                                                   ...        ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...  Hst44         na
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...  Hst44         na
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...  Hst44         na
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...  Hst44         na
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...  Hst44         na
#
#                                                          region region_finest  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...  Pericardium   Pericardium
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...  Pericardium   Pericardium
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...  Pericardium   Pericardium
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...  Pericardium   Pericardium
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...  Pericardium   Pericardium
# ...                                                         ...           ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...        Heart         Heart
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...        Heart         Heart
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...        Heart         Heart
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...        Heart         Heart
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...        Heart         Heart
#
#                                                         age  ... facility  \
# barcode                                                      ...
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...  PCW-14w  ...   Sanger
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...  PCW-14w  ...   Sanger
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...  PCW-14w  ...   Sanger
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...  PCW-14w  ...   Sanger
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...  PCW-14w  ...   Sanger
# ...                                                     ...  ...      ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...  PCW-13w  ...   Sanger
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...  PCW-13w  ...   Sanger
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...  PCW-13w  ...   Sanger
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...  PCW-13w  ...   Sanger
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...  PCW-13w  ...   Sanger
#
#                                                    cell_or_nuclei  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...         Nuclei
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...         Nuclei
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...         Nuclei
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...         Nuclei
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...         Nuclei
# ...                                                           ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...         Nuclei
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...         Nuclei
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...         Nuclei
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...         Nuclei
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...         Nuclei
#
#                                                         modality      kit_10x  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...  Multiome-RNA  Multiome-v1
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...  Multiome-RNA  Multiome-v1
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...  Multiome-RNA  Multiome-v1
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...  Multiome-RNA  Multiome-v1
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...  Multiome-RNA  Multiome-v1
# ...                                                          ...          ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...  Multiome-RNA  Multiome-v1
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...  Multiome-RNA  Multiome-v1
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...  Multiome-RNA  Multiome-v1
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...  Multiome-RNA  Multiome-v1
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...  Multiome-RNA  Multiome-v1
#
#                                                    flushed scrublet_score  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...      na       0.230024
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...      na       0.211480
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...      na       0.208054
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...      na       0.140000
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...      na       0.246798
# ...                                                    ...            ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...      na       0.141188
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...      na       0.026022
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...      na       0.070529
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...      na       0.015574
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...      na       0.030408
#
#                                                     scrublet_leiden  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...              8,3
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...              8,3
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...              8,3
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...             15,5
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...              8,3
# ...                                                             ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...              9,9
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...             15,3
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...              0,7
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...             9,11
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...             28,0
#
#                                                    cluster_scrublet_score  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...               0.255937
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...               0.255937
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...               0.255937
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...               0.147806
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...               0.255937
# ...                                                                   ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...               0.006345
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...               0.069216
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...               0.052632
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...               0.022868
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...               0.025431
#
#                                                     doublet_pval  \
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...      0.027970
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...      0.027970
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...      0.027970
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...      0.332187
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...      0.027970
# ...                                                          ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...      0.891491
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...      0.488795
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...      0.619804
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...      0.816651
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...      0.802676
#
#                                                     doublet_bh_pval
# barcode
# BHF_F_Hea13188319_BHF_F_Hea13187621_GGGCATTGTCA...         0.889341
# BHF_F_Hea13188319_BHF_F_Hea13187621_ATATGCTCAAT...         0.889341
# BHF_F_Hea13188319_BHF_F_Hea13187621_GCTGGATGTAC...         0.889341
# BHF_F_Hea13188319_BHF_F_Hea13187621_TAAGGACCATG...         0.889341
# BHF_F_Hea13188319_BHF_F_Hea13187621_TTATCCTAGCT...         0.889341
# ...                                                             ...
# BHF_F_Hea13188327_BHF_F_Hea13187629_ACCTACCTCTT...         0.895322
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCACTAAGTGA...         0.875967
# BHF_F_Hea13188327_BHF_F_Hea13187629_GCTGGATGTGC...         0.875967
# BHF_F_Hea13188327_BHF_F_Hea13187629_CTTAACAAGCT...         0.875967
# BHF_F_Hea13188327_BHF_F_Hea13187629_TTGCTTTAGGT...         0.875967
#
# [190750 rows x 21 columns]

# %% [markdown]
# ## Save

# %%
adata.write('/nfs/team205/heart/anndata_objects/Foetal/QC/T21_multiome_RNA_foetal_prefilter.h5ad')
# Out:
# ... storing 'sangerID' as categorical
# ... storing 'combinedID' as categorical
# ... storing 'donor' as categorical
# ... storing 'donor_type' as categorical
# ... storing 'region' as categorical
# ... storing 'region_finest' as categorical
# ... storing 'age' as categorical
# ... storing 'gender' as categorical
# ... storing 'facility' as categorical
# ... storing 'cell_or_nuclei' as categorical
# ... storing 'modality' as categorical
# ... storing 'kit_10x' as categorical
# ... storing 'flushed' as categorical
# ... storing 'scrublet_leiden' as categorical
# ... storing 'gene_name' as categorical
# ... storing 'feature_type' as categorical

# %%
sc.pl.violin(adata,
             ['scrublet_score', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval'],jitter = 0, multi_panel = True)

# %%
adata.obs['donor'].value_counts()
# Out:
# Hst42    137539
# Hst44     53211
# Name: donor, dtype: int64
