# %% [markdown]
# ## Import modules

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import scrublet as scr
import session_info

# %%
sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi = 160, color_map = 'RdPu', dpi_save = 180, vector_friendly = True, format = 'svg')
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# matplotlib          3.3.4
# numpy               1.20.1
# pandas              1.1.4
# scanpy              1.7.1
# scipy               1.6.1
# scrublet            NA
# session_info        1.0.0
# statsmodels         0.12.2
# tables              3.6.1
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 8.1.2
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.1
# dateutil            2.8.1
# decorator           4.4.2
# fsspec              0.8.7
# get_version         2.1
# google              NA
# h5py                2.10.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# packaging           20.9
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pyarrow             0.16.0
# pygments            2.8.0
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2021.1
# requests            2.25.1
# ruamel              NA
# send2trash          NA
# setuptools_scm      NA
# simplejson          3.17.2
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.22
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# storemagic          NA
# tblib               1.7.0
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# uritemplate         3.0.1
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.1.2
# zmq                 22.0.3
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-112-generic-x86_64-with-glibc2.10
# -----
# Session information updated at 2023-02-08 21:30
# </pre>
# </details>

# %% [markdown]
# ## Functions

# %%
"""Functions for downstream work with outputs of remove-background."""

# to read cellbender outputs<br>
# https://github.com/broadinstitute/CellBender/issues/57

import tables
import numpy as np
import scipy.sparse as sp
from typing import Dict


def dict_from_h5(file: str) -> Dict[str, np.ndarray]:
    """Read in everything from an h5 file and put into a dictionary."""
    d = {}
    with tables.open_file(file) as f:
        # read in everything
        for array in f.walk_nodes("/", "Array"):
            d[array.name] = array.read()
    return d


def anndata_from_h5(file: str,
                    analyzed_barcodes_only: bool = True) -> 'anndata.AnnData':
    """Load an output h5 file into an AnnData object for downstream work.

    Args:
        file: The h5 file
        analyzed_barcodes_only: False to load all barcodes, so that the size of
            the AnnData object will match the size of the input raw count matrix.
            True to load a limited set of barcodes: only those analyzed by the
            algorithm. This allows relevant latent variables to be loaded
            properly into adata.obs and adata.obsm, rather than adata.uns.

    Returns:
        adata: The anndata object, populated with inferred latent variables
            and metadata.

    """

    try:
        import anndata
    except ImportError:
        raise ImportError('The anndata package must be installed to use the '
                          'function anndata_from_h5()')

    d = dict_from_h5(file)
    X = sp.csc_matrix((d.pop('data'), d.pop('indices'), d.pop('indptr')),
                      shape=d.pop('shape')).transpose().tocsr()

    if analyzed_barcodes_only:
        if 'barcodes_analyzed_inds' in d.keys():
            X = X[d['barcodes_analyzed_inds'], :]
            d['barcodes'] = d['barcodes'][d['barcodes_analyzed_inds']]
        elif 'barcode_indices_for_latents' in d.keys():
            X = X[d['barcode_indices_for_latents'], :]
            d['barcodes'] = d['barcodes'][d['barcode_indices_for_latents']]
        else:
            print('Warning: analyzed_barcodes_only=True, but the key '
                  '"barcodes_analyzed_inds" or "barcode_indices_for_latents" '
                  'is missing from the h5 file. '
                  'Will output all barcodes, and proceed as if '
                  'analyzed_barcodes_only=False')

    # Construct the count matrix.
    adata = anndata.AnnData(X=X,
                            obs={'barcode': d.pop('barcodes').astype(str)},
                            var={'gene_name': (d.pop('gene_names') if 'gene_names' in d.keys()
                                               else d.pop('name')).astype(str)})
    adata.obs.set_index('barcode', inplace=True)
    adata.var.set_index('gene_name', inplace=True)

    # Add other information to the adata object in the appropriate slot.
    for key, value in d.items():
        try:
            value = np.asarray(value)
            if len(value.shape) == 0:
                adata.uns[key] = value
            elif value.shape[0] == X.shape[0]:
                if (len(value.shape) < 2) or (value.shape[1] < 2):
                    adata.obs[key] = value
                else:
                    adata.obsm[key] = value
            elif value.shape[0] == X.shape[1]:
                if value.dtype.name.startswith('bytes'):
                    adata.var[key] = value.astype(str)
                else:
                    adata.var[key] = value
            else:
                adata.uns[key] = value
        except Exception:
            print('Unable to load data into AnnData: ', key, value, type(value))

    if analyzed_barcodes_only:
        for col in adata.obs.columns[adata.obs.columns.str.startswith('barcodes_analyzed')
                                     | adata.obs.columns.str.startswith('barcode_indices')]:
            try:
                del adata.obs[col]
            except Exception:
                pass

    return adata

# %%
# from https://github.com/Teichlab/mapcloud/blob/master/scripts/starsolo/postprocess.py

from statsmodels.stats.multitest import multipletests
# from emptydrops.matrix import CountMatrix
# from emptydrops import find_nonambient_barcodes
import scrublet as scr
import scanpy as sc
import pandas as pd
import numpy as np
import scipy

#some functions that Ni uses in scanpy scripts to run scrublet
#which in turn are inspired by my original notebook on the matter
#(extracted from scanpy_scripts 0.2.10 to get around scanpy version incompatibility)
def test_outlier(x, upper_mad_only=True):
	med = np.median(x)
	if upper_mad_only:
		mad = np.median(x[x>med] - med) * 1.4826
	else:
		mad = np.median(np.abs(x - med)) * 1.4826
	pvals = 1 - scipy.stats.norm.cdf(x, loc=med, scale=mad)
	bh_pvals = multipletests(pvals, method='fdr_bh')[1]
	return pvals, bh_pvals

def run_scrublet(adata, resolution_function=None):
	old_verbosity = sc.settings.verbosity
	sc.settings.verbosity = 1
	if resolution_function is None:
		resolution_function = lambda x: np.maximum(np.maximum(np.log10(x)-1, 0)**2, 0.1)
	scrub = scr.Scrublet(adata.X)
	#this has the potential to brick for poor quality data
	#if so, abort it and everything downstream
	try:
		ds, pd = scrub.scrub_doublets(verbose=False)
	except:
		return
	adata.obs['scrublet_score'] = ds

	adata_copy = adata.copy()
	sc.pp.filter_genes(adata_copy, min_cells=3)
	sc.pp.normalize_total(adata_copy, target_sum=1e4)
	sc.pp.log1p(adata_copy)
	sc.pp.highly_variable_genes(adata_copy, min_mean=0.0125, max_mean=3, min_disp=0.5, subset=True)
	sc.pp.scale(adata_copy, zero_center=False)
	sc.pp.pca(adata_copy, svd_solver='arpack', zero_center=False)
	sc.pp.neighbors(adata_copy, n_pcs=30)
	sc.tl.umap(adata_copy)
	sc.tl.leiden(adata_copy, resolution=1)
	for clst in np.unique(adata_copy.obs['leiden']):
		clst_size = sum(adata_copy.obs['leiden'] == clst)
		sc.tl.leiden(adata_copy, restrict_to=('leiden', [clst]), resolution=resolution_function(clst_size), key_added='leiden_R')
		adata_copy.obs['leiden'] = adata_copy.obs['leiden_R']
	clst_meds = []
	for clst in np.unique(adata_copy.obs['leiden']):
		k = adata_copy.obs['leiden'] == clst
		clst_med = np.median(adata_copy.obs.loc[k, 'scrublet_score'])
		adata_copy.obs.loc[k, 'cluster_scrublet_score'] = clst_med
		clst_meds.append(clst_med)
	clst_meds = np.array(clst_meds)
	pvals, bh_pvals = test_outlier(clst_meds)
	for i, clst in enumerate(np.unique(adata_copy.obs['leiden'])):
		k = adata_copy.obs['leiden'] == clst
		adata_copy.obs.loc[k, 'pval'] = pvals[i]
		adata_copy.obs.loc[k, 'bh_pval'] = bh_pvals[i]
	sc.settings.verbosity = old_verbosity
	#need to also export the clustering, for soupx purposes
	adata.obs['scrublet_leiden'] = adata_copy.obs['leiden']
	adata.obs['scrublet_score'] = adata_copy.obs['scrublet_score']
	adata.obs['cluster_scrublet_score'] = adata_copy.obs['cluster_scrublet_score']
	adata.obs['doublet_pval'] = adata_copy.obs['pval']
	adata.obs['doublet_bh_pval'] = adata_copy.obs['bh_pval']
	del adata_copy

# %% [markdown]
# ## Create anndata object

# %%
# read in metadata
metadata = pd.read_csv('/nfs/team205/heart/anndata_objects/Foetal/metadata/HeartTeamSamples_Mappeddata_20230208.csv', sep = ',', index_col = None)
metadata = metadata[metadata['Publication']=='Foetal']

# select healthy data
metadata = metadata[metadata['status']=='Healthy']


print(metadata['modality'].value_counts())
# Out:
# Multiome-RNA     40
# Multiome-ATAC    40
# Visium           23
# scRNA            20
# Visium-FFPE       2
# Name: modality, dtype: int64

# %%
# select modality
metadata = metadata[metadata['modality']=='Multiome-RNA']

# %%
########### editted: put id to var_names ###########

# read in
adatas=[]
for i in range(len(metadata)):
    print(metadata.iloc[i]['combinedID'])
    
    path=metadata.iloc[i]['CellBender_out']
    adatas.append(anndata_from_h5(path + '/' + path.split('/')[-1] + '_cellbender_out_filtered.h5', analyzed_barcodes_only=False))
    del path
    
    # replace var_names with ensembleID
    adatas[i].var.reset_index(inplace=True)
    if 'id' in adatas[i].var.columns:
        adatas[i].var.set_index('id',inplace=True)
    else:
        adatas[i].var.set_index('genes',inplace=True)
    
    # modify barcodes
    adatas[i].obs.index = metadata.iloc[i]['combinedID'] + '_' + adatas[i].obs.index 
    
    # add metadata
    for col in ['sangerID','combinedID', 'donor', 'donor_type', 'region', 'region_finest', 'age',
                'gender', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x','flushed']:
        adatas[i].obs[col] = metadata.iloc[i][col]


# concatenate
adata = adatas[0].concatenate(adatas[1:], index_unique = None, batch_key=None)
adata.shape
# Out:
# BHF_F_Hea11064670_BHF_F_Hea11031823
# BHF_F_Hea11064671_BHF_F_Hea11031824
# BHF_F_Hea11064672_BHF_F_Hea11031825
# BHF_F_Hea11933664_BHF_F_Hea11596617
# BHF_F_Hea11933665_BHF_F_Hea11596618
# BHF_F_Hea11933666_BHF_F_Hea11596619
# BHF_F_Hea11933667_BHF_F_Hea11596620
# BHF_F_Hea11933668_BHF_F_Hea11596621
# BHF_F_Hea11933669_BHF_F_Hea11596622
# BHF_F_Hea11933670_BHF_F_Hea11596623
# BHF_F_Hea11933671_BHF_F_Hea11596624
# BHF_F_Hea11933672_BHF_F_Hea11596625
# BHF_F_Hea11933673_BHF_F_Hea11596626
# BHF_F_Hea11933674_BHF_F_Hea11596627
# BHF_F_Hea11933675_BHF_F_Hea11596628
# BHF_F_Hea13188316_BHF_F_Hea13187618
# BHF_F_Hea13188317_BHF_F_Hea13187619
# BHF_F_Hea13188318_BHF_F_Hea13187620
# BHF_F_Hea13188324_BHF_F_Hea13187626
# BHF_F_Hea13188328_BHF_F_Hea13187630
# BHF_F_Hea13188329_BHF_F_Hea13187631
# BHF_F_Hea13188330_BHF_F_Hea13187632
# BHF_F_Hea13168892_BHF_F_Hea13168508
# BHF_F_Hea13168893_BHF_F_Hea13168509
# BHF_F_Hea13168894_BHF_F_Hea13168510
# BHF_F_Hea13168895_BHF_F_Hea13168511
# BHF_F_Hea13168896_BHF_F_Hea13168512
# BHF_F_Hea13168897_BHF_F_Hea13168513
# BHF_F_Hea13168898_BHF_F_Hea13168514
# BHF_F_Hea13168899_BHF_F_Hea13168515
# 7089STDY13216920_BHF_F_Hea13242527
# 7089STDY13216921_BHF_F_Hea13242528
# 7089STDY13216922_BHF_F_Hea13242529
# 7089STDY13216923_BHF_F_Hea13242530
# 7089STDY13216924_BHF_F_Hea13242531
# 7089STDY13216925_BHF_F_Hea13242532
# 7089STDY13216926_BHF_F_Hea13242533
# 7089STDY13216927_BHF_F_Hea13242534
# HCAHeartST13386009_HCAHeartST13303419
# HCAHeartST13386010_HCAHeartST13303420
# (721979, 36601)

# %%
for i in range(len(adatas)):
    print(adatas[i].var.columns)
# Out:
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')
# Index(['gene_name', 'ambient_expression', 'feature_type'], dtype='object')

# %%
adata.obs['combinedID'].value_counts()
# Out:
# BHF_F_Hea13188316_BHF_F_Hea13187618      59866
# 7089STDY13216924_BHF_F_Hea13242531       40000
# BHF_F_Hea11933665_BHF_F_Hea11596618      33997
# 7089STDY13216925_BHF_F_Hea13242532       30453
# BHF_F_Hea13188318_BHF_F_Hea13187620      27856
# 7089STDY13216920_BHF_F_Hea13242527       27498
# BHF_F_Hea13168898_BHF_F_Hea13168514      24781
# 7089STDY13216927_BHF_F_Hea13242534       24666
# 7089STDY13216926_BHF_F_Hea13242533       24602
# BHF_F_Hea13188324_BHF_F_Hea13187626      24381
# 7089STDY13216921_BHF_F_Hea13242528       24211
# BHF_F_Hea13168896_BHF_F_Hea13168512      22267
# HCAHeartST13386009_HCAHeartST13303419    21577
# BHF_F_Hea11933666_BHF_F_Hea11596619      21509
# BHF_F_Hea13168899_BHF_F_Hea13168515      21418
# 7089STDY13216922_BHF_F_Hea13242529       21402
# BHF_F_Hea13188317_BHF_F_Hea13187619      21327
# BHF_F_Hea11933664_BHF_F_Hea11596617      20338
# BHF_F_Hea11933667_BHF_F_Hea11596620      19811
# BHF_F_Hea13168894_BHF_F_Hea13168510      19258
# BHF_F_Hea11933669_BHF_F_Hea11596622      19029
# BHF_F_Hea13168897_BHF_F_Hea13168513      18609
# HCAHeartST13386010_HCAHeartST13303420    18350
# BHF_F_Hea13168895_BHF_F_Hea13168511      18315
# BHF_F_Hea11933668_BHF_F_Hea11596621      17494
# BHF_F_Hea13168893_BHF_F_Hea13168509      11782
# BHF_F_Hea11933670_BHF_F_Hea11596623      11068
# BHF_F_Hea11933673_BHF_F_Hea11596626      10769
# BHF_F_Hea11933671_BHF_F_Hea11596624      10256
# BHF_F_Hea11064672_BHF_F_Hea11031825      10191
# BHF_F_Hea13168892_BHF_F_Hea13168508      10023
# BHF_F_Hea11933672_BHF_F_Hea11596625       9711
# BHF_F_Hea11933674_BHF_F_Hea11596627       6199
# BHF_F_Hea13188328_BHF_F_Hea13187630       5340
# BHF_F_Hea11064671_BHF_F_Hea11031824       4757
# BHF_F_Hea11064670_BHF_F_Hea11031823       2665
# BHF_F_Hea13188329_BHF_F_Hea13187631       1878
# 7089STDY13216923_BHF_F_Hea13242530        1873
# BHF_F_Hea13188330_BHF_F_Hea13187632       1750
# BHF_F_Hea11933675_BHF_F_Hea11596628        702
# Name: combinedID, dtype: int64

# %% [markdown]
# ## Run scrublet

# %%
# %%time

# per rxn
for i,ID in enumerate(adata.obs['combinedID'].unique()):
    print(ID)
    
    ad = adata[adata.obs['combinedID'] == ID].copy()
    run_scrublet(ad)
    if i==0:
        meta = ad.obs
    else:
        meta = pd.concat([meta, ad.obs])
    del ad
# Out:
# BHF_F_Hea11064670_BHF_F_Hea11031823
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11064671_BHF_F_Hea11031824
# BHF_F_Hea11064672_BHF_F_Hea11031825
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933664_BHF_F_Hea11596617
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933665_BHF_F_Hea11596618
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933666_BHF_F_Hea11596619
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933667_BHF_F_Hea11596620
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933668_BHF_F_Hea11596621
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933669_BHF_F_Hea11596622
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933670_BHF_F_Hea11596623
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933671_BHF_F_Hea11596624
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933672_BHF_F_Hea11596625
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933673_BHF_F_Hea11596626
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933674_BHF_F_Hea11596627
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea11933675_BHF_F_Hea11596628
# BHF_F_Hea13188316_BHF_F_Hea13187618
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188317_BHF_F_Hea13187619
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188318_BHF_F_Hea13187620
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188324_BHF_F_Hea13187626
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188328_BHF_F_Hea13187630
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188329_BHF_F_Hea13187631
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13188330_BHF_F_Hea13187632
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13168892_BHF_F_Hea13168508
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13168893_BHF_F_Hea13168509
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13168894_BHF_F_Hea13168510
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13168895_BHF_F_Hea13168511
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13168896_BHF_F_Hea13168512
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13168897_BHF_F_Hea13168513
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13168898_BHF_F_Hea13168514
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# BHF_F_Hea13168899_BHF_F_Hea13168515
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# 7089STDY13216920_BHF_F_Hea13242527
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# 7089STDY13216921_BHF_F_Hea13242528
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# 7089STDY13216922_BHF_F_Hea13242529
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# 7089STDY13216923_BHF_F_Hea13242530
# 7089STDY13216924_BHF_F_Hea13242531
# 7089STDY13216925_BHF_F_Hea13242532
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# 7089STDY13216926_BHF_F_Hea13242533
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# 7089STDY13216927_BHF_F_Hea13242534
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13386009_HCAHeartST13303419
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13386010_HCAHeartST13303420
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# CPU times: user 2h 18min 29s, sys: 1h 16min 7s, total: 3h 34min 36s
# Wall time: 59min 16s

# %%
meta_scrub = meta[['scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval']].copy()
meta_scrub.shape
# Out:
# (721979, 5)

# %%
if meta_scrub.reindex(adata.obs.index).index.equals(adata.obs.index):
    adata.obs = pd.concat([adata.obs, meta_scrub.reindex(adata.obs.index)], axis=1)
else:
    raise Exception('Different barcodes in meta and adata')

# %%
adata.obs
# Out:
#                                                     latent_RT_efficiency  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...              8.281664
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...              7.750196
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...              7.196345
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...              7.661210
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...              7.444614
# ...                                                                  ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...              0.391199
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...              0.410119
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...              0.268203
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...              0.432260
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...              0.613591
#
#                                                     latent_cell_probability  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...                 0.506006
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...                 0.986125
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...                 0.999430
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...                 0.988581
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...                 0.997983
# ...                                                                     ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...                 0.903360
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...                 0.541073
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...                 0.872349
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...                 0.593111
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...                 0.974390
#
#                                                     latent_scale  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...   2320.444580
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...   3909.921875
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...   4387.478027
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...   3705.300781
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...   3762.943604
# ...                                                          ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...   6694.860352
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...   6675.453125
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...   7308.047363
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...   9477.296875
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...   6887.774902
#
#                                                               sangerID  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...   BHF_F_Hea11064670
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...   BHF_F_Hea11064670
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...   BHF_F_Hea11064670
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...   BHF_F_Hea11064670
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...   BHF_F_Hea11064670
# ...                                                                ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...  HCAHeartST13386010
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...  HCAHeartST13386010
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...  HCAHeartST13386010
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...  HCAHeartST13386010
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...  HCAHeartST13386010
#
#                                                                                combinedID  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...    BHF_F_Hea11064670_BHF_F_Hea11031823
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...    BHF_F_Hea11064670_BHF_F_Hea11031823
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...    BHF_F_Hea11064670_BHF_F_Hea11031823
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...    BHF_F_Hea11064670_BHF_F_Hea11031823
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...    BHF_F_Hea11064670_BHF_F_Hea11031823
# ...                                                                                   ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...  HCAHeartST13386010_HCAHeartST13303420
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...  HCAHeartST13386010_HCAHeartST13303420
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...  HCAHeartST13386010_HCAHeartST13303420
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...  HCAHeartST13386010_HCAHeartST13303420
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...  HCAHeartST13386010_HCAHeartST13303420
#
#                                                     donor donor_type region  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...    C82         na  Heart
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...    C82         na  Heart
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...    C82         na  Heart
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...    C82         na  Heart
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...    C82         na  Heart
# ...                                                   ...        ...    ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...  Hst41         na     RV
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...  Hst41         na     RV
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...  Hst41         na     RV
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...  Hst41         na     RV
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...  Hst41         na     RV
#
#                                                                     region_finest  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...                          Heart
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...                          Heart
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...                          Heart
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...                          Heart
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...                          Heart
# ...                                                                           ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...  RV (pool of RV, ModB samples)
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...  RV (pool of RV, ModB samples)
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...  RV (pool of RV, ModB samples)
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...  RV (pool of RV, ModB samples)
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...  RV (pool of RV, ModB samples)
#
#                                                          age  ... facility  \
# barcode                                                       ...
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...  GA-11w3d  ...   Sanger
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...  GA-11w3d  ...   Sanger
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...  GA-11w3d  ...   Sanger
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...  GA-11w3d  ...   Sanger
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...  GA-11w3d  ...   Sanger
# ...                                                      ...  ...      ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...   PCW-20w  ...   Sanger
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...   PCW-20w  ...   Sanger
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...   PCW-20w  ...   Sanger
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...   PCW-20w  ...   Sanger
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...   PCW-20w  ...   Sanger
#
#                                                    cell_or_nuclei  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...         Nuclei
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...         Nuclei
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...         Nuclei
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...         Nuclei
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...         Nuclei
# ...                                                           ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...         Nuclei
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...         Nuclei
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...         Nuclei
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...         Nuclei
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...         Nuclei
#
#                                                         modality      kit_10x  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...  Multiome-RNA  Multiome-v1
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...  Multiome-RNA  Multiome-v1
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...  Multiome-RNA  Multiome-v1
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...  Multiome-RNA  Multiome-v1
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...  Multiome-RNA  Multiome-v1
# ...                                                          ...          ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...  Multiome-RNA  Multiome-v1
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...  Multiome-RNA  Multiome-v1
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...  Multiome-RNA  Multiome-v1
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...  Multiome-RNA  Multiome-v1
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...  Multiome-RNA  Multiome-v1
#
#                                                    flushed scrublet_score  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...      na       0.103448
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...      na       0.207547
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...      na       0.194030
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...      na       0.160622
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...      na       0.181818
# ...                                                    ...            ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...      na       0.025522
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...      na       0.014028
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...      na       0.014028
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...      na       0.059848
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...      na       0.024427
#
#                                                     scrublet_leiden  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...             13,6
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...              1,2
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...              1,8
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...              1,8
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...              1,2
# ...                                                             ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...              4,0
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...              6,0
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...             8,29
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...             26,0
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...            16,13
#
#                                                    cluster_scrublet_score  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...               0.103448
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...               0.194683
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...               0.181818
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...               0.181818
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...               0.194683
# ...                                                                   ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...               0.026646
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...               0.111981
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...               0.097444
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...               0.059848
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...               0.032746
#
#                                                     doublet_pval  \
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...      0.582499
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...      0.070436
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...      0.108314
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...      0.108314
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...      0.070436
# ...                                                          ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...      0.866913
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...      0.494090
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...      0.570294
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...      0.749696
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...      0.848818
#
#                                                     doublet_bh_pval
# barcode
# BHF_F_Hea11064670_BHF_F_Hea11031823_ATCTTTGGTAG...         0.899783
# BHF_F_Hea11064670_BHF_F_Hea11031823_GACGTAAAGGA...         0.899783
# BHF_F_Hea11064670_BHF_F_Hea11031823_GTTGCATAGGC...         0.899783
# BHF_F_Hea11064670_BHF_F_Hea11031823_TATTCGTTCGG...         0.899783
# BHF_F_Hea11064670_BHF_F_Hea11031823_AGGTCATTCAA...         0.899783
# ...                                                             ...
# HCAHeartST13386010_HCAHeartST13303420_TATCCGGAG...         0.906713
# HCAHeartST13386010_HCAHeartST13303420_CGCATTTGT...         0.906713
# HCAHeartST13386010_HCAHeartST13303420_TTTCCACCA...         0.906713
# HCAHeartST13386010_HCAHeartST13303420_GGAACTAAG...         0.906713
# HCAHeartST13386010_HCAHeartST13303420_AAAGGACGT...         0.906713
#
# [721979 rows x 21 columns]

# %% [markdown]
# ## Save

# %%
adata.write('/nfs/team205/heart/anndata_objects/Foetal/QC/multiome_RNA_foetal_prefilter.h5ad')
# Out:
# ... storing 'sangerID' as categorical
# ... storing 'combinedID' as categorical
# ... storing 'donor' as categorical
# ... storing 'donor_type' as categorical
# ... storing 'region' as categorical
# ... storing 'region_finest' as categorical
# ... storing 'age' as categorical
# ... storing 'gender' as categorical
# ... storing 'facility' as categorical
# ... storing 'cell_or_nuclei' as categorical
# ... storing 'modality' as categorical
# ... storing 'kit_10x' as categorical
# ... storing 'flushed' as categorical
# ... storing 'scrublet_leiden' as categorical
# ... storing 'gene_name' as categorical
# ... storing 'feature_type' as categorical

# %%
sc.pl.violin(adata,
             ['scrublet_score', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval'],jitter = 0.2, multi_panel = True)

# %%
adata.obs['donor'].value_counts()
# Out:
# Hst41                  319810
# Hst33                  132178
# Hst39                   64602
# Hst39, Hst40            51709
# C92                     41804
# Hst40                   30453
# Hst36                   24666
# Hst36, Hst39, Hst40     23275
# C87                     10191
# C104                     8968
# C98                      6901
# C85                      4757
# C82                      2665
# Name: donor, dtype: int64
