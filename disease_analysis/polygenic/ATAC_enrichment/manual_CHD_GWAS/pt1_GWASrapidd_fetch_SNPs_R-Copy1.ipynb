# %% [markdown]
# ### Uses a very broad search (Parent term contains string 'Cardiovascular') to select a large number of trait IDs (these are later pruned)

# %%
# supress warnings
options(warn=-1)

# %%
# get date for time stamping
today=format(Sys.Date(), "%Y-%m-%d")

# %%
# load packages
library('gwasrapidd')
library('tidyverse')
library('glue')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ dplyr::n()      masks gwasrapidd::n()

# %%
# Read in CHD SNPs
snps=read.csv('/nfs/team205/heart/CHD_GWAS/chd_gwas_SNPs.csv')
snps
# Out:
#    simplified_classification phenotype                 SNP
# 1  obstructive               Obstructive Heart Defects rs2360743
# 2  LH                        LH lesions                rs8061121
# 3  LH                        LH lesions                rs1975649
# 4  LH                        LH lesions                rs6495706
# 5  NOS                       NOS                       rs185531658
# 6  septal                    ASD                       rs870142
# 7  septal                    ASD II                    rs145619574
# 8  septal                    ASD II                    rs187369228
# 9  septal                    ASD II                    rs72917381
# 10 LH                        LH lesions                rs114503684
# 11 LH                        LH lesions                rs2046060
# 12 LH                        LH lesions                rs35437121
# 13 RH                        RH lesions                rs146300195
# 14 septal                    septal defects            rs138741144
# 15 septal                    septal defects            rs185531658
# 16 vascular                  TGA                       rs143638934
# 17 vascular                  TGA                       rs148563140
# 18 vascular                  TGA                       rs149467721
# 19 vascular                  TGA                       rs149890280
# 20 vascular                  TGA                       rs150246290
# 21 vascular                  TGA                       rs77094733
# 22 vascular                  thoracic vessels          rs117527287
# 23 vascular                  thoracic vessels          rs11874
# 24 vascular                  thoracic vessels          rs17677363
# 25 vascular                  thoracic vessels          rs76774446
# 26 NOS                       NOS                       rs2474937
# 27 NOS                       NOS                       rs1531070
# 28 LH                        LH lesions                rs3746446
# 29 LH                        LH lesions                rs12045807
# 30 obstructive               LVOTO                     rs870142
# 31 septal                    ASD                       rs870142
# 32 obstructive               LVOTO                     rs11514295
# 33 obstructive               LVOTO                     rs74095902
# 34 obstructive               LVOTO                     rs6542647
# 35 obstructive               LVOTO                     rs6811802
# 36 obstructive               LVOTO                     rs72820264
# 37 obstructive               LVOTO                     rs11755054
# 38 obstructive               LVOTO                     rs733317
# 39 obstructive               LVOTO                     rs74377301
# 40 obstructive               LVOTO                     rs1379134
# 41 obstructive               LVOTO                     rs672149
# 42 obstructive               LVOTO                     rs7623291
# 43 obstructive               LVOTO                     rs11159840
# 44 obstructive               LVOTO                     rs11894932
# 45 obstructive               LVOTO                     rs2567992
# 46 obstructive               LVOTO                     rs7465601
# 47 NOS                       NOS                       rs1176869
# 48 NOS                       NOS                       rs17111230
# 49 NOS                       NOS                       rs1000613
# 50 NOS                       NOS                       rs56409046
# 51 NOS                       NOS                       rs13285621
# 52 septal                    VSD                       rs12186641
# 53 obstructive               Obstructive Heart Defects rs5913271
# 54 obstructive               Obstructive Heart Defects rs113920486
# 55 obstructive               Obstructive Heart Defects rs55877192
# 56 obstructive               Obstructive Heart Defects rs188255766
#    study
# 1  Rashkin2021
# 2  Mitchell2015
# 3  Mitchell2015
# 4  Mitchell2015
# 5  Lahm2021
# 6  Lahm2021
# 7  Lahm2021
# 8  Lahm2021
# 9  Lahm2021
# 10 Lahm2021
# 11 Lahm2021
# 12 Lahm2021
# 13 Lahm2021
# 14 Lahm2021
# 15 Lahm2021
# 16 Lahm2021
# 17 Lahm2021
# 18 Lahm2021
# 19 Lahm2021
# 20 Lahm2021
# 21 Lahm2021
# 22 Lahm2021
# 23 Lahm2021
# 24 Lahm2021
# 25 Lahm2021
# 26 Hu 2013
# 27 Hu 2013
# 28 Hanchard2016
# 29 Hanchard2016
# 30 Córdova-Palomera2019
# 31 Cordell2013
# 32 Agopian2017
# 33 Agopian2017
# 34 Agopian2017
# 35 Agopian2017
# 36 Agopian2017
# 37 Agopian2017
# 38 Agopian2017
# 39 Agopian2017
# 40 Agopian2017
# 41 Agopian2017
# 42 Agopian2017
# 43 Agopian2017
# 44 Agopian2017
# 45 Agopian2017
# 46 Agopian2017
# 47 Agopian2017
# 48 Agopian2017
# 49 Agopian2017
# 50 Agopian2017
# 51 Agopian2017
# 52 Cordell2013
# 53 Rashkin2021
# 54 Rashkin2021
# 55 Rashkin2021
# 56 Rashkin2021

# %%
chrom<-list()
pos<-list()
region<-list()

tmp<-get_variants(variant_id=snps$SNP[2])@variants
chrom[]<-tmp$chromosome_name
# Out:
#   variant_id merged functional_class chromosome_name chromosome_position
# 1 rs8061121  0      intron_variant   16              87159478
#   chromosome_region last_update_date
# 1 16q24.2           2021-06-24 17:50:13

# %%
# get metadata for those trait terms, the efo_ids in particular

chrom<-list()
pos<-list()
region<-list()

for (i in seq_along(snps$SNP)) {
    tmp<-get_variants(variant_id=snps$SNP[i])@variants
    chrom[i]<-tmp$chromosome_name[1]
    pos[i]<-tmp$chromosome_position[1]
    region[i]<-tmp$chromosome_region[1]
}

snps$chrom<-chrom
snps$pos<-pos
snps$region<-region

snps
# Out:
#    simplified_classification phenotype                 SNP
# 1  obstructive               Obstructive Heart Defects rs2360743
# 2  LH                        LH lesions                rs8061121
# 3  LH                        LH lesions                rs1975649
# 4  LH                        LH lesions                rs6495706
# 5  NOS                       NOS                       rs185531658
# 6  septal                    ASD                       rs870142
# 7  septal                    ASD II                    rs145619574
# 8  septal                    ASD II                    rs187369228
# 9  septal                    ASD II                    rs72917381
# 10 LH                        LH lesions                rs114503684
# 11 LH                        LH lesions                rs2046060
# 12 LH                        LH lesions                rs35437121
# 13 RH                        RH lesions                rs146300195
# 14 septal                    septal defects            rs138741144
# 15 septal                    septal defects            rs185531658
# 16 vascular                  TGA                       rs143638934
# 17 vascular                  TGA                       rs148563140
# 18 vascular                  TGA                       rs149467721
# 19 vascular                  TGA                       rs149890280
# 20 vascular                  TGA                       rs150246290
# 21 vascular                  TGA                       rs77094733
# 22 vascular                  thoracic vessels          rs117527287
# 23 vascular                  thoracic vessels          rs11874
# 24 vascular                  thoracic vessels          rs17677363
# 25 vascular                  thoracic vessels          rs76774446
# 26 NOS                       NOS                       rs2474937
# 27 NOS                       NOS                       rs1531070
# 28 LH                        LH lesions                rs3746446
# 29 LH                        LH lesions                rs12045807
# 30 obstructive               LVOTO                     rs870142
# 31 septal                    ASD                       rs870142
# 32 obstructive               LVOTO                     rs11514295
# 33 obstructive               LVOTO                     rs74095902
# 34 obstructive               LVOTO                     rs6542647
# 35 obstructive               LVOTO                     rs6811802
# 36 obstructive               LVOTO                     rs72820264
# 37 obstructive               LVOTO                     rs11755054
# 38 obstructive               LVOTO                     rs733317
# 39 obstructive               LVOTO                     rs74377301
# 40 obstructive               LVOTO                     rs1379134
# 41 obstructive               LVOTO                     rs672149
# 42 obstructive               LVOTO                     rs7623291
# 43 obstructive               LVOTO                     rs11159840
# 44 obstructive               LVOTO                     rs11894932
# 45 obstructive               LVOTO                     rs2567992
# 46 obstructive               LVOTO                     rs7465601
# 47 NOS                       NOS                       rs1176869
# 48 NOS                       NOS                       rs17111230
# 49 NOS                       NOS                       rs1000613
# 50 NOS                       NOS                       rs56409046
# 51 NOS                       NOS                       rs13285621
# 52 septal                    VSD                       rs12186641
# 53 obstructive               Obstructive Heart Defects rs5913271
# 54 obstructive               Obstructive Heart Defects rs113920486
# 55 obstructive               Obstructive Heart Defects rs55877192
# 56 obstructive               Obstructive Heart Defects rs188255766
#    study                chrom pos       region
# 1  Rashkin2021          19    10625838  19p13.2
# 2  Mitchell2015         16    87159478  16q24.2
# 3  Mitchell2015         3     63453210  3p14.2
# 4  Mitchell2015         15    34684669  15q14
# 5  Lahm2021             5     113800824 5q22.3
# 6  Lahm2021             4     4646320   4p16.2
# 7  Lahm2021             NA    NA        NA
# 8  Lahm2021             3     190084650 3q28
# 9  Lahm2021             18    56878992  18q21.31
# 10 Lahm2021             NA    NA        NA
# 11 Lahm2021             3     188134698 3q27.3
# 12 Lahm2021             NA    NA        NA
# 13 Lahm2021             5     128991152 5q23.3
# 14 Lahm2021             17    33959545  17q12
# 15 Lahm2021             5     113800824 5q22.3
# 16 Lahm2021             NA    NA        NA
# 17 Lahm2021             8     80563171  8q21.13
# 18 Lahm2021             NA    NA        NA
# 19 Lahm2021             NA    NA        NA
# 20 Lahm2021             20    15132234  20p12.1
# 21 Lahm2021             NA    NA        NA
# 22 Lahm2021             6     85020241  6q14.3
# 23 Lahm2021             17    46939827  17q21.32
# 24 Lahm2021             17    46958746  17q21.32
# 25 Lahm2021             17    46969002  17q21.32
# 26 Hu 2013              1     118360355 1p12
# 27 Hu 2013              4     139874173 4q31.1
# 28 Hanchard2016         20    34986962  20q11.22
# 29 Hanchard2016         1     150612358 1q21.3
# 30 Córdova-Palomera2019 4     4646320   4p16.2
# 31 Cordell2013          4     4646320   4p16.2
# 32 Agopian2017          12    69984473  12q15
# 33 Agopian2017          13    71427529  13q21.33
# 34 Agopian2017          2     4898655   2p25.2
# 35 Agopian2017          4     78011684  4q21.21
# 36 Agopian2017          6     9291650   6p24.3
# 37 Agopian2017          6     22656836  6p22.3
# 38 Agopian2017          7     31017952  7p14.3
# 39 Agopian2017          7     123592441 7q31.32
# 40 Agopian2017          8     41028059  8p11.21
# 41 Agopian2017          11    128759487 11q24.3
# 42 Agopian2017          3     178638449 3q26.32
# 43 Agopian2017          14    88090181  14q31.3
# 44 Agopian2017          2     98648723  2q11.2
# 45 Agopian2017          12    121228050 12q24.31
# 46 Agopian2017          8     131375210 8q24.22
# 47 Agopian2017          14    40807221  14q21.1
# 48 Agopian2017          14    40922047  14q21.1
# 49 Agopian2017          5     104604349 5q21.2
# 50 Agopian2017          6     9320073   6p24.3
# 51 Agopian2017          9     73601791  9q21.13
# 52 Cordell2013          5     51868281  5q11.2
# 53 Rashkin2021          X     80475711  Xq21.1
# 54 Rashkin2021          10    52539853  10q21.1
# 55 Rashkin2021          6     44161476  6p21.1
# 56 Rashkin2021          5     115946361 5q23.1

# %%
%%time

# add chromosomal position of each of the tagged SNPs to output

tagged_pos=[]


for tagged_snp in range(len(out['tagged_snps'])):

    if type(out['tagged_snps'][tagged_snp])==str and out['tagged_snps'][tagged_snp].startswith('rs'):
            server = "https://rest.ensembl.org"
            ext = f"/variation/human/{out['tagged_snps'][tagged_snp]}?"
            r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
            decoded = r.json()

            if len(decoded)>0 and "mappings" in decoded:
                tagged_pos.append(decoded['mappings'][0]['start'])
            else:
                tagged_pos.append('NA')
    else:
        tagged_pos.append('NA')

# add the column
out['tagged_snps_pos']=tagged_pos

# write a file (for each trait)
out.to_csv('/nfs/team205/heart/EBI_GWAS/PITX2/EFO_FAKE_PITX2_index_SNPs_with_SNPs_in_LD_with_pos.csv',index=False)
# Out:
# EFO_0000275
# CPU times: user 1.1 s, sys: 39.1 ms, total: 1.14 s
# Wall time: 15.1 s

# %%
# Make a table of index SNPs for each trait

list_of_tibbles<-list()

for (i in seq_along(efos$trait)) {
    if (file.exists(glue('/nfs/team205/heart/EBI_GWAS/index_snps/{efos$efo_id[i]}_{efos$trait[i]}_index_SNPs.csv'))==FALSE) {
        print(glue('{efos$trait[i]}: file needs to be made'))
        variants_table<-get_variants(efo_id=efos$efo_id[i])@variants #gets variants for the trait
        variants_table<-variants_table[complete.cases(variants_table), ] # removes any variants where SNP coordinates are not known, since these are useless to us
        if (dim(variants_table)[1]>0) { # only keep traits for which there are SNPs
            variants_table$efo_id=efos$efo_id[i]
            variants_table$efo_term=efos$trait[i]
            n_SNPs<-dim(variants_table)[1]
            print(efos$efo_id[i])
            list_of_tibbles[[i]]<-variants_table
            write_csv(list_of_tibbles[[i]],glue('/nfs/team205/heart/EBI_GWAS/index_snps/{efos$efo_id[i]}_{efos$trait[i]}_index_SNPs.csv'))
        }
    } else {
        print(glue('{efos$trait[i]}: file already exists'))
    }
}
# Out:
# mri defined brain infarct: file needs to be made
# vascular dementia: file needs to be made
# [1] "EFO_0004718"
# aortic aneurysm: file needs to be made
# [1] "EFO_0001666"
# cerebral autosomal dominant arteriopathy with subcortical infarcts and leukoencephalopathy: file needs to be made
# [1] "Orphanet_136"
# nt-probnp measurement: file needs to be made
# [1] "EFO_0004745"
# TP segment duration: file needs to be made
# ST segment duration: file needs to be made
# T wave duration: file needs to be made
# carotid-femoral pulse wave velocity: file needs to be made
# [1] "EFO_0004724"
# congestive heart failure: file needs to be made
# [1] "EFO_0000373"
# atrial natriuretic factor measurement: file needs to be made
# [1] "EFO_0004789"
# cardiotoxicity: file needs to be made
# [1] "EFO_1001482"
# non-obstructive coronary artery disease: file needs to be made
# [1] "EFO_1001483"
# tissue plasminogen activator measurement: file needs to be made
# [1] "EFO_0004791"
# vascular endothelial growth factor measurement: file needs to be made
# [1] "EFO_0004762"
# uric acid measurement: file needs to be made
# [1] "EFO_0004761"
# early onset hypertension: file needs to be made
# [1] "EFO_0004772"
# cardiac embolism: file needs to be made
# [1] "EFO_1001493"
# small artery occlusion: file needs to be made
# [1] "EFO_1001495"
# asymmetrical dimethylarginine measurement: file needs to be made
# [1] "EFO_0006522"
# symmetrical dimethylarginine measurement: file needs to be made
# [1] "EFO_0006523"
# congenital heart disease: file needs to be made
# [1] "EFO_0005207"
# carotid plaque build: file needs to be made
# [1] "EFO_0006501"
# angiographic measurement: file needs to be made
# albumin:globulin ratio measurement: file needs to be made
# [1] "EFO_0005128"
# plasma betaine measurement: file needs to be made
# [1] "EFO_0007787"
# arylesterase enzyme measurement: file needs to be made
# [1] "EFO_0005126"
# conduction system disorder: file needs to be made
# diabetic foot: file needs to be made
# [1] "EFO_1001459"
# heart aneurysm: file needs to be made
# mitral valve disease: file needs to be made
# male reproductive system disease: file needs to be made
# tricuspid valve disease: file needs to be made
# left ventricular stroke volume measurement: file needs to be made
# left ventricular mass to end-diastolic volume ratio: file needs to be made
# [1] "EFO_0010556"
# left ventricular structural measurement: file needs to be made
# [1] "EFO_0008205"
# left ventricular diastolic function measurement: file needs to be made
# [1] "EFO_0008204"
# left ventricular systolic function measurement: file needs to be made
# [1] "EFO_0008206"
# aortic valve disease: file needs to be made
# heart valve disease: file needs to be made
# [1] "EFO_0009551"
# hemorrhoid: file needs to be made
# [1] "EFO_0009552"
# vasoactive peptide measurement: file needs to be made
# [1] "EFO_0005196"
# coronary artery disease: file needs to be made
# [1] "EFO_0001645"
# cardiomyopathy: file needs to be made
# osteoprotegerin measurement: file needs to be made
# [1] "EFO_0005918"
# aortic stenosis: file needs to be made
# [1] "EFO_0000266"
# atrial fibrillation: file needs to be made
# [1] "EFO_0000275"
# congenital left-sided heart lesions: file needs to be made
# [1] "EFO_0005938"
# parental genotype effect measurement: file needs to be made
# [1] "EFO_0005939"
# chemotherapy-induced hypertension: file needs to be made
# [1] "EFO_0005942"
# Mitral valve prolapse: file needs to be made
# [1] "HP_0001634"
# TPE interval measurement: file needs to be made
# [1] "EFO_0004644"
# Subdural hemorrhage: file needs to be made
# QRS amplitude: file needs to be made
# [1] "EFO_0007742"
# R wave amplitude: file needs to be made
# [1] "EFO_0007741"
# S wave amplitude: file needs to be made
# Takotsubo cardiomyopathy: file needs to be made
# [1] "EFO_1002000"
# treatment-resistant hypertension: file needs to be made
# [1] "EFO_1002006"
# QT interval: file needs to be made
# [1] "EFO_0004682"
# secondary hypertension: file needs to be made
# aortic root size: file needs to be made
# [1] "EFO_0005037"
# cardiac troponin T measurement: file needs to be made
# [1] "EFO_0005043"
# internal carotid intimal medial thickness: file needs to be made
# [1] "EFO_0005053"
# heart septal defect: file needs to be made
# [1] "MONDO_0002078"
# P wave duration: file needs to be made
# [1] "EFO_0005094"
# PR segment: file needs to be made
# [1] "EFO_0005095"
# QRS complex: file needs to be made
# [1] "EFO_0005054"
# QRS duration: file needs to be made
# [1] "EFO_0005055"
# cardiac arrest: file needs to be made
# paroxysmal tachycardia: file needs to be made
# small vessel stroke: file needs to be made
# [1] "EFO_1001504"
# platelet reactivity measurement: file needs to be made
# [1] "EFO_0004985"
# aortic coarctation: file needs to be made
# pulse wave reflection index measurement: file needs to be made
# serum ST2 measurement: file needs to be made
# [1] "EFO_0005416"
# abnormality of cardiovascular system morphology: file needs to be made
# [1] "HP_0030680"
# cor pulmonale: file needs to be made
# Abnormality of the vasculature: file needs to be made
# temporal arteritis: file needs to be made
# [1] "EFO_1001209"
# lipoprotein-associated phospholipase A(2) change measurement: file needs to be made
# [1] "EFO_0008432"
# Brugada syndrome: file needs to be made
# [1] "MONDO_0015263"
# B-type natriuretic peptide to N-terminal pro B-type natriuretic peptide ratio: file needs to be made
# [1] "EFO_0008469"
# midregional pro atrial natriuretic peptide measurement: file needs to be made
# [1] "EFO_0008468"
# transposition of the great arteries: file needs to be made
# [1] "MONDO_0000153"
# aortic valve insufficiency: file needs to be made
# parenchymal hematoma: file needs to be made
# [1] "EFO_0020101"
# carotid atherosclerosis: file needs to be made
# [1] "EFO_0009783"
# intracranial hemorrhage: file needs to be made
# hypertension: file needs to be made
# [1] "EFO_0000537"
# hypertrophic cardiomyopathy: file needs to be made
# [1] "EFO_0000538"
# endocarditis: file needs to be made
# RR interval: file needs to be made
# [1] "EFO_0004831"
# Zika virus congenital syndrome: file needs to be made
# [1] "MONDO_0000890"
# common carotid intimal medial thickness: file needs to be made
# [1] "EFO_0004860"
# postoperative ventricular dysfunction: file needs to be made
# early cardiac repolarization measurement: file needs to be made
# [1] "EFO_0004885"
# AL amyloidosis: file needs to be made
# [1] "MONDO_0019438"
# cervical artery dissection: file needs to be made
# [1] "EFO_1000059"
# ventricular rate measurement: file needs to be made
# [1] "EFO_0007928"
# myocardial ischemia: file needs to be made
# propionylcarnitine measurement: file needs to be made
# [1] "EFO_0020942"
# phlebitis: file needs to be made
# [1] "EFO_1001395"
# ventricular tachycardia: file needs to be made
# torsades de pointes: file needs to be made
# [1] "EFO_0005307"
# aortic valve calcification: file needs to be made
# [1] "EFO_0005239"
# myocarditis: file needs to be made
# [1] "EFO_0009609"
# aortic measurement: file needs to be made
# [1] "EFO_0020865"
# major adverse cardiovascular event measurement: file needs to be made
# [1] "EFO_0020863"
# myeloperoxidase measurement: file needs to be made
# [1] "EFO_0005243"
# hypotension: file needs to be made
# [1] "EFO_0005251"
# JT interval: file needs to be made
# [1] "EFO_0007885"
# cardiovascular disease biomarker measurement: file needs to be made
# [1] "EFO_0005278"
# orthostatic hypotension: file needs to be made
# [1] "EFO_0005252"
# angiopoietin-1 receptor measurement: file needs to be made
# [1] "EFO_0010600"
# congenital heart malformation: file needs to be made
# [1] "EFO_0005269"
# occlusion precerebral artery: file needs to be made
# bacterial endocarditis: file needs to be made
# atrial heart septal defect: file needs to be made
# abnormal morphology of female internal genitalia: file needs to be made
# pericardial effusion: file needs to be made
# arterial embolism: file needs to be made
# cerebral infarction: file needs to be made
# carotid artery thrombosis: file needs to be made
# T wave amplitude: file needs to be made
# ventricular repolarisation duration measurement: file needs to be made
# TpTe measurement: file needs to be made
# T wave morphology measurement: file needs to be made
# [1] "EFO_0008398"
# diffuse scleroderma: file needs to be made
# [1] "EFO_0000404"
# heart amyloid deposition measurement: file needs to be made
# [1] "EFO_0008365"
# left ventricular ejection fraction measurement: file needs to be made
# [1] "EFO_0008373"
# disease: file needs to be made
# dilated cardiomyopathy: file needs to be made
# [1] "EFO_0000407"
# P wave terminal force measurement: file needs to be made
# [1] "EFO_0008379"
# coronary aneurysm: file needs to be made
# [1] "EFO_1000881"
# coronary stenosis: file needs to be made
# [1] "EFO_1000882"
# coronary thrombosis: file needs to be made
# [1] "EFO_1000883"
# Abnormal nasolacrimal system morphology: file needs to be made
# BNP measurement: file needs to be made
# [1] "EFO_0006920"
# epistaxis: file needs to be made
# hepatocyte growth factor measurement: file needs to be made
# [1] "EFO_0006903"
# peripheral vascular disease: file needs to be made
# [1] "EFO_0003875"
# endothelial growth factor measurement: file needs to be made
# [1] "EFO_0006900"
# angiopoietin-2 measurement: file needs to be made
# angiopoietin-2 receptor measurement: file needs to be made
# [1] "EFO_0006902"
# brain aneurysm: file needs to be made
# [1] "EFO_0003870"
# heart rate response to exercise: file needs to be made
# [1] "EFO_0009184"
# heart rate response to recovery post exercise: file needs to be made
# [1] "EFO_0009185"
# lobar intracerebral hemorrhage: file needs to be made
# [1] "EFO_0010177"
# non-lobar intracerebral hemorrhage: file needs to be made
# [1] "EFO_0010178"
# cardiovascular event measurement: file needs to be made
# [1] "EFO_0006919"
# heart function measurement: file needs to be made
# [1] "EFO_0004311"
# limited scleroderma: file needs to be made
# [1] "EFO_1001017"
# acute coronary syndrome: file needs to be made
# [1] "EFO_0005672"
# mouth disease: file needs to be made
# resting heart rate: file needs to be made
# [1] "EFO_0004351"
# exercise test: file needs to be made
# [1] "EFO_0004328"
# electrocardiography: file needs to be made
# [1] "EFO_0004327"
# heart rate: file needs to be made
# [1] "EFO_0004326"
# coronary atherosclerosis: file needs to be made
# [1] "MONDO_0021661"
# intracerebral hemorrhage: file needs to be made
# [1] "EFO_0005669"
# peripheral arterial disease: file needs to be made
# [1] "EFO_0004265"
# vascular disease: file needs to be made
# post-operative myocardial infarction: file needs to be made
# [1] "EFO_0009953"
# cardiac arrhythmia: file needs to be made
# [1] "EFO_0004269"
# post-operative atrial fibrillation: file needs to be made
# [1] "EFO_0009952"
# sudden cardiac arrest: file needs to be made
# [1] "EFO_0004278"
# brain infarction: file needs to be made
# [1] "EFO_0004277"
# thoracic aortic aneurysm: file needs to be made
# [1] "EFO_0004282"
# stroke: file needs to be made
# [1] "EFO_0000712"
# subarachnoid hemorrhage: file needs to be made
# [1] "EFO_0000713"
# systemic scleroderma: file needs to be made
# [1] "EFO_0000717"
# ventricular fibrillation: file needs to be made
# venous thromboembolism: file needs to be made
# [1] "EFO_0004286"
# macrovascular complications of diabetes: file needs to be made
# [1] "EFO_0010977"
# pulmonary embolism: file needs to be made
# [1] "EFO_0003827"
# Takayasu arteritis: file needs to be made
# [1] "EFO_1001857"
# primary pulmonary hypertension: file needs to be made
# heart disease: file needs to be made
# vascular brain injury measurement: file needs to be made
# [1] "EFO_0006800"
# vasculitis: file needs to be made
# [1] "EFO_0006803"
# carotid artery disease: file needs to be made
# idiopathic dilated cardiomyopathy: file needs to be made
# [1] "EFO_0009094"
# cardiac troponin I measurement: file needs to be made
# [1] "EFO_0010071"
# congenital anomaly of the great arteries: file needs to be made
# transient ischemic attack: file needs to be made
# cerebrovascular disorder: file needs to be made
# Chagas cardiomyopathy: file needs to be made
# [1] "EFO_0005529"
# large artery stroke: file needs to be made
# [1] "EFO_0005524"
# ejection fraction measurement: file needs to be made
# [1] "EFO_0005527"
# plasma renin activity measurement: file needs to be made
# [1] "EFO_0006828"
# raynaud disease: file needs to be made
# pseudotumor cerebri: file needs to be made
# [1] "EFO_1001132"
# coronary vasospasm: file needs to be made
# [1] "EFO_0004225"
# coronary restenosis: file needs to be made
# [1] "EFO_0004224"
# rheumatic heart disease: file needs to be made
# [1] "EFO_1001161"
# retinal vein occlusion: file needs to be made
# angioedema: file needs to be made
# [1] "EFO_0005532"
# hernia of the abdominal wall: file needs to be made
# abdominal aortic aneurysm: file needs to be made
# [1] "EFO_0004214"
# bone development disease: file needs to be made
# Spontaneous coronary artery dissection: file needs to be made
# [1] "EFO_0010820"
# cerebral amyloid angiopathy: file needs to be made
# [1] "EFO_0006790"
# vascular brain injury: file needs to be made
# [1] "EFO_0006791"
# bundle branch block: file needs to be made
# serum VEGFR2 concentration measurement: file needs to be made
# [1] "EFO_0006795"
# nonischemic cardiomyopathy: file needs to be made
# Churg-Strauss syndrome: file needs to be made
# [1] "EFO_0007208"
# anti-topoisomerase-I-antibody-positive systemic scleroderma: file needs to be made
# [1] "EFO_0008537"
# anti-centromere-antibody-positive systemic scleroderma: file needs to be made
# [1] "EFO_0008536"
# non-st elevation myocardial infarction: file needs to be made
# st elevation myocardial infarction: file needs to be made
# essential hypertension: file needs to be made
# [1] "MONDO_0001134"
# myocardial infarction: file needs to be made
# [1] "EFO_0000612"
# subsequent st elevation (stemi) and non-st elevation (nstemi) myocardial infarction: file needs to be made
# acute myocardial infarction: file needs to be made
# [1] "EFO_0008583"
# preeclampsia: file needs to be made
# [1] "EFO_0000668"
# Arteritis: file needs to be made
# cardioembolic stroke: file needs to be made
# [1] "EFO_1001976"
# ischemic cardiomyopathy: file needs to be made
# [1] "EFO_0001425"
# D dimer measurement: file needs to be made
# [1] "EFO_0004507"
# Abnormal foot morphology: file needs to be made
# [1] "HP_0001760"
# soluble p-selectin measurement: file needs to be made
# [1] "EFO_0004519"
# arterial stiffness measurement: file needs to be made
# [1] "EFO_0004517"
# icam-1 measurement: file needs to be made
# [1] "EFO_0004520"
# creatine kinase measurement: file needs to be made
# [1] "EFO_0004534"
# homocysteine measurement: file needs to be made
# [1] "EFO_0004578"
# chemerin measurement: file needs to be made
# [1] "EFO_0004573"
# C4BP measurement: file needs to be made
# [1] "EFO_0004572"
# sick sinus syndrome: file needs to be made
# [1] "MONDO_0001823"
# right ventricular ejection fraction measurement: file needs to be made
# [1] "EFO_0021816"
# right ventricular stroke volume measurement: file needs to be made
# [1] "EFO_0021817"
# right ventricular diastolic volume measurement: file needs to be made
# [1] "EFO_0021814"
# right ventricular systolic volume measurement: file needs to be made
# [1] "EFO_0021815"
# migraine with aura: file needs to be made
# [1] "MONDO_0005475"
# abnormal cardiac septum morphology: file needs to be made
# supraventricular tachycardia: file needs to be made
# Paroxysmal supraventricular tachycardia: file needs to be made
# heart rate variability measurement: file needs to be made
# [1] "EFO_0008003"
# interventricular septum thickness: file needs to be made
# posterior wall thickness: file needs to be made
# fractional shortening: file needs to be made
# [1] "EFO_0009285"
# heart relative wall thickness: file needs to be made
# [1] "EFO_0009286"
# left ventricular mass: file needs to be made
# [1] "EFO_0009289"
# left ventricular mass index: file needs to be made
# E/A ratio: file needs to be made
# abdominal aortic calcification measurement: file needs to be made
# [1] "EFO_0010272"
# thoracic aortic calcification measurement: file needs to be made
# [1] "EFO_0010273"
# peripartum cardiomyopathy: file needs to be made
# ventricular ectopy: file needs to be made
# [1] "EFO_0009276"
# supraventricular ectopy: file needs to be made
# [1] "EFO_0009277"
# premature cardiac contractions: file needs to be made
# [1] "EFO_0009275"
# Moyamoya disease: file needs to be made
# [1] "MONDO_0016820"
# pulmonary arterial hypertension: file needs to be made
# [1] "EFO_0001361"
# atrioventricular block: file needs to be made
# third-degree atrioventricular block: file needs to be made
# pulse pressure measurement: file needs to be made
# [1] "EFO_0005763"
# migraine disorder: file needs to be made
# [1] "MONDO_0005277"
# Duchenne muscular dystrophy: file needs to be made
# [1] "MONDO_0010679"
# PR interval: file needs to be made
# [1] "EFO_0004462"
# heart failure: file needs to be made
# [1] "EFO_0003144"
# aortic vascular smooth muscle cell proliferation measurement: file needs to be made
# [1] "EFO_0600026"
# aortic vascular smooth muscle cell calcification measurement: file needs to be made
# [1] "EFO_0600025"
# congenital right-sided heart lesions: file needs to be made
# [1] "EFO_0600032"
# pericarditis: file needs to be made
# left atrial volume measurement: file needs to be made
# [1] "EFO_0600035"
# preeclampsia severity measurement: file needs to be made
# [1] "EFO_0021792"
# descending aortic diameter: file needs to be made
# [1] "EFO_0021788"
# ascending aortic diameter: file needs to be made
# [1] "EFO_0021787"
# cardiac troponin I change measurement: file needs to be made
# [1] "EFO_0600077"
# atherosclerosis: file needs to be made
# [1] "EFO_0003914"
# ankle brachial index: file needs to be made
# [1] "EFO_0003912"
# schizophrenia: file needs to be made
# [1] "MONDO_0005090"
# osteoarthritis: file needs to be made
# [1] "MONDO_0005178"
