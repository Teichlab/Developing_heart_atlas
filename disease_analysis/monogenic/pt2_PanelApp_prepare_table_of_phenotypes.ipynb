# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import rc_context
import bbknn
import re
import httplib2 as http
import json
import os
import glob

# %%
sc.settings.verbosity = 0            # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white', color_map = 'Reds', figsize = (5, 5),dpi_save=300)
# Out:
# scanpy==1.9.1 anndata==0.8.0 umap==0.5.3 numpy==1.22.4 scipy==1.8.1 pandas==1.4.3 scikit-learn==1.1.1 statsmodels==0.13.2 python-igraph==0.9.11 pynndescent==0.5.7

# %% [markdown]
# # Import a list of all human TFs

# %%
tf_df=pd.read_csv('http://humantfs.ccbr.utoronto.ca/download/v_1.01/DatabaseExtract_v_1.01.csv',index_col='HGNC symbol') # import a df of all human TFs
tf_df=tf_df.drop(['Unnamed: 0'],axis=1) # tidy
tf_list=tf_df.index.tolist() # convert gene symbol to list

# %% [markdown]
# # Define a list of phenotypes and search terms for those

# %%
# Using the list of phenotypes (see notebook pt1), make a dictionary grouping them
phenotype_dict={
    'Heterotaxy':['eterotaxy','Dextrocardia'],
    'ASD':['ASD','trial septal','Atrial septal defect','Patent foramen ovale'],
    'VSD':['VSD','entricular septal','Ventricular septal defect'],
    'AVSD':['AVSD','trioventricular septal','Atrioventricular septal defect'],
    'Malformation of outflow tracts':['Truncus arteriosus','Malformation of outflow tracts','Fallot','fallot','Double outlet right ventricle','Pentalogy of fallot','Transposition of the great arteries','Transposition of the great vessels',],
    'Functional single ventricle':['Functional single ventricle','Double-inlet left ventricle','Hypoplastic left heart syndrome','Hypoplastic right ventricle','Hypoplastic rv'],
#    'Obstructive lesions':['Obstructive lesions','alv','stenosis'], # removed because I don't know how to define this term
    'Cardiomyopathy':['ardiomyopathy'],
    'DCM':['DCM','ilated'],
    'HCM':['HCM','ypertrophic'],
    'LVNC':['ompaction','LVNC','Left ventricular noncompaction'],
    'Venous anomaly':['Total anomalous pulmonary venous return','Pulmonary vein stenosis','Partial anomalous pulmonary venous return','Persistent left superior vena cava'],
    'Pulmonary artery':['Dilatation of the pulmonary trunk','Hypoplastic left pulmonary artery','Pulmonary artery dysplasia and hypoplasia','Pulmonary atresia','Pulmonary trunk and pulmonary artery absence'],
    'Aortic arch':['Right aortic arch','Patent ductus arteriosus','Ductus arteriosus','Coarctation of the aorta','Interrupted aortic arch','Lsvc and left pulmonary artery arising from the ductus arteriosus'],
    'Aorta':['Aberrant supraclavicular artery','Anomalous right subclavian artery','Aortic aneurysm','Aortic hypoplasia'],
    'Coronary anomaly':['Anomalous left coronary artery from the pulmonary artery','Coronary artery anomaly'],
    'VA valves':['Pulmonic stenosis','Absent pulmonary valve','Bicuspid aortic valve', 'Aortic stenosis','Dysplastic pulmonary valve','Pulmonary stenosis'],
    'AV valves':['Dysplastic mitral valve','Dysplastic tricuspid valve',"Ebstein's anomaly",'Mitral atresia','Mitral stenosis','Mitral valve dysplasia','Tricuspid atresia','Tricuspid stenosis','Tricuspid valve atresia','Tricuspid valve dysplasia']
}

# %% [markdown]
# # Import PanelApp panels

# %%
# read in .tsvs for each trait, calling it by the trait name

all_files = []
for i in range(len(os.listdir('/home/jovyan/notebooks/suspension/scanpy_clustering/marker_lists/PanelApp/'))):
    all_files.append(os.listdir('/home/jovyan/notebooks/suspension/scanpy_clustering/marker_lists/PanelApp/')[i])
    
# remove '.ipynb...'

bad_traits = [item for item in all_files if item.startswith('.')]
all_files=[item for item in all_files if item not in bad_traits]

all_files
# Out:
# ['Brugada syndrome.tsv',
#  'Catecholaminergic polymorphic VT.tsv',
#  'Pulmonary arterial hypertension.tsv',
#  'Dilated cardiomyopathy - adult and teen.tsv',
#  'Left Ventricular Noncompaction Cardiomyopathy.tsv',
#  'Hypertrophic cardiomyopathy - teen and adult.tsv',
#  'Familial non syndromic congenital heart disease.tsv',
#  'Long QT syndrome.tsv',
#  'Dilated Cardiomyopathy and conduction defects.tsv',
#  'Cardiomyopathies - including childhood onset.tsv',
#  'Arrhythmogenic cardiomyopathy.tsv',
#  'Thoracic aortic aneurysm or dissection.tsv',
#  'Cardiac arrhythmias.tsv',
#  'Progressive cardiac conduction disease.tsv']

# %%
# Some of the files aren't about developmental disorders

files_for_analysis=['Left Ventricular Noncompaction Cardiomyopathy.tsv',
 'Familial non syndromic congenital heart disease.tsv',
'Cardiomyopathies - including childhood onset.tsv']

# %%
path = '/home/jovyan/notebooks/suspension/scanpy_clustering/marker_lists/PanelApp/'

li = []

for filename in files_for_analysis:
    df = pd.read_table(os.path.join(path,filename))
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
df=df.set_index('Entity Name')
df=df.rename_axis('gene')
df
# Out:
#        Entity type Gene Symbol  \
# gene
# ACTC1         gene       ACTC1
# MYBPC3        gene      MYBPC3
# MYH7          gene        MYH7
# TAZ           gene         TAZ
# TNNT2         gene       TNNT2
# ...            ...         ...
# TPM1          gene        TPM1
# TSFM          gene        TSFM
# TTN           gene         TTN
# TTR           gene         TTR
# VCL           gene         VCL
#
#                                      Sources(; separated)  \
# gene
# ACTC1   Expert list;Expert Review Green;Illumina TruGe...
# MYBPC3  Eligibility statement prior genetic testing;Ex...
# MYH7    Eligibility statement prior genetic testing;Ex...
# TAZ     Expert list;Expert Review Green;Illumina TruGe...
# TNNT2   Eligibility statement prior genetic testing;Ex...
# ...                                                   ...
# TPM1    Expert Review Green;London South GLH;NHS GMS;S...
# TSFM           Expert Review Green;NHS GMS;South West GLH
# TTN            Expert Review Green;NHS GMS;South West GLH
# TTR            Expert Review Green;NHS GMS;South West GLH
# VCL            Expert Review Green;NHS GMS;South West GLH
#
#                                                Level4          Level3  \
# gene
# ACTC1   Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# MYBPC3  Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# MYH7    Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# TAZ     Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# TNNT2   Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# ...                                               ...             ...
# TPM1     Cardiomyopathies - including childhood onset             NaN
# TSFM     Cardiomyopathies - including childhood onset             NaN
# TTN      Cardiomyopathies - including childhood onset             NaN
# TTR      Cardiomyopathies - including childhood onset             NaN
# VCL      Cardiomyopathies - including childhood onset             NaN
#
#                           Level2  \
# gene
# ACTC1   Cardiovascular disorders
# MYBPC3  Cardiovascular disorders
# MYH7    Cardiovascular disorders
# TAZ     Cardiovascular disorders
# TNNT2   Cardiovascular disorders
# ...                          ...
# TPM1                         NaN
# TSFM                         NaN
# TTN                          NaN
# TTR                          NaN
# VCL                          NaN
#
#                                      Model_Of_Inheritance  \
# gene
# ACTC1   MONOALLELIC, autosomal or pseudoautosomal, imp...
# MYBPC3  MONOALLELIC, autosomal or pseudoautosomal, imp...
# MYH7    MONOALLELIC, autosomal or pseudoautosomal, imp...
# TAZ     X-LINKED: hemizygous mutation in males, monoal...
# TNNT2   MONOALLELIC, autosomal or pseudoautosomal, imp...
# ...                                                   ...
# TPM1    MONOALLELIC, autosomal or pseudoautosomal, NOT...
# TSFM              BIALLELIC, autosomal or pseudoautosomal
# TTN     MONOALLELIC, autosomal or pseudoautosomal, NOT...
# TTR     MONOALLELIC, autosomal or pseudoautosomal, NOT...
# VCL     MONOALLELIC, autosomal or pseudoautosomal, NOT...
#
#                                                Phenotypes  Omim  Orphanet  \
# gene
# ACTC1   Left ventricular noncompaction 4 ;Left Ventric...   NaN       NaN
# MYBPC3  Left ventricular noncompaction 10, ;Hypertroph...   NaN       NaN
# MYH7    Left ventricular noncompaction 5, OMIM:613426;...   NaN       NaN
# TAZ        Left Ventricular Noncompaction Cardiomyopathy    NaN       NaN
# TNNT2   Left ventricular noncompaction 6, ;Hypertrophi...   NaN       NaN
# ...                                                   ...   ...       ...
# TPM1    Cardiomyopathy, familial hypertrophic, 3;Cardi...   NaN       NaN
# TSFM    Combined oxidative phosphorylation deficiency ...   NaN       NaN
# TTN     Cardiomyopathy, familial hypertrophic, 9,;Card...   NaN       NaN
# TTR                                         syndromic HCM   NaN       NaN
# VCL     Cardiomyopathy, familial hypertrophic, 15,;Car...   NaN       NaN
#
#         ...  Position GRCh38 Start Position GRCh38 End  STR Repeated Sequence  \
# gene    ...
# ACTC1   ...                    NaN                 NaN                    NaN
# MYBPC3  ...                    NaN                 NaN                    NaN
# MYH7    ...                    NaN                 NaN                    NaN
# TAZ     ...                    NaN                 NaN                    NaN
# TNNT2   ...                    NaN                 NaN                    NaN
# ...     ...                    ...                 ...                    ...
# TPM1    ...                    NaN                 NaN                    NaN
# TSFM    ...                    NaN                 NaN                    NaN
# TTN     ...                    NaN                 NaN                    NaN
# TTR     ...                    NaN                 NaN                    NaN
# VCL     ...                    NaN                 NaN                    NaN
#
#         STR Normal Repeats  STR Pathogenic Repeats  \
# gene
# ACTC1                  NaN                     NaN
# MYBPC3                 NaN                     NaN
# MYH7                   NaN                     NaN
# TAZ                    NaN                     NaN
# TNNT2                  NaN                     NaN
# ...                    ...                     ...
# TPM1                   NaN                     NaN
# TSFM                   NaN                     NaN
# TTN                    NaN                     NaN
# TTR                    NaN                     NaN
# VCL                    NaN                     NaN
#
#        Region Haploinsufficiency Score  Region Triplosensitivity Score  \
# gene
# ACTC1                              NaN                             NaN
# MYBPC3                             NaN                             NaN
# MYH7                               NaN                             NaN
# TAZ                                NaN                             NaN
# TNNT2                              NaN                             NaN
# ...                                ...                             ...
# TPM1                               NaN                             NaN
# TSFM                               NaN                             NaN
# TTN                                NaN                             NaN
# TTR                                NaN                             NaN
# VCL                                NaN                             NaN
#
#         Region Required Overlap Percentage Region Variant Type  \
# gene
# ACTC1                                  NaN                 NaN
# MYBPC3                                 NaN                 NaN
# MYH7                                   NaN                 NaN
# TAZ                                    NaN                 NaN
# TNNT2                                  NaN                 NaN
# ...                                    ...                 ...
# TPM1                                   NaN                 NaN
# TSFM                                   NaN                 NaN
# TTN                                    NaN                 NaN
# TTR                                    NaN                 NaN
# VCL                                    NaN                 NaN
#
#        Region Verbose Name
# gene
# ACTC1                  NaN
# MYBPC3                 NaN
# MYH7                   NaN
# TAZ                    NaN
# TNNT2                  NaN
# ...                    ...
# TPM1                   NaN
# TSFM                   NaN
# TTN                    NaN
# TTR                    NaN
# VCL                    NaN
#
# [146 rows x 35 columns]

# %%
phenotype_column='Phenotypes'

df['Phenotypes'][df['Phenotypes'].isna()]=df['Level4'] # replaces NaNs in Phenotypes column, allowing it to be used to filter for conditions

for phenotype in range(len(phenotype_dict)):
    df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])]=0
    df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1

df['TF']=0
df['TF'][df.index.isin(tf_list)]=1 # add a column indicating whether TF or not
df=df[df['Entity type']!='region'] # Remove any non-gene entities
df['source']='PanelApp'
df['granular_phenotype']=df[phenotype_column]
PanelApp=df
PanelApp
# Out:
# /tmp/ipykernel_5784/1749012678.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phenotypes'][df['Phenotypes'].isna()]=df['Level4'] # replaces NaNs in Phenotypes column, allowing it to be used to filter for conditions
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phenotype_'+str(list(phenotype_dict.keys())[phenotype])][df[phenotype_column].str.contains('|'.join(list(phenotype_dict.values())[phenotype]))]=1
# /tmp/ipykernel_5784/1749012678.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TF'][df.index.isin(tf_list)]=1 # add a column indicating whether TF or not
# /tmp/ipykernel_5784/1749012678.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['source']='PanelApp'
# /tmp/ipykernel_5784/1749012678.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['granular_phenotype']=df[phenotype_column]
#        Entity type Gene Symbol  \
# gene
# ACTC1         gene       ACTC1
# MYBPC3        gene      MYBPC3
# MYH7          gene        MYH7
# TAZ           gene         TAZ
# TNNT2         gene       TNNT2
# ...            ...         ...
# TPM1          gene        TPM1
# TSFM          gene        TSFM
# TTN           gene         TTN
# TTR           gene         TTR
# VCL           gene         VCL
#
#                                      Sources(; separated)  \
# gene
# ACTC1   Expert list;Expert Review Green;Illumina TruGe...
# MYBPC3  Eligibility statement prior genetic testing;Ex...
# MYH7    Eligibility statement prior genetic testing;Ex...
# TAZ     Expert list;Expert Review Green;Illumina TruGe...
# TNNT2   Eligibility statement prior genetic testing;Ex...
# ...                                                   ...
# TPM1    Expert Review Green;London South GLH;NHS GMS;S...
# TSFM           Expert Review Green;NHS GMS;South West GLH
# TTN            Expert Review Green;NHS GMS;South West GLH
# TTR            Expert Review Green;NHS GMS;South West GLH
# VCL            Expert Review Green;NHS GMS;South West GLH
#
#                                                Level4          Level3  \
# gene
# ACTC1   Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# MYBPC3  Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# MYH7    Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# TAZ     Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# TNNT2   Left Ventricular Noncompaction Cardiomyopathy  Cardiomyopathy
# ...                                               ...             ...
# TPM1     Cardiomyopathies - including childhood onset             NaN
# TSFM     Cardiomyopathies - including childhood onset             NaN
# TTN      Cardiomyopathies - including childhood onset             NaN
# TTR      Cardiomyopathies - including childhood onset             NaN
# VCL      Cardiomyopathies - including childhood onset             NaN
#
#                           Level2  \
# gene
# ACTC1   Cardiovascular disorders
# MYBPC3  Cardiovascular disorders
# MYH7    Cardiovascular disorders
# TAZ     Cardiovascular disorders
# TNNT2   Cardiovascular disorders
# ...                          ...
# TPM1                         NaN
# TSFM                         NaN
# TTN                          NaN
# TTR                          NaN
# VCL                          NaN
#
#                                      Model_Of_Inheritance  \
# gene
# ACTC1   MONOALLELIC, autosomal or pseudoautosomal, imp...
# MYBPC3  MONOALLELIC, autosomal or pseudoautosomal, imp...
# MYH7    MONOALLELIC, autosomal or pseudoautosomal, imp...
# TAZ     X-LINKED: hemizygous mutation in males, monoal...
# TNNT2   MONOALLELIC, autosomal or pseudoautosomal, imp...
# ...                                                   ...
# TPM1    MONOALLELIC, autosomal or pseudoautosomal, NOT...
# TSFM              BIALLELIC, autosomal or pseudoautosomal
# TTN     MONOALLELIC, autosomal or pseudoautosomal, NOT...
# TTR     MONOALLELIC, autosomal or pseudoautosomal, NOT...
# VCL     MONOALLELIC, autosomal or pseudoautosomal, NOT...
#
#                                                Phenotypes  Omim  Orphanet  \
# gene
# ACTC1   Left ventricular noncompaction 4 ;Left Ventric...   NaN       NaN
# MYBPC3  Left ventricular noncompaction 10, ;Hypertroph...   NaN       NaN
# MYH7    Left ventricular noncompaction 5, OMIM:613426;...   NaN       NaN
# TAZ        Left Ventricular Noncompaction Cardiomyopathy    NaN       NaN
# TNNT2   Left ventricular noncompaction 6, ;Hypertrophi...   NaN       NaN
# ...                                                   ...   ...       ...
# TPM1    Cardiomyopathy, familial hypertrophic, 3;Cardi...   NaN       NaN
# TSFM    Combined oxidative phosphorylation deficiency ...   NaN       NaN
# TTN     Cardiomyopathy, familial hypertrophic, 9,;Card...   NaN       NaN
# TTR                                         syndromic HCM   NaN       NaN
# VCL     Cardiomyopathy, familial hypertrophic, 15,;Car...   NaN       NaN
#
#         ...  phenotype_Venous anomaly phenotype_Pulmonary artery  \
# gene    ...
# ACTC1   ...                         0                          0
# MYBPC3  ...                         0                          0
# MYH7    ...                         0                          0
# TAZ     ...                         0                          0
# TNNT2   ...                         0                          0
# ...     ...                       ...                        ...
# TPM1    ...                         0                          0
# TSFM    ...                         0                          0
# TTN     ...                         0                          0
# TTR     ...                         0                          0
# VCL     ...                         0                          0
#
#         phenotype_Aortic arch  phenotype_Aorta  phenotype_Coronary anomaly  \
# gene
# ACTC1                       0                0                           0
# MYBPC3                      0                0                           0
# MYH7                        0                0                           0
# TAZ                         0                0                           0
# TNNT2                       0                0                           0
# ...                       ...              ...                         ...
# TPM1                        0                0                           0
# TSFM                        0                0                           0
# TTN                         0                0                           0
# TTR                         0                0                           0
# VCL                         0                0                           0
#
#        phenotype_VA valves  phenotype_AV valves  TF    source  \
# gene
# ACTC1                    0                    0   0  PanelApp
# MYBPC3                   0                    0   0  PanelApp
# MYH7                     0                    0   0  PanelApp
# TAZ                      0                    0   0  PanelApp
# TNNT2                    0                    0   0  PanelApp
# ...                    ...                  ...  ..       ...
# TPM1                     0                    0   0  PanelApp
# TSFM                     0                    0   0  PanelApp
# TTN                      0                    0   0  PanelApp
# TTR                      0                    0   0  PanelApp
# VCL                      0                    0   0  PanelApp
#
#                                        granular_phenotype
# gene
# ACTC1   Left ventricular noncompaction 4 ;Left Ventric...
# MYBPC3  Left ventricular noncompaction 10, ;Hypertroph...
# MYH7    Left ventricular noncompaction 5, OMIM:613426;...
# TAZ        Left Ventricular Noncompaction Cardiomyopathy
# TNNT2   Left ventricular noncompaction 6, ;Hypertrophi...
# ...                                                   ...
# TPM1    Cardiomyopathy, familial hypertrophic, 3;Cardi...
# TSFM    Combined oxidative phosphorylation deficiency ...
# TTN     Cardiomyopathy, familial hypertrophic, 9,;Card...
# TTR                                         syndromic HCM
# VCL     Cardiomyopathy, familial hypertrophic, 15,;Car...
#
# [138 rows x 55 columns]

# %%
PanelApp.to_csv('/home/jovyan/data/PanelApp_with_phenotype_annotation.csv')
