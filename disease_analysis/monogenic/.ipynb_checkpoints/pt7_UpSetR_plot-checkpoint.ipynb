# %%
# Plot using UpsetR

# %%
install.packages("UpSetR")
# Out:
# Installing package into ‘/home/jovyan/R/x86_64-pc-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)

# %%
library("UpSetR")
library("repr")
library("tidyverse")
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
options(repr.plot.width=15, repr.plot.height=10)

# %%
df=read.csv('/home/jovyan/data/combined_tidied_disease_gene_with_phenotype_annotation.csv')
head(df,3)
# Out:
#   X     TF source  phenotype_Heterotaxy phenotype_ASD phenotype_VSD
# 1 ABL1  1  CHDgene 0                    1             1
# 2 ACTC1 0  CHDgene 0                    1             1
# 3 ACVR1 0  CHDgene 0                    1             1
#   phenotype_AVSD phenotype_Malformation.of.outflow.tracts
# 1 0              0
# 2 0              0
# 3 1              1
#   phenotype_Functional.single.ventricle phenotype_Cardiomyopathy ⋯
# 1 0                                     0                        ⋯
# 2 0                                     0                        ⋯
# 3 0                                     0                        ⋯
#   phenotype_HCM phenotype_LVNC phenotype_Venous.anomaly
# 1 0             0              0
# 2 0             0              0
# 3 0             0              0
#   phenotype_Pulmonary.artery phenotype_Aortic.arch phenotype_Aorta
# 1 0                          0                     0
# 2 0                          0                     0
# 3 0                          0                     0
#   phenotype_Coronary.anomaly phenotype_VA.valves phenotype_AV.valves
# 1 0                          0                   0
# 2 0                          0                   0
# 3 0                          0                   0
#   phenotype
# 1 Atrial septal defect,Ventricular septal defect
# 2 Atrial septal defect,Ventricular septal defect
# 3 Atrial septal defect,Atrioventricular septal defect,Transposition of the great arteries,Double outlet right ventricle

# %%
cols<-colnames(df)
phen_cols<-grep("phenotype_", cols, value = TRUE)

tmp<-df%>%filter(source=='CHDgene')%>%select(all_of(phen_cols))

names(tmp)<-substring(names(tmp), 11)

tmp<-tmp%>% select_if(colSums(.) != 0)

sets=colnames(tmp)

upset(tmp,
     sets=sets,
     order.by='freq', 
    text.scale = c(2, 1, 2,1, 1.5, 2),
     mainbar.y.label = "Intersection size",
     sets.x.label = "# genes per CHD phenotype",
  point.size = 3,
      line.size = 1)
# Out:
# plot without title
