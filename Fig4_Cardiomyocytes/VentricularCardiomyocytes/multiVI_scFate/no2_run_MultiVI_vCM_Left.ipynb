# %% [markdown]
# ## Import modules

# %%
# this is for the jupyter notebook at JupyterLab
# to make sys.path between the terminal and Jupyter same
import sys

print(sys.path) # especially the path to site-packages are different... so thats why couldn't find correct package...

# sys.path from terminal at scvi0190_env
# obtained by excuting `python -c "import sys; print('\n'.join(sys.path))"`
sys.path = [
    "/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python39.zip",
    "/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9",
    "/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/lib-dynload",
    "/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/site-packages"
]

print(sys.path)
# Out:
# ['/nfs/team205/kk18/Analysis/multiVI/notebooks', '/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python39.zip', '/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9', '/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/lib-dynload', '', '/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/site-packages']
# ['/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python39.zip', '/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9', '/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/lib-dynload', '/nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/site-packages']

# %%
import scvi
import anndata
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt

scvi.settings.seed = 420
# Out:
# Global seed set to 0
# /nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/site-packages/flax/core/frozen_dict.py:169: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(
# /nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)
# Global seed set to 420

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.8.0
# matplotlib          3.7.1
# numpy               1.23.5
# pandas              1.5.3
# scanpy              1.9.3
# scvi                0.19.0
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 9.4.0
# absl                NA
# asttokens           NA
# attr                22.2.0
# backcall            0.2.0
# certifi             2022.12.07
# cffi                1.15.1
# charset_normalizer  3.1.0
# chex                0.1.6
# comm                0.1.2
# contextlib2         NA
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.6
# decorator           5.1.1
# defusedxml          0.7.1
# deprecate           0.3.2
# docrep              0.3.2
# etils               1.1.0
# executing           1.2.0
# flax                0.6.7
# fsspec              2023.3.0
# google              NA
# h5py                3.8.0
# idna                3.4
# igraph              0.10.4
# importlib_metadata  NA
# importlib_resources NA
# ipykernel           6.21.3
# ipython_genutils    0.2.0
# ipywidgets          8.0.4
# jax                 0.4.10
# jaxlib              0.4.10
# jedi                0.18.2
# joblib              1.2.0
# kiwisolver          1.4.4
# leidenalg           0.9.1
# llvmlite            0.39.1
# ml_collections      NA
# ml_dtypes           0.2.0
# mpl_toolkits        NA
# msgpack             1.0.5
# mudata              0.2.1
# multipledispatch    0.6.0
# natsort             8.3.1
# numba               0.56.4
# numpyro             0.11.0
# nvidia              NA
# opt_einsum          v3.3.0
# optax               0.1.4
# packaging           23.0
# parso               0.8.3
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.1.1
# prompt_toolkit      3.0.38
# psutil              5.9.4
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.14.0
# pyparsing           3.0.9
# pyro                1.8.4
# pytorch_lightning   1.7.7
# pytz                2022.7.1
# requests            2.28.2
# rich                NA
# scipy               1.10.1
# setuptools          65.6.3
# six                 1.16.0
# sklearn             1.2.2
# stack_data          0.6.2
# tensorboard         2.12.0
# texttable           1.6.7
# threadpoolctl       3.1.0
# toolz               0.12.0
# torch               1.13.1+cu117
# torchmetrics        0.11.4
# torchvision         0.14.1+cu117
# tornado             6.2
# tqdm                4.65.0
# traitlets           5.9.0
# tree                0.1.8
# typing_extensions   NA
# urllib3             1.26.15
# wcwidth             0.2.6
# yaml                6.0
# zipp                NA
# zmq                 25.0.1
# zoneinfo            NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.11.0
# jupyter_client      8.0.3
# jupyter_core        5.2.0
# notebook            6.5.3
# -----
# Python 3.9.16 (main, Mar  8 2023, 14:00:05) [GCC 11.2.0]
# Linux-4.15.0-213-generic-x86_64-with-glibc2.27
# -----
# Session information updated at 2023-08-15 23:34
# </pre>
# </details>

# %% [markdown]
# ## Read in data

# %%
# paired
# only multiome
adata_mvi = sc.read_h5ad('/nfs/team205/heart/anndata_objects/Foetal/vCM/MultiVI-pre_paired_foetal_vCMs_raw.h5ad')
adata_mvi
# Out:
# AnnData object with n_obs × n_vars = 35705 × 544641
#     obs: 'sangerID', 'combinedID', 'donor', 'region', 'age', 'sex', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'week', 'trimester', 'cycling', 'S_score', 'G2M_score', 'phase', 'fine_grain', 'mid_grain', 'coarse_grain', 'batch_key', 'total_counts', 'total_counts_mt', 'total_counts_ribo', 'n_genes_by_counts', 'pct_counts_mt', 'pct_counts_ribo', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'log1p_total_counts_ribo', 'scrublet_score', 'doublet_pval', 'doublet_bh_pval'
#     var: 'modality', 'gene_name_scRNA-0', 'gene_id', 'seqnames', 'start', 'end', 'width', 'strand', 'score', 'replicateScoreQuantile', 'groupScoreQuantile', 'Reproducibility', 'GroupReplicate', 'distToGeneStart', 'nearestGene', 'peakType', 'distToTSS', 'nearestTSS', 'GC', 'idx', 'N'

# %%
adata_mvi.obs['fine_grain'].value_counts()
# Out:
# VentricularCardiomyocytesRightCompact         12008
# VentricularCardiomyocytesLeftCompact          11397
# VentricularCardiomyocytesLeftTrabeculated      5054
# VentricularCardiomyocytesCycling               4977
# VentricularCardiomyocytesRightTrabeculated     2269
# Name: fine_grain, dtype: int64

# %%
# remove cycling population
adata_mvi = adata_mvi[adata_mvi.obs['fine_grain'].isin([
    'VentricularCardiomyocytesLeftCompact','VentricularCardiomyocytesLeftTrabeculated'
])]
adata_mvi.obs['fine_grain'].value_counts()
# Out:
# VentricularCardiomyocytesLeftCompact         11397
# VentricularCardiomyocytesLeftTrabeculated     5054
# Name: fine_grain, dtype: int64

# %%
adata_mvi.obs
# Out:
#                                                               sangerID  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...   BHF_F_Hea11933669
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...  HCAHeartST13386009
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...   BHF_F_Hea13188324
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...   BHF_F_Hea13188324
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...   BHF_F_Hea13188324
# ...                                                                ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...   BHF_F_Hea11933669
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...   BHF_F_Hea11933667
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...   BHF_F_Hea11933667
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...   BHF_F_Hea11933667
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...   BHF_F_Hea11933668
#
#                                                                                combinedID  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...    BHF_F_Hea11933669_BHF_F_Hea11596622
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...  HCAHeartST13386009_HCAHeartST13303419
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...    BHF_F_Hea13188324_BHF_F_Hea13187626
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...    BHF_F_Hea13188324_BHF_F_Hea13187626
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...    BHF_F_Hea13188324_BHF_F_Hea13187626
# ...                                                                                   ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...    BHF_F_Hea11933669_BHF_F_Hea11596622
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...    BHF_F_Hea11933667_BHF_F_Hea11596620
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...    BHF_F_Hea11933667_BHF_F_Hea11596620
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...    BHF_F_Hea11933667_BHF_F_Hea11596620
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...    BHF_F_Hea11933668_BHF_F_Hea11596621
#
#                                                     donor          region  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...  Hst33    whole sample
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...  Hst41           atria
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...  Hst41  left ventricle
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...  Hst41  left ventricle
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...  Hst41  left ventricle
# ...                                                   ...             ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...  Hst33    whole sample
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...  Hst33    whole sample
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...  Hst33    whole sample
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...  Hst33    whole sample
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...  Hst33    whole sample
#
#                                                       age     sex facility  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...  13W0D  female   Sanger
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...  20W0D    male   Sanger
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...  20W0D    male   Sanger
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...  20W0D    male   Sanger
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...  20W0D    male   Sanger
# ...                                                   ...     ...      ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...  13W0D  female   Sanger
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...  13W0D  female   Sanger
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...  13W0D  female   Sanger
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...  13W0D  female   Sanger
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...  13W0D  female   Sanger
#
#                                                    cell_or_nuclei  modality  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...         nuclei  Multiome
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...         nuclei  Multiome
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...         nuclei  Multiome
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...         nuclei  Multiome
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...         nuclei  Multiome
# ...                                                           ...       ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...         nuclei  Multiome
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...         nuclei  Multiome
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...         nuclei  Multiome
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...         nuclei  Multiome
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...         nuclei  Multiome
#
#                                                         kit_10x  ...  \
# barcode                                                          ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...  Multiome-v1  ...
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...  Multiome-v1  ...
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...  Multiome-v1  ...
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...  Multiome-v1  ...
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...  Multiome-v1  ...
# ...                                                         ...  ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...  Multiome-v1  ...
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...  Multiome-v1  ...
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...  Multiome-v1  ...
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...  Multiome-v1  ...
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...  Multiome-v1  ...
#
#                                                    n_genes_by_counts  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...              2076
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...              2299
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...              1764
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...              1703
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...              1797
# ...                                                              ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...              2090
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...              1083
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...              1876
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...              2390
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...              2432
#
#                                                    pct_counts_mt  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...      1.362089
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...      2.856576
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...      3.310502
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...      0.133298
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...      0.339147
# ...                                                          ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...      0.434333
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...      4.306488
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...      0.133809
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...      3.911770
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...      1.915097
#
#                                                    pct_counts_ribo  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...        1.570185
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...        2.439992
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...        0.742009
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...        0.106638
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...        0.096899
# ...                                                            ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...        0.868666
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...        3.747204
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...        0.356824
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...        1.309667
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...        2.202362
#
#                                                     log1p_n_genes_by_counts  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...                 7.638680
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...                 7.740664
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...                 7.475906
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...                 7.440734
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...                 7.494430
# ...                                                                     ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...                 7.645398
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...                 6.988413
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...                 7.537430
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...                 7.779467
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...                 7.796880
#
#                                                     log1p_total_counts  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...            8.573007
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...            8.525558
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...            8.161945
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...            8.230044
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...            8.325790
# ...                                                                ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...            8.483843
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...            7.489412
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...            8.408494
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...            8.666303
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...            8.743053
#
#                                                    log1p_total_counts_mt  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...              4.290460
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...              4.976734
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...              4.762174
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...              1.791759
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...              2.708050
# ...                                                                  ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...              3.091043
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...              4.356709
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...              1.945910
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...              5.429346
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...              4.795791
#
#                                                    log1p_total_counts_ribo  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...                4.430817
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...                4.820282
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...                3.295837
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...                1.609438
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...                1.609438
# ...                                                                    ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...                3.761200
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...                4.219508
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...                2.833213
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...                4.343805
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...                4.934474
#
#                                                    scrublet_score  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...       0.126360
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...       0.086068
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...       0.118524
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...       0.036697
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...       0.053483
# ...                                                           ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...       0.123762
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...       0.039370
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...       0.025028
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...       0.125926
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...       0.122327
#
#                                                    doublet_pval  \
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...     0.370379
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...     0.219175
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...     0.376974
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...     0.830124
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...     0.814834
# ...                                                         ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...     0.556822
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...     0.851546
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...     0.878757
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...     0.395974
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...     0.395922
#
#                                                    doublet_bh_pval
# barcode
# BHF_F_Hea11933669_BHF_F_Hea11596622_AATTAGCGTTA...        0.881283
# HCAHeartST13386009_HCAHeartST13303419_ATCCTTAGT...        0.733829
# BHF_F_Hea13188324_BHF_F_Hea13187626_CGAGGCAAGGC...        0.932287
# BHF_F_Hea13188324_BHF_F_Hea13187626_TAGTAAGCACA...        0.932287
# BHF_F_Hea13188324_BHF_F_Hea13187626_GTTTAACCACG...        0.932287
# ...                                                            ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_GCCCAAATCAC...        0.881283
# BHF_F_Hea11933667_BHF_F_Hea11596620_CGCAATTAGGT...        0.941734
# BHF_F_Hea11933667_BHF_F_Hea11596620_GCGCTTGCAGG...        0.941734
# BHF_F_Hea11933667_BHF_F_Hea11596620_CTCTTGATCAT...        0.941734
# BHF_F_Hea11933668_BHF_F_Hea11596621_AACTAGCTCTT...        0.925448
#
# [16451 rows x 33 columns]

# %%
adata_mvi.var['modality'].value_counts()
# Out:
# Peaks              508040
# Gene Expression     36601
# Name: modality, dtype: int64

# %%
adata_mvi.obs['modality'].value_counts()
# Out:
# Multiome    16451
# Name: modality, dtype: int64

# %%
# MultiVI requires the features to be ordered, 
# such that genes appear before genomic regions. In this case this is already the case, but it’s always good to verify:
adata_mvi = adata_mvi[:, adata_mvi.var["modality"].argsort()].copy()
adata_mvi.var
# Out:
#                                  modality gene_name_scRNA-0          gene_id  \
# MIR1302-2HG               Gene Expression       MIR1302-2HG  ENSG00000243485
# AL391261.2                Gene Expression        AL391261.2  ENSG00000258847
# FUT8-AS1                  Gene Expression          FUT8-AS1  ENSG00000276116
# FUT8                      Gene Expression              FUT8  ENSG00000033170
# AL355076.2                Gene Expression        AL355076.2  ENSG00000258760
# ...                                   ...               ...              ...
# chr5:177134858_177135358            Peaks               NaN              NaN
# chr5:177134341_177134841            Peaks               NaN              NaN
# chr5:177133469_177133969            Peaks               NaN              NaN
# chr5:177194851_177195351            Peaks               NaN              NaN
# chrX:155881618_155882118            Peaks               NaN              NaN
#
#                          seqnames        start          end  width strand  \
# MIR1302-2HG                   NaN          NaN          NaN    NaN    NaN
# AL391261.2                    NaN          NaN          NaN    NaN    NaN
# FUT8-AS1                      NaN          NaN          NaN    NaN    NaN
# FUT8                          NaN          NaN          NaN    NaN    NaN
# AL355076.2                    NaN          NaN          NaN    NaN    NaN
# ...                           ...          ...          ...    ...    ...
# chr5:177134858_177135358     chr5  177134858.0  177135358.0  501.0      *
# chr5:177134341_177134841     chr5  177134341.0  177134841.0  501.0      *
# chr5:177133469_177133969     chr5  177133469.0  177133969.0  501.0      *
# chr5:177194851_177195351     chr5  177194851.0  177195351.0  501.0      *
# chrX:155881618_155882118     chrX  155881618.0  155882118.0  501.0      *
#
#                              score  replicateScoreQuantile  ...  \
# MIR1302-2HG                    NaN                     NaN  ...
# AL391261.2                     NaN                     NaN  ...
# FUT8-AS1                       NaN                     NaN  ...
# FUT8                           NaN                     NaN  ...
# AL355076.2                     NaN                     NaN  ...
# ...                            ...                     ...  ...
# chr5:177134858_177135358   1.95268                   0.052  ...
# chr5:177134341_177134841  18.50900                   0.959  ...
# chr5:177133469_177133969  35.92410                   0.997  ...
# chr5:177194851_177195351   2.30598                   0.311  ...
# chrX:155881618_155882118   8.37732                   0.673  ...
#
#                           Reproducibility  \
# MIR1302-2HG                           NaN
# AL391261.2                            NaN
# FUT8-AS1                              NaN
# FUT8                                  NaN
# AL355076.2                            NaN
# ...                                   ...
# chr5:177134858_177135358              2.0
# chr5:177134341_177134841              2.0
# chr5:177133469_177133969              3.0
# chr5:177194851_177195351              2.0
# chrX:155881618_155882118              2.0
#
#                                                       GroupReplicate  \
# MIR1302-2HG                                                      NaN
# AL391261.2                                                       NaN
# FUT8-AS1                                                         NaN
# FUT8                                                             NaN
# AL355076.2                                                       NaN
# ...                                                              ...
# chr5:177134858_177135358                       Megakaryocytes._.Rep2
# chr5:177134341_177134841                            MastCells._.Rep2
# chr5:177133469_177133969                            Monocytes._.Rep3
# chr5:177194851_177195351  VentricularConductionSystemProximal._.Rep2
# chrX:155881618_155882118     CoronaryArterialEndothelialCells._.Rep1
#
#                          distToGeneStart  nearestGene  peakType distToTSS  \
# MIR1302-2HG                          NaN          NaN       NaN       NaN
# AL391261.2                           NaN          NaN       NaN       NaN
# FUT8-AS1                             NaN          NaN       NaN       NaN
# FUT8                                 NaN          NaN       NaN       NaN
# AL355076.2                           NaN          NaN       NaN       NaN
# ...                                  ...          ...       ...       ...
# chr5:177134858_177135358          2082.0         NSD1    Exonic     878.0
# chr5:177134341_177134841          1565.0         NSD1  Intronic     361.0
# chr5:177133469_177133969           693.0         NSD1  Intronic      78.0
# chr5:177194851_177195351         62075.0         NSD1  Intronic   17009.0
# chrX:155881618_155882118        211923.0        TMLHE    Distal     489.0
#
#                           nearestTSS      GC      idx    N
# MIR1302-2HG                      NaN     NaN      NaN  NaN
# AL391261.2                       NaN     NaN      NaN  NaN
# FUT8-AS1                         NaN     NaN      NaN  NaN
# FUT8                             NaN     NaN      NaN  NaN
# AL355076.2                       NaN     NaN      NaN  NaN
# ...                              ...     ...      ...  ...
# chr5:177134858_177135358  uc063kbv.1  0.4711  26270.0  0.0
# chr5:177134341_177134841  uc063kbv.1  0.6647  26269.0  0.0
# chr5:177133469_177133969  uc003mfq.4  0.7824  26268.0  0.0
# chr5:177194851_177195351  uc063kbw.1  0.4731  26281.0  0.0
# chrX:155881618_155882118  uc004fnt.4  0.4311   8525.0  0.0
#
# [544641 rows x 21 columns]

# %% [markdown]
# ## Setup and training MultiVI (with continuous covariates)

# %% [markdown]
# ### All region, add 'region' key as a covariate

# %%
adata_mvi_sub = adata_mvi.copy()

# %%
# We also filter features to remove those that appear in fewer than 1% of the cells
print(adata_mvi_sub.shape)
sc.pp.filter_genes(adata_mvi_sub, min_cells=int(adata_mvi_sub.shape[0] * 0.01))
print(adata_mvi_sub.shape)
# Out:
# (16451, 544641)
# (16451, 174604)

# %%
adata_mvi_sub.var['modality'].value_counts()
# Out:
# Peaks              161398
# Gene Expression     13206
# Name: modality, dtype: int64

# %%
adata_mvi_sub.obs['modality'].value_counts()
# Out:
# Multiome    16451
# Name: modality, dtype: int64

# %%
pd.crosstab(adata_mvi_sub.obs['batch_key'],adata_mvi_sub.obs['region'])
# Out:
# region                    apex  atria  atrial septum  whole sample  \
# batch_key
# C82_Nuclei_Multiome-v1       0      0              0            27
# C85_Nuclei_Multiome-v1       0      0              0           121
# C87_Nuclei_Multiome-v1       0      0              0           735
# C92_Nuclei_Multiome-v1       0      0              0           186
# C98_Nuclei_Multiome-v1       0      0              0           233
# C104_Nuclei_Multiome-v1    290      0              0             0
# Hst33_Nuclei_Multiome-v1     0      0              0          9170
# Hst36_Nuclei_Multiome-v1     0      0              0          1254
# Hst39_Nuclei_Multiome-v1     0      0              0             0
# Hst40_Nuclei_Multiome-v1     0      0              0             0
# Hst41_Nuclei_Multiome-v1     0    289             14             0
#
# region                    heart without node  left ventricle  node  \
# batch_key
# C82_Nuclei_Multiome-v1                     0               0     0
# C85_Nuclei_Multiome-v1                     0               0     0
# C87_Nuclei_Multiome-v1                     0               0     0
# C92_Nuclei_Multiome-v1                     0               0     0
# C98_Nuclei_Multiome-v1                     0               0     0
# C104_Nuclei_Multiome-v1                    0               0     0
# Hst33_Nuclei_Multiome-v1                   0               0     0
# Hst36_Nuclei_Multiome-v1                   0               0     0
# Hst39_Nuclei_Multiome-v1                1107               0     0
# Hst40_Nuclei_Multiome-v1                 822               0     6
# Hst41_Nuclei_Multiome-v1                   0            1498     0
#
# region                    outflow tract  right ventricle  \
# batch_key
# C82_Nuclei_Multiome-v1                0                0
# C85_Nuclei_Multiome-v1                0                0
# C87_Nuclei_Multiome-v1                0                0
# C92_Nuclei_Multiome-v1                0                0
# C98_Nuclei_Multiome-v1                0                0
# C104_Nuclei_Multiome-v1              85                0
# Hst33_Nuclei_Multiome-v1              0                0
# Hst36_Nuclei_Multiome-v1              0                0
# Hst39_Nuclei_Multiome-v1              0                0
# Hst40_Nuclei_Multiome-v1              0                0
# Hst41_Nuclei_Multiome-v1              0              343
#
# region                    right ventricle and papillaries
# batch_key
# C82_Nuclei_Multiome-v1                                  0
# C85_Nuclei_Multiome-v1                                  0
# C87_Nuclei_Multiome-v1                                  0
# C92_Nuclei_Multiome-v1                                  0
# C98_Nuclei_Multiome-v1                                  0
# C104_Nuclei_Multiome-v1                                 0
# Hst33_Nuclei_Multiome-v1                                0
# Hst36_Nuclei_Multiome-v1                                0
# Hst39_Nuclei_Multiome-v1                                0
# Hst40_Nuclei_Multiome-v1                                0
# Hst41_Nuclei_Multiome-v1                              271

# %%
scvi.model.MULTIVI.setup_anndata(adata_mvi_sub, batch_key='modality',
                                categorical_covariate_keys=['batch_key','region'], ### adding 'region' ###
                                continuous_covariate_keys=['total_counts','pct_counts_mt','pct_counts_ribo',
                                                          'S_score','G2M_score'])
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
# When creating the object, we need to specify how many of the features are genes, and how many are genomic regions. 
# This is so MultiVI can determine the exact architecture for each modality.
mvi = scvi.model.MULTIVI(
    adata_mvi_sub,
    n_genes=(adata_mvi_sub.var['modality']=='Gene Expression').sum(),
    n_regions=(adata_mvi_sub.var['modality']=='Peaks').sum(),
)
mvi.view_anndata_setup()
# Out:
# /nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/site-packages/torch/nn/init.py:405: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Anndata setup with scvi-tools version 0.19.0.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Setup via `MULTIVI.setup_anndata` with arguments:
# {
# │   'layer': None,
# │   'batch_key': 'modality',
# │   'size_factor_key': None,
# │   'categorical_covariate_keys': ['batch_key', 'region'],
# │   'continuous_covariate_keys': ['total_counts', 'pct_counts_mt', 'pct_counts_ribo', 'S_score', 'G2M_score'],
# │   'protein_expression_obsm_key': None,
# │   'protein_names_uns_key': None
# }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#          Summary Statistics
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃     Summary Stat Key     ┃ Value  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │         n_batch          │   1    │
# │         n_cells          │ 16451  │
# │ n_extra_categorical_covs │   2    │
# │ n_extra_continuous_covs  │   5    │
# │         n_labels         │   1    │
# │          n_vars          │ 174604 │
# └──────────────────────────┴────────┘
#                              Data Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Registry Key      ┃            scvi-tools Location             ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │           X            │                  adata.X                   │
# │         batch          │          adata.obs['_scvi_batch']          │
# │ extra_categorical_covs │ adata.obsm['_scvi_extra_categorical_covs'] │
# │ extra_continuous_covs  │ adata.obsm['_scvi_extra_continuous_covs']  │
# │         ind_x          │           adata.obs['_indices']            │
# │         labels         │         adata.obs['_scvi_labels']          │
# └────────────────────────┴────────────────────────────────────────────┘
#                     batch State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃    Source Location    ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['modality'] │  Multiome  │          0          │
# └───────────────────────┴────────────┴─────────────────────┘
#                      labels State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_labels'] │     0      │          0          │
# └───────────────────────────┴────────────┴─────────────────────┘
#                     batch State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃    Source Location    ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['modality'] │  Multiome  │          0          │
# └───────────────────────┴────────────┴─────────────────────┘
#                       extra_categorical_covs State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃    Source Location     ┃           Categories            ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['batch_key'] │     C82_Nuclei_Multiome-v1      │          0          │
# │                        │     C85_Nuclei_Multiome-v1      │          1          │
# │                        │     C87_Nuclei_Multiome-v1      │          2          │
# │                        │     C92_Nuclei_Multiome-v1      │          3          │
# │                        │     C98_Nuclei_Multiome-v1      │          4          │
# │                        │     C104_Nuclei_Multiome-v1     │          5          │
# │                        │    Hst33_Nuclei_Multiome-v1     │          6          │
# │                        │    Hst36_Nuclei_Multiome-v1     │          7          │
# │                        │    Hst39_Nuclei_Multiome-v1     │          8          │
# │                        │    Hst40_Nuclei_Multiome-v1     │          9          │
# │                        │    Hst41_Nuclei_Multiome-v1     │         10          │
# │                        │                                 │                     │
# │  adata.obs['region']   │              apex               │          0          │
# │                        │              atria              │          1          │
# │                        │          atrial septum          │          2          │
# │                        │          whole sample           │          3          │
# │                        │       heart without node        │          4          │
# │                        │         left ventricle          │          5          │
# │                        │              node               │          6          │
# │                        │          outflow tract          │          7          │
# │                        │         right ventricle         │          8          │
# │                        │ right ventricle and papillaries │          9          │
# │                        │                                 │                     │
# └────────────────────────┴─────────────────────────────────┴─────────────────────┘
#   extra_continuous_covs State
#             Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃       Source Location        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  adata.obs['total_counts']   │
# │  adata.obs['pct_counts_mt']  │
# │ adata.obs['pct_counts_ribo'] │
# │     adata.obs['S_score']     │
# │    adata.obs['G2M_score']    │
# └──────────────────────────────┘

# %%
mvi.train()
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /nfs/team205/kk18/miniconda3/envs/scvi0190_env/lib/python3.9/site-packages/pytorch_lightning/trainer/configuration_validator.py:267: LightningDeprecationWarning: The `Callback.on_epoch_end` hook was deprecated in v1.6 and will be removed in v1.8. Please use `Callback.on_<train/validation/test>_epoch_end` instead.
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 269/500:  54%|██████████████████████                   | 269/500 [1:57:00<1:40:28, 26.10s/it, loss=1.42e+04, v_num=1]
# Monitored metric reconstruction_loss_validation did not improve in the last 50 records. Best score: 30056.787. Signaling Trainer to stop.

# %%
mvi.save("/nfs/team205/heart/anndata_objects/Foetal/vCM/MultiVI-model_foetal_vCM_onlyMultiome_allregion_onlyLeft_feature-select-001")

# %%
adata_mvi_sub.obsm["MultiVI_latent"] = mvi.get_latent_representation()

# %%
adata_mvi_sub.write('/nfs/team205/heart/anndata_objects/Foetal/vCM/MultiVI-post_foetal_vCM_onlyMultiome_allregion_onlyLeft_feature-select-001.h5ad')

# %%
# Convergency plot
mvi.history['elbo_train']
x = np.linspace(1, (len(mvi.history['elbo_train'])), (len(mvi.history['elbo_train'])))
plt.plot(x, mvi.history['elbo_train'], label="train")
plt.xlabel('epoch')
plt.ylabel('elbo_train')
plt.show()
