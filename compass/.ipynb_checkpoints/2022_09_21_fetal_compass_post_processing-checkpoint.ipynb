# %% [markdown]
# # Processing Compass Outs

# %% [markdown]
# # References
# https://yoseflab.github.io/Compass/notebooks/Demo-micropools.html
#
# https://yoseflab.github.io/Compass/notebooks/Demo.html

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import statsmodels
import scipy
import matplotlib.pyplot as plt
from matplotlib import __version__ as matplotlibversion
if matplotlibversion < "3.4":
    print("Matplotlib versions older than 3.4 may not be able to generate figure 2E, as they do not support alpha arrays")
    
from scipy.stats import wilcoxon, mannwhitneyu, ranksums
from statsmodels.stats.multitest import multipletests
import scipy.cluster.hierarchy as hcluster
from scipy.spatial.distance import squareform

# %%
def cohens_d(x, y):
    pooled_std = np.sqrt(((len(x)-1) * np.var(x, ddof=1) 
                          + (len(y)-1) * np.var(y, ddof=1)) / 
                             (len(x) + len(y) - 2))
    return (np.mean(x) - np.mean(y)) / pooled_std
    

def wilcoxon_test(consistencies_matrix, group_A_cells, group_B_cells):
	"""
		Performs an unpaired wilcoxon test (or mann-whitney U test) for each reaction between group_A and group_B
	"""
	#per reaction/meta-reaction, conduct wilcoxon test between group_A and group_B
	group_A = consistencies_matrix.loc[:,group_A_cells]
	group_B = consistencies_matrix.loc[:,group_B_cells]
	results = pd.DataFrame(index = consistencies_matrix.index, columns = ['wilcox_stat', 'wilcox_pval', 'cohens_d'], dtype='float64')
	for rxn in consistencies_matrix.index:
		A, B = group_A.loc[rxn].to_numpy().ravel(), group_B.loc[rxn].to_numpy().ravel()
		#sometimes there's a solitary value, and we don't want to test then
		if len(np.unique(A)) == 1 and len(np.unique(B)) == 1:
			if np.unique(A) == np.unique(B):
				#we've got no data. set p-value to 1 and skip!
				#(p-value needs to be 1 so multipletests doesn't cry)
				results.loc[rxn, ['wilcox_pval']] = 1
				continue
		stat, pval = mannwhitneyu(A, B, alternative='two-sided')
		c_d = cohens_d(A, B)
		results.loc[rxn, ['wilcox_stat', 'wilcox_pval', 'cohens_d']] = stat, pval, c_d
	results['adjusted_pval'] = np.array(multipletests(results['wilcox_pval'], method='fdr_bh')[1], dtype='float64')
	return results

def get_reaction_consistencies(compass_reaction_penalties, min_range=1e-3):
    """
        Converts the raw penalties outputs of compass into scores per reactions where higher numbers indicate more activity
    """
    df = -np.log(compass_reaction_penalties + 1)
    df = df[df.max(axis=1) - df.min(axis=1) >= min_range]
    df = df - df.min().min()
    return df

def get_metareactions(reactions, height=0.02):
    """
        Returns an array of metareaction labels for each reaction
        Index k in the returned array has the metareaction label for reaction k.
    """
    #pairwise_reaction_correlations = reactions.T.corr(method='spearman') #Pandas method here is orders of magnitude slower
    pairwise_reaction_correlations = np.corrcoef(reactions.rank(axis=1))
    #Unfortunately due to floating point issues, these matrices are not always perfectly symmetric and the diagonal may be slightly off from 1
    pairwise_reaction_correlations[np.arange(reactions.shape[0]), np.arange(reactions.shape[0])] = 1.0
    pairwise_reaction_correlations = (pairwise_reaction_correlations + pairwise_reaction_correlations.T)/2
    assert(np.all(pairwise_reaction_correlations == pairwise_reaction_correlations.T))

    Z = hcluster.complete(squareform(1 - pairwise_reaction_correlations))
    return hcluster.fcluster(Z, height, criterion='distance')

labeled_reactions = {
    "PGM_neg" : "phosphoglycerate mutase (PGAM)",
    "LDH_L_neg" : "lactate dehydrogenase",
    "PDHm_pos" : "pyruvate dehydrogenase (PDH)",
    "TPI_neg" : "triosephosphate isomerase (DHAP forming)",
    "FACOAL1821_neg" : "long-chain fatty-acid-CoA ligase",
    "r1257_pos" : "long-chain fatty-acid-CoA ligase",
    "FACOAL1831_neg" : "long-chain fatty-acid-CoA ligase",
    "CSNATr_neg" : "carnitine O-acetyltransferase",
    "C160CPT1_pos" : "carnitine O-palmitoyltransferase",
    "ACONTm_pos" : "aconitate hydratase",
    "SUCOASm_pos" : "succinate-CoA ligase",
    "AKGDm_pos" : "alpha-ketoglutarate dehydrogenase",
    "SUCD1m_pos" : "succinate dehydrogenase",
    "ICDHyrm_pos" : "isocitrate dehydrogenase",
    "CK_pos" : "creatine\nkinase",
    "PGCD_pos" : "phosphoglycerate dehydrogenase",
    "ARGSS_pos" : "arginosuccinate synthase",
    "r0281_neg" : "putrescine diamine oxidase",
    "SPMDOX_pos" : "spermidine dehydrogenase (spermidine -> GABA)",
    "ARGDCm_pos" : "arginine decarboxylase",
    "AGMTm_pos" : "agmatinase",
    "GHMT2r_pos" : "serine hydroxymethyltransferase",
    "AHC_pos" : "adenosylhomocysteinase",
    "METAT_pos" : "methionine adenosyltransferase",
    "METS_pos" : "methionine\nsynthase",
    "ARGN_pos" : "arginase"
}

amino_acid_metab = ["Alanine and aspartate metabolism",
            "Arginine and Proline Metabolism",
            "beta-Alanine metabolism",
            "Cysteine Metabolism",
            "D-alanine metabolism",
            "Folate metabolism",
            "Glutamate metabolism",
            "Glycine, serine, alanine and threonine metabolism",
            "Histidine metabolism",
            "Lysine metabolism",
            "Methionine and cysteine metabolism",
            "Taurine and hypotaurine metabolism",
            "Tryptophan metabolism",
            "Tyrosine metabolism",
            "Urea cycle",
            "Valine, leucine, and isoleucine metabolism"]

def plot_differential_scores(data, title, c):
    plt.figure(figsize=(10,10))
    axs = plt.gca()
    axs.scatter(data['cohens_d'], -np.log10(data['adjusted_pval']), c=c)
    axs.set_xlabel("Cohen's d", fontsize=16)
    axs.set_ylabel("-log10 (Wilcoxon-adjusted p)", fontsize=16)
    #Everything after this should be tweaked depending on your application
    axs.set_xlim(-2.2, 2.2)
    axs.axvline(0, dashes=(3,3), c='black')
    axs.axhline(1, dashes=(3,3), c='black')
    axs.set_title(title, fontdict={'fontsize':20})
    axs.annotate('', xy=(0.5, -0.08), xycoords='axes fraction', xytext=(0, -0.08),
            arrowprops=dict(arrowstyle="<-", color='#348C73', linewidth=4))
    axs.annotate(cellA, xy=(0.75, -0.12), xycoords='axes fraction', fontsize=10)
    axs.annotate('', xy=(0.5, -0.08), xycoords='axes fraction', xytext=(1, -0.08),
            arrowprops=dict(arrowstyle="<-", color='#E92E87', linewidth=4))
    axs.annotate(cellB, xy=(0.25, -0.12), xycoords='axes fraction', fontsize=10)
    for r in data.index:
        if r in labeled_reactions:
            x = data.loc[r, 'cohens_d']
            y = -np.log10(data.loc[r, 'adjusted_pval'])
            offset = (20, 0)
            if x < 0:
                offset = (-100, -40)
            axs.annotate(labeled_reactions[r], (x,y), xytext = offset,
                         textcoords='offset pixels', arrowprops={'arrowstyle':"-"})

# %% [markdown]
# # Match cell types to micropools

# %%
cell_md = pd.read_csv('/nfs/team205/heart/compass/fetal_allCM/cell_metadata.csv', index_col = 0)
micropools = pd.read_csv('/nfs/team205/heart/compass/fetal_allCM/out/micropools.tsv', index_col = 0, sep ='\t')

# %%
df=pd.merge(cell_md, micropools, left_index=True, right_index=True).sort_values(by=['microcluster'])
df.head(3)
# Out:
#                                                       coarse_grain  \
# BHF_F_Hea11933665_BHF_F_Hea11596618_TGCCATTGTAC...  Cardiomyocytes
# BHF_F_Hea11933665_BHF_F_Hea11596618_TATGGTCAGCA...  Cardiomyocytes
# BHF_F_Hea11933667_BHF_F_Hea11596620_TTAGCCTGTTG...  Cardiomyocytes
#
#                                                                                fine_grain  \
# BHF_F_Hea11933665_BHF_F_Hea11596618_TGCCATTGTAC...  VentricularCardiomyocytesTrabeculated
# BHF_F_Hea11933665_BHF_F_Hea11596618_TATGGTCAGCA...       VentricularCardiomyocytesCompact
# BHF_F_Hea11933667_BHF_F_Hea11596620_TTAGCCTGTTG...       VentricularCardiomyocytesCompact
#
#                                                     microcluster
# BHF_F_Hea11933665_BHF_F_Hea11596618_TGCCATTGTAC...             0
# BHF_F_Hea11933665_BHF_F_Hea11596618_TATGGTCAGCA...             0
# BHF_F_Hea11933667_BHF_F_Hea11596620_TTAGCCTGTTG...             0

# %%
df['fine_grain'].unique().tolist()
# Out:
# ['VentricularCardiomyocytesTrabeculated',
#  'VentricularCardiomyocytesCompact',
#  'VentricularCardiomyocytesCycling',
#  'VentricularCardiomyocytesPRRX1pos',
#  'VentricularConductionSystemDistal',
#  'VentricularConductionSystemProximal',
#  'Cardiofibromyocytes',
#  'AtrialCardiomyocytesRight',
#  'AtrialCardiomyocytesLeft',
#  'AtrioventricularNodeCardiomyocytes',
#  'SinoatrialNodeCardiomyocytes',
#  'AtrialCardiomyocytesCycling']

# %%
# for each cluster find out which is the commonest cell type and what its % is
clusters=[]
modes=[]
pct=[]

for i in df['microcluster'].unique().tolist():
    clusters.append('cluster_'+str(i))
    mode=df['fine_grain'][df['microcluster']==i].mode()[0]
    modes.append(mode)
    pct.append(len(df['fine_grain'][(df['microcluster']==i)&(df['fine_grain']==mode)])/(len(df['fine_grain'][(df['microcluster']==i)&(df['fine_grain']==mode)])+len(df['fine_grain'][(df['microcluster']==i)&(df['fine_grain']!=mode)])))

# %%
micropool_md = {'microclusters':clusters,
      'modal cell state': modes,
      'percentage': pct,
     }
micropool_md=pd.DataFrame.from_dict(micropool_md)
micropool_md=micropool_md.set_index('microclusters')

# %%
micropool_md['percentage'].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
micropool_md[(micropool_md['percentage']>0.8)]
# Out:
#                                     modal cell state  percentage
# microclusters
# cluster_3           VentricularCardiomyocytesCompact    0.861111
# cluster_7           VentricularCardiomyocytesCompact    0.909091
# cluster_8           VentricularCardiomyocytesCompact    0.809524
# cluster_10          VentricularCardiomyocytesCycling    0.833333
# cluster_11     VentricularCardiomyocytesTrabeculated    0.900000
# ...                                              ...         ...
# cluster_3232                     Cardiofibromyocytes    1.000000
# cluster_3233                     Cardiofibromyocytes    1.000000
# cluster_3234                     Cardiofibromyocytes    1.000000
# cluster_3235                     Cardiofibromyocytes    1.000000
# cluster_3236                     Cardiofibromyocytes    1.000000
#
# [1531 rows x 2 columns]

# %%
# save this metadata output
micropool_md.to_csv('/nfs/team205/heart/compass/fetal_allCM/cluster_metadata.csv')

# %%
cell_states = micropool_md['modal cell state'].unique()

for cell_state in cell_states:
    print(cell_state+'_'+str(len(micropool_md[micropool_md['modal cell state']==cell_state])))
# Out:
# VentricularCardiomyocytesCompact_690
# VentricularCardiomyocytesCycling_555
# VentricularConductionSystemProximal_35
# VentricularCardiomyocytesTrabeculated_334
# VentricularCardiomyocytesPRRX1pos_585
# VentricularConductionSystemDistal_65
# Cardiofibromyocytes_266
# AtrioventricularNodeCardiomyocytes_30
# AtrialCardiomyocytesLeft_323
# AtrialCardiomyocytesRight_280
# SinoatrialNodeCardiomyocytes_43
# AtrialCardiomyocytesCycling_31

# %% [markdown]
# # Generate reaction consistencies
#
# The numbers in the reactions tsv correspond to penalties for each reaction per cell, so we take the negative log to get scores that are higher the more active the reaction is predicted to be. This also drops reactions that are close to constant and therefore not informative for the comparison.

# %%
reaction_penalties = pd.read_csv("/nfs/team205/heart/compass/fetal_allCM/out/reactions.tsv", sep="\t", index_col = 0)
reaction_penalties
# Out:
#                             cluster_0     cluster_1     cluster_2  \
# 10FTHF5GLUtl_pos          4367.912561   4422.962762   4330.323057
# 10FTHF5GLUtm_pos          5889.371696   5914.088558   5771.428474
# 10FTHF6GLUtl_pos          5480.053029   5565.703557   5419.228580
# 10FTHF6GLUtm_pos          6427.426661   6446.283477   6224.444303
# 10FTHF7GLUtl_pos          6097.817173   6231.143196   5966.811897
# ...                               ...           ...           ...
# sink_pre_prot(r)_pos         0.000000      0.000000      0.000000
# sink_tetdec2coa(c)_neg   20273.686958  21038.578934  20445.479157
# sink_tetdec2coa(c)_pos       0.000000      0.000000      0.000000
# sink_tetdece1coa(c)_neg  20273.686958  21038.578934  20445.479157
# sink_tetdece1coa(c)_pos      0.000000      0.000000      0.000000
#
#                             cluster_3     cluster_4     cluster_5  \
# 10FTHF5GLUtl_pos          4408.916141   4428.410747   4368.772515
# 10FTHF5GLUtm_pos          5766.265284   5813.229751   5907.162337
# 10FTHF6GLUtl_pos          5492.909212   5569.559207   5481.483864
# 10FTHF6GLUtm_pos          6229.643250   6284.305886   6442.883124
# 10FTHF7GLUtl_pos          6037.375552   6127.890983   6219.709361
# ...                               ...           ...           ...
# sink_pre_prot(r)_pos         0.000000      0.000000      0.000000
# sink_tetdec2coa(c)_neg   20412.043525  20443.135551  20751.784780
# sink_tetdec2coa(c)_pos       0.000000      0.000000      0.000000
# sink_tetdece1coa(c)_neg  20412.043525  20443.135551  20751.784780
# sink_tetdece1coa(c)_pos      0.000000      0.000000      0.000000
#
#                             cluster_6     cluster_7     cluster_8  \
# 10FTHF5GLUtl_pos          4381.035055   4430.142619   4464.118169
# 10FTHF5GLUtm_pos          5742.485166   5793.006151   5861.129548
# 10FTHF6GLUtl_pos          5468.331233   5549.363617   5605.428628
# 10FTHF6GLUtm_pos          6165.342886   6263.269104   6341.890542
# 10FTHF7GLUtl_pos          6000.682850   6105.206044   6175.072581
# ...                               ...           ...           ...
# sink_pre_prot(r)_pos         0.000000      0.000000      0.000000
# sink_tetdec2coa(c)_neg   20610.700223  20310.995220  20525.566700
# sink_tetdec2coa(c)_pos       0.000000      0.000000      0.000000
# sink_tetdece1coa(c)_neg  20610.700223  20310.995220  20525.566700
# sink_tetdece1coa(c)_pos      0.000000      0.000000      0.000000
#
#                             cluster_9  ...  cluster_3227  cluster_3228  \
# 10FTHF5GLUtl_pos          4353.807899  ...   4270.381459   4369.037541
# 10FTHF5GLUtm_pos          5690.660417  ...   5738.277107   5971.450720
# 10FTHF6GLUtl_pos          5432.984866  ...   5323.252771   5478.669825
# 10FTHF6GLUtm_pos          6125.650511  ...   6161.737053   6401.203844
# 10FTHF7GLUtl_pos          5963.550623  ...   5940.952443   6034.926074
# ...                               ...  ...           ...           ...
# sink_pre_prot(r)_pos         0.000000  ...      0.000000      0.000000
# sink_tetdec2coa(c)_neg   20254.318055  ...  20429.204559  21238.394088
# sink_tetdec2coa(c)_pos       0.000000  ...      0.000000      0.000000
# sink_tetdece1coa(c)_neg  20254.318055  ...  20429.204559  21238.394088
# sink_tetdece1coa(c)_pos      0.000000  ...      0.000000      0.000000
#
#                          cluster_3229  cluster_3230  cluster_3231  \
# 10FTHF5GLUtl_pos          4503.984510   4287.044356   4396.187989
# 10FTHF5GLUtm_pos          6313.687760   5863.808195   6082.288725
# 10FTHF6GLUtl_pos          5694.416026   5347.610314   5523.076919
# 10FTHF6GLUtm_pos          6842.304815   6286.895589   6515.825386
# 10FTHF7GLUtl_pos          6431.528219   5943.606879   6169.228419
# ...                               ...           ...           ...
# sink_pre_prot(r)_pos         0.000000      0.000000      0.000000
# sink_tetdec2coa(c)_neg   22127.215459  20720.740474  21241.419847
# sink_tetdec2coa(c)_pos       0.000000      0.000000      0.000000
# sink_tetdece1coa(c)_neg  22127.215459  20720.740474  21241.419847
# sink_tetdece1coa(c)_pos      0.000000      0.000000      0.000000
#
#                          cluster_3232  cluster_3233  cluster_3234  \
# 10FTHF5GLUtl_pos          4291.998118   4598.660367   4206.697038
# 10FTHF5GLUtm_pos          5936.891713   6555.336347   5735.954809
# 10FTHF6GLUtl_pos          5355.382715   5848.405276   5219.300413
# 10FTHF6GLUtm_pos          6322.591819   7125.651626   6112.389664
# 10FTHF7GLUtl_pos          5885.517378   6680.329306   5756.327904
# ...                               ...           ...           ...
# sink_pre_prot(r)_pos         0.000000      0.000000      0.000000
# sink_tetdec2coa(c)_neg   20968.104979  21357.147094  20458.136087
# sink_tetdec2coa(c)_pos       0.000000      0.000000      0.000000
# sink_tetdece1coa(c)_neg  20968.104979  21357.147094  20458.136087
# sink_tetdece1coa(c)_pos      0.000000      0.000000      0.000000
#
#                          cluster_3235  cluster_3236
# 10FTHF5GLUtl_pos          4283.651985   4427.460546
# 10FTHF5GLUtm_pos          5908.291817   6078.768235
# 10FTHF6GLUtl_pos          5342.859670   5572.359716
# 10FTHF6GLUtm_pos          6308.835878   6535.751224
# 10FTHF7GLUtl_pos          5948.679847   6229.598201
# ...                               ...           ...
# sink_pre_prot(r)_pos         0.000000      0.000000
# sink_tetdec2coa(c)_neg   20511.112240  21500.841078
# sink_tetdec2coa(c)_pos       0.000000      0.000000
# sink_tetdece1coa(c)_neg  20511.112240  21500.841078
# sink_tetdece1coa(c)_pos      0.000000      0.000000
#
# [10211 rows x 3237 columns]

# %%
# this is a reference file - not specific to each run of Compass
reaction_metadata = pd.read_csv("/home/jovyan/COMPASSResources/reaction_metadata.csv", index_col = 0)
reaction_metadata
# Out:
#                                                     reaction_name  \
# reaction_no_direction
# 10FTHF5GLUtl               5-glutamyl-10FTHF transport, lysosomal
# 10FTHF5GLUtm           5-glutamyl-10FTHF transport, mitochondrial
# 10FTHF6GLUtl               6-glutamyl-10FTHF transport, lysosomal
# 10FTHF6GLUtm           6-glutamyl-10FTHF transport, mitochondrial
# 10FTHF7GLUtl               7-glutamyl-10FTHF transport, lysosomal
# ...                                                           ...
# MAL_Lte                                     Transport of L-malate
# OROTGLUt                                                 OROTGLUt
# PNTOte                              Transport of (R)-Pantothenate
# IDOURte                      L-iduronate transport, extracellular
# EX_idour(e)                               Exchange of L-iduronate
#
#                                                                  formula  \
# reaction_no_direction
# 10FTHF5GLUtl           1.00 * 10-formyltetrahydrofolate-[Glu](5) [c] ...
# 10FTHF5GLUtm           1.00 * 10-formyltetrahydrofolate-[Glu](5) [m] ...
# 10FTHF6GLUtl           1.00 * 10-formyltetrahydrofolate-[Glu](6) [c] ...
# 10FTHF6GLUtm           1.00 * 10-formyltetrahydrofolate-[Glu](6) [m] ...
# 10FTHF7GLUtl           1.00 * 10-formyltetrahydrofolate-[Glu](7) [c] ...
# ...                                                                  ...
# MAL_Lte                1.00 * (S)-malate(2-) [e] --> 1.00 * (S)-malat...
# OROTGLUt               1.00 * L-glutamate(1-) [c] + 1.00 * Orotate [e...
# PNTOte                 1.00 * (R)-Pantothenate [e] --> 1.00 * (R)-Pan...
# IDOURte                1.00 * L-iduronate [e] --> 1.00 * L-iduronate ...
# EX_idour(e)                       1.00 * L-iduronate [e] --> ϕ\nNo genes
#
#                       associated_genes                 subsystem EC_number  \
# reaction_no_direction
# 10FTHF5GLUtl                       NaN      Transport, lysosomal       NaN
# 10FTHF5GLUtm                       NaN  Transport, mitochondrial       NaN
# 10FTHF6GLUtl                       NaN      Transport, lysosomal       NaN
# 10FTHF6GLUtm                       NaN  Transport, mitochondrial       NaN
# 10FTHF7GLUtl                       NaN      Transport, lysosomal       NaN
# ...                                ...                       ...       ...
# MAL_Lte                            NaN  Transport, extracellular       NaN
# OROTGLUt                       SLC22A7  Transport, extracellular       NaN
# PNTOte                             NaN  Transport, extracellular       NaN
# IDOURte                            NaN  Transport, extracellular       NaN
# EX_idour(e)                        NaN  Exchange/demand reaction       NaN
#
#                        confidence
# reaction_no_direction
# 10FTHF5GLUtl                  2.0
# 10FTHF5GLUtm                  2.0
# 10FTHF6GLUtl                  2.0
# 10FTHF6GLUtm                  2.0
# 10FTHF7GLUtl                  2.0
# ...                           ...
# MAL_Lte                       NaN
# OROTGLUt                      NaN
# PNTOte                        NaN
# IDOURte                       NaN
# EX_idour(e)                   NaN
#
# [7440 rows x 6 columns]

# %%
# example for one reaction
reaction_metadata.loc['r0281']['formula']
# Out:
# '1.00 * Water [e] + 1.00 * O2 [e] + 1.00 * Putrescine [e] --> 1.00 * Ammonium [e] + 1.00 * Hydrogen peroxide [e] + 1.00 * 4-Aminobutanal [e]\nAOC1'

# %%
reaction_consistencies = get_reaction_consistencies(reaction_penalties)
reaction_consistencies['r_id'] = ""
for r in reaction_consistencies.index:
    if r in reaction_consistencies.index:
        reaction_consistencies.loc[r, 'r_id'] = r[:-4]
    else:
        print("Should not occur")
reaction_consistencies
# Out:
#                          cluster_0  cluster_1  cluster_2  cluster_3  \
# 10FTHF5GLUtl_pos          3.581116   3.568594   3.589757   3.571774
# 10FTHF5GLUtm_pos          3.282311   3.278123   3.302537   3.303432
# 10FTHF6GLUtl_pos          3.354332   3.338827   3.365492   3.351990
# 10FTHF6GLUtm_pos          3.194900   3.191971   3.226985   3.226150
# 10FTHF7GLUtl_pos          3.247535   3.225909   3.269249   3.257495
# ...                            ...        ...        ...        ...
# sink_decdicoa(c)_neg      2.046257   2.009224   2.037819   2.039456
# sink_octdececoa(c)_neg    1.694162   1.677915   1.710676   1.703706
# sink_pre_prot(r)_neg      7.505503   7.489046   7.506454   7.503040
# sink_tetdec2coa(c)_neg    2.046257   2.009224   2.037819   2.039456
# sink_tetdece1coa(c)_neg   2.046257   2.009224   2.037819   2.039456
#
#                          cluster_4  cluster_5  cluster_6  cluster_7  \
# 10FTHF5GLUtl_pos          3.567363   3.580919   3.578116   3.566972
# 10FTHF5GLUtm_pos          3.295321   3.279295   3.307563   3.298806
# 10FTHF6GLUtl_pos          3.338134   3.354071   3.356473   3.341766
# 10FTHF6GLUtm_pos          3.217415   3.192498   3.236524   3.220768
# 10FTHF7GLUtl_pos          3.242616   3.227746   3.263590   3.246324
# ...                            ...        ...        ...        ...
# sink_decdicoa(c)_neg      2.037934   2.022949   2.029771   2.044418
# sink_octdececoa(c)_neg    1.689212   1.661251   1.706103   1.702883
# sink_pre_prot(r)_neg      7.477145   7.492006   7.477432   7.507114
# sink_tetdec2coa(c)_neg    2.037934   2.022949   2.029771   2.044418
# sink_tetdece1coa(c)_neg   2.037934   2.022949   2.029771   2.044418
#
#                          cluster_8  cluster_9  ...  cluster_3228  \
# 10FTHF5GLUtl_pos          3.559334   3.584349  ...      3.580858
# 10FTHF5GLUtm_pos          3.287117   3.316628  ...      3.268472
# 10FTHF6GLUtl_pos          3.331716   3.362957  ...      3.354585
# 10FTHF6GLUtm_pos          3.208295   3.242981  ...      3.198987
# 10FTHF7GLUtl_pos          3.234947   3.269796  ...      3.257900
# ...                            ...        ...  ...           ...
# sink_decdicoa(c)_neg      2.033910   2.047212  ...      1.999772
# sink_octdececoa(c)_neg    1.685715   1.716105  ...      1.647987
# sink_pre_prot(r)_neg      7.504848   7.513087  ...      7.495922
# sink_tetdec2coa(c)_neg    2.033910   2.047212  ...      1.999772
# sink_tetdece1coa(c)_neg   2.033910   2.047212  ...      1.999772
#
#                          cluster_3229  cluster_3230  cluster_3231  \
# 10FTHF5GLUtl_pos             3.550445      3.599799      3.574664
# 10FTHF5GLUtm_pos             3.212751      3.286660      3.250084
# 10FTHF6GLUtl_pos             3.315968      3.378793      3.346514
# 10FTHF6GLUtm_pos             3.132359      3.217003      3.181242
# 10FTHF7GLUtl_pos             3.194262      3.273145      3.235894
# ...                               ...           ...           ...
# sink_decdicoa(c)_neg         1.958776      2.024446      1.999630
# sink_octdececoa(c)_neg       1.618137      1.683436      1.663101
# sink_pre_prot(r)_neg         7.447345      7.539147      7.494326
# sink_tetdec2coa(c)_neg       1.958776      2.024446      1.999630
# sink_tetdece1coa(c)_neg      1.958776      2.024446      1.999630
#
#                          cluster_3232  cluster_3233  cluster_3234  \
# 10FTHF5GLUtl_pos             3.598644      3.529647      3.618714
# 10FTHF5GLUtm_pos             3.274276      3.175198      3.308701
# 10FTHF6GLUtl_pos             3.377341      3.289290      3.403075
# 10FTHF6GLUtm_pos             3.211342      3.091788      3.245148
# 10FTHF7GLUtl_pos             3.282965      3.156313      3.305156
# ...                               ...           ...           ...
# sink_decdicoa(c)_neg         2.012580      1.994196      2.037200
# sink_octdececoa(c)_neg       1.669392      1.632386      1.694546
# sink_pre_prot(r)_neg         7.520505      7.456249      7.547690
# sink_tetdec2coa(c)_neg       2.012580      1.994196      2.037200
# sink_tetdece1coa(c)_neg      2.012580      1.994196      2.037200
#
#                          cluster_3235  cluster_3236                 r_id
# 10FTHF5GLUtl_pos             3.600590      3.567578         10FTHF5GLUtl
# 10FTHF5GLUtm_pos             3.279104      3.250663         10FTHF5GLUtm
# 10FTHF6GLUtl_pos             3.379681      3.337632         10FTHF6GLUtl
# 10FTHF6GLUtm_pos             3.213520      3.178189         10FTHF6GLUtm
# 10FTHF7GLUtl_pos             3.272292      3.226157         10FTHF7GLUtl
# ...                               ...           ...                  ...
# sink_decdicoa(c)_neg         2.034614      1.987491     sink_decdicoa(c)
# sink_octdececoa(c)_neg       1.692775      1.642565   sink_octdececoa(c)
# sink_pre_prot(r)_neg         7.529680      7.477200     sink_pre_prot(r)
# sink_tetdec2coa(c)_neg       2.034614      1.987491   sink_tetdec2coa(c)
# sink_tetdece1coa(c)_neg      2.034614      1.987491  sink_tetdece1coa(c)
#
# [6508 rows x 3238 columns]

# %% [markdown]
# # Compare cells of interest
# We use the unpaired Wilcoxon rank-sum test (equivlanet to the Mann–Whitney U test) to analyze which reactions are predicted to be more active

# %%
micropool_md.head(3)
# Out:
#                                modal cell state  percentage
# microclusters
# cluster_0      VentricularCardiomyocytesCompact    0.571429
# cluster_1      VentricularCardiomyocytesCycling    0.538462
# cluster_2      VentricularCardiomyocytesCompact    0.600000

# %%
cellA='AtrialCardiomyocytesRight'
cellB='AtrialCardiomyocytesLeft'
threshold = 0.9

# %%
#get clusters which refer to cell types of interest
cellA_clusters = micropool_md.index[(micropool_md['modal cell state'] == cellA)&(micropool_md['percentage']>threshold)]
cellB_clusters = micropool_md.index[(micropool_md['modal cell state'] == cellB)&(micropool_md['percentage']>threshold)]

# %%
wilcox_results = wilcoxon_test(reaction_consistencies, cellA_clusters, cellB_clusters)
wilcox_results['metadata_r_id'] = ""
for r in wilcox_results.index:
    if r in reaction_metadata.index:
        wilcox_results.loc[r, 'metadata_r_id'] = r
    elif r[:-4] in reaction_metadata.index:
        wilcox_results.loc[r, 'metadata_r_id'] = r[:-4]
    else:
        print("Should not occur")

# %%
wilcox_results
# Out:
#                          wilcox_stat  wilcox_pval  cohens_d  adjusted_pval  \
# 10FTHF5GLUtl_pos             12219.0     0.017917 -0.236296       0.038383
# 10FTHF5GLUtm_pos             11376.0     0.000985 -0.307128       0.003559
# 10FTHF6GLUtl_pos             12020.0     0.009703 -0.253135       0.024696
# 10FTHF6GLUtm_pos             11211.0     0.000509 -0.334720       0.002058
# 10FTHF7GLUtl_pos             11735.0     0.003735 -0.292910       0.010973
# ...                              ...          ...       ...            ...
# sink_decdicoa(c)_neg         13456.0     0.314150 -0.084259       0.381933
# sink_octdececoa(c)_neg       13226.0     0.207826 -0.138409       0.267141
# sink_pre_prot(r)_neg         12775.0     0.079141 -0.167727       0.117110
# sink_tetdec2coa(c)_neg       13456.0     0.314150 -0.084259       0.381933
# sink_tetdece1coa(c)_neg      13456.0     0.314150 -0.084259       0.381933
#
#                                metadata_r_id
# 10FTHF5GLUtl_pos                10FTHF5GLUtl
# 10FTHF5GLUtm_pos                10FTHF5GLUtm
# 10FTHF6GLUtl_pos                10FTHF6GLUtl
# 10FTHF6GLUtm_pos                10FTHF6GLUtm
# 10FTHF7GLUtl_pos                10FTHF7GLUtl
# ...                                      ...
# sink_decdicoa(c)_neg        sink_decdicoa(c)
# sink_octdececoa(c)_neg    sink_octdececoa(c)
# sink_pre_prot(r)_neg        sink_pre_prot(r)
# sink_tetdec2coa(c)_neg    sink_tetdec2coa(c)
# sink_tetdece1coa(c)_neg  sink_tetdece1coa(c)
#
# [6508 rows x 5 columns]

# %% [markdown]
# Next we join the metadata to the reactions in a new dataframe W, so that we can filter out non-core reactions. More specifically, we remove reactions with confidence other than 0 or 4 (4 = most confident; 0 = unassigned confidence). In the original Compass paper they filtered out reactions in the citric acid cycle subsystem which are outside of the mitochondria.

# %%
W = wilcox_results.merge(reaction_metadata, how='left',
                         left_on='metadata_r_id', right_index=True, validate='m:1')
W = W[W['confidence'].isin([0,4])]
W = W[~W['EC_number'].isna()]
W.loc[(W['formula'].map(lambda x: '[m]' not in x)) & (W['subsystem'] == "Citric acid cycle"), 'subsystem'] = 'Other'

# %%
W[W['confidence']==4]
# Out:
#                       wilcox_stat   wilcox_pval  cohens_d  adjusted_pval  \
# 2HBO_neg                  12615.0  5.339662e-02 -0.190296   8.655173e-02
# 2HBO_pos                  15611.0  1.728919e-01  0.146943   2.272633e-01
# 34DHOXPEGOX_pos           10961.0  1.759952e-04 -0.409284   7.834313e-04
# 34DHPLACOX_NADP__neg      12434.0  3.310483e-02 -0.137456   6.036599e-02
# 34DHPLACOX_pos            12434.0  3.310483e-02 -0.137456   6.036599e-02
# ...                           ...           ...       ...            ...
# XAO2x_pos                 13107.0  1.643857e-01 -0.135016   2.175762e-01
# XAOx_pos                  13114.0  1.667351e-01 -0.137886   2.203720e-01
# XYLK_pos                  14448.0  9.333710e-01  0.000525   9.387420e-01
# XYLUR_neg                  8075.0  4.330401e-12 -0.725129   1.409113e-10
# XYLUR_pos                 10383.0  1.149112e-05 -0.337536   8.801156e-05
#
#                          metadata_r_id  \
# 2HBO_neg                          2HBO
# 2HBO_pos                          2HBO
# 34DHOXPEGOX_pos            34DHOXPEGOX
# 34DHPLACOX_NADP__neg  34DHPLACOX_NADP_
# 34DHPLACOX_pos              34DHPLACOX
# ...                                ...
# XAO2x_pos                        XAO2x
# XAOx_pos                          XAOx
# XYLK_pos                          XYLK
# XYLUR_neg                        XYLUR
# XYLUR_pos                        XYLUR
#
#                                                           reaction_name  \
# 2HBO_neg                          2-Hydroxybutyrate:NAD+ oxidoreductase
# 2HBO_pos                          2-Hydroxybutyrate:NAD+ oxidoreductase
# 34DHOXPEGOX_pos       3,4-Dihydroxyphenylethyleneglycol:NAD+ oxidore...
# 34DHPLACOX_NADP__neg  3,4-Dihydroxyphenylacetaldehyde:NADP+ oxidored...
# 34DHPLACOX_pos        3,4-Dihydroxyphenylacetaldehyde:NAD+ oxidoredu...
# ...                                                                 ...
# XAO2x_pos                                              xanthine oxidase
# XAOx_pos                                  xanthine  oxidase,peroxisomal
# XYLK_pos                                                   xylulokinase
# XYLUR_neg                                            xylulose reductase
# XYLUR_pos                                            xylulose reductase
#
#                                                                 formula  \
# 2HBO_neg              1.00 * 2-Hydroxybutyrate [c] + 1.00 * Nicotina...
# 2HBO_pos              1.00 * 2-Hydroxybutyrate [c] + 1.00 * Nicotina...
# 34DHOXPEGOX_pos       1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# 34DHPLACOX_NADP__neg  1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# 34DHPLACOX_pos        1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# ...                                                                 ...
# XAO2x_pos             1.00 * O2 [x] + 1.00 * Water [x] + 1.00 * Hypo...
# XAOx_pos              1.00 * O2 [x] + 1.00 * Water [x] + 1.00 * Xant...
# XYLK_pos              1.00 * ATP [c] + 1.00 * D-xylulose [c] --> 1.0...
# XYLUR_neg             1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# XYLUR_pos             1.00 * proton [c] + 1.00 * Nicotinamide adenin...
#
#                                            associated_genes  \
# 2HBO_neg                   LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 2HBO_pos                   LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 34DHOXPEGOX_pos       ADH1; ADH4; ADH5; ADH6A; ADH7; ADHFE1
# 34DHPLACOX_NADP__neg              ALDH3A1; ALDH3B1; ALDH3B3
# 34DHPLACOX_pos           ALDH1A3; ALDH3A1; ALDH3B1; ALDH3B3
# ...                                                     ...
# XAO2x_pos                                               XDH
# XAOx_pos                                                XDH
# XYLK_pos                                               XYLB
# XYLUR_neg                                              DCXR
# XYLUR_pos                                              DCXR
#
#                                       subsystem  EC_number  confidence
# 2HBO_neg                  Propanoate metabolism   1.1.1.27         4.0
# 2HBO_pos                  Propanoate metabolism   1.1.1.27         4.0
# 34DHOXPEGOX_pos             Tyrosine metabolism    1.1.1.1         4.0
# 34DHPLACOX_NADP__neg        Tyrosine metabolism    1.2.1.5         4.0
# 34DHPLACOX_pos              Tyrosine metabolism    1.2.1.5         4.0
# ...                                         ...        ...         ...
# XAO2x_pos                     Purine catabolism  1.1.1.204         4.0
# XAOx_pos                      Purine catabolism  1.1.1.204         4.0
# XYLK_pos              Pentose phosphate pathway   2.7.1.17         4.0
# XYLUR_neg             Pentose phosphate pathway   1.1.1.10         4.0
# XYLUR_pos             Pentose phosphate pathway   1.1.1.10         4.0
#
# [1081 rows x 11 columns]

# %% [markdown]
# # Plotting results

# %%
data = W[W['subsystem'] == "Citric acid cycle"]
plot_differential_scores(data, title="TCA Cycle", c="#D3A991")

# %%
data = W[W['subsystem'] == "Glycolysis/gluconeogenesis"]
plot_differential_scores(data, title='Glycolysis', c="#695D73")

# %%
data = W[W['subsystem'] == "Fatty acid oxidation"]
plot_differential_scores(data, "Fatty Acid Oxidation", c="#040772")

# %%
data = W[W['subsystem'].isin(amino_acid_metab)].copy()
data['adjusted_pval'] = data['adjusted_pval'].clip(1e-12)
plot_differential_scores(data, "Amino Acid Metabolism", c="#BF1E2E")

# %%
data = W[~W['subsystem'].isin(["Miscellaneous", "Unassigned"])]
data = data[~data['subsystem'].map(lambda x: "Transport" in x or "Exchange" in x or x == "Other")]
items, counts = np.unique(data['subsystem'], return_counts=True)
items = [items[i] for i in range(len(items)) if counts[i] > 5] #filter(n() > 5) %>%
data = data[data['subsystem'].isin(items)]

# %%
plt.figure(figsize=(12,12))
axs = plt.gca()
#Sorts the reactions for plotting
d = data[data['adjusted_pval'] < 0.2].groupby('subsystem')['cohens_d'].median().abs()
axs.scatter(d[d.argsort], d[d.argsort].index, alpha=0)
color = data['cohens_d'].map(lambda x: 'r' if x >= 0 else 'g')
alpha = data['adjusted_pval'].map(lambda x: 1.0 if x < 0.1 else 0.25)
axs.scatter(data['cohens_d'], data['subsystem'], c=color, alpha=alpha)
axs.set_xlabel("Cohen's d")
# Out:
# Text(0.5, 0, "Cohen's d")

# %% [markdown]
# # Meta reactions

# %%
reaction_penalties[reaction_penalties <= 1e-4] = 0
reaction_penalties = reaction_penalties[np.all(reaction_penalties != 0, axis=1)]

reaction_penalties = reaction_penalties[reaction_penalties.max(axis=1) - reaction_penalties.min(axis=1) != 0]

# %%
meta_rxns_map = get_metareactions(reaction_penalties)
meta_rxns = reaction_penalties.join(pd.DataFrame(meta_rxns_map, columns=["meta_rxn_id"], index = reaction_penalties.index)).groupby("meta_rxn_id").mean()

# %%
meta_rxn_consistencies = get_reaction_consistencies(meta_rxns)

# %%
wilcox_meta_rxn_results = wilcoxon_test(meta_rxn_consistencies, cellA_clusters, cellB_clusters)

# %%
wilcox_meta_rxn_expanded = pd.DataFrame(index=reaction_penalties.index, columns=wilcox_meta_rxn_results.columns)
for i in range(len(wilcox_meta_rxn_expanded.index)):
    if (meta_rxns_map[i] in wilcox_meta_rxn_results.index):
        wilcox_meta_rxn_expanded.loc[wilcox_meta_rxn_expanded.index[i]] = wilcox_meta_rxn_results.loc[meta_rxns_map[i]]
wilcox_meta_rxn_expanded = wilcox_meta_rxn_expanded.dropna().astype('float64')

# %%
wilcox_meta_rxn_expanded['metadata_r_id'] = ""
for r in wilcox_meta_rxn_expanded.index:
    if r in reaction_metadata.index:
        wilcox_meta_rxn_expanded.loc[r, 'metadata_r_id'] = r
    elif r[:-4] in reaction_metadata.index:
        wilcox_meta_rxn_expanded.loc[r, 'metadata_r_id'] = r[:-4]
    else:
        print("Should not occur")

# %%
W = wilcox_meta_rxn_expanded.merge(reaction_metadata, how='left',
                         left_on='metadata_r_id', right_index=True, validate='m:1')
W = W[W['confidence'].isin([0,4])]
W = W[~W['EC_number'].isna()]
W.loc[(W['formula'].map(lambda x: '[m]' not in x)) & (W['subsystem'] == "Citric acid cycle"), 'subsystem'] = 'Other'

# %%
W['subsystem'].unique().tolist()
# Out:
# ['Propanoate metabolism',
#  'Tyrosine metabolism',
#  'Sphingolipid metabolism',
#  'Tryptophan metabolism',
#  'Taurine and hypotaurine metabolism',
#  'Cytochrome metabolism',
#  'Steroid metabolism',
#  'Glycine, serine, alanine and threonine metabolism',
#  'Lysine metabolism',
#  'Glutamate metabolism',
#  'beta-Alanine metabolism',
#  'Valine, leucine, and isoleucine metabolism',
#  'Cholesterol metabolism',
#  'Fatty acid oxidation',
#  'Aminosugar metabolism',
#  'Phosphatidylinositol phosphate metabolism',
#  'Glycerophospholipid metabolism',
#  'Other',
#  'Butanoate metabolism',
#  'Pyruvate metabolism',
#  'Citric acid cycle',
#  'Bile acid synthesis',
#  'Glycolysis/gluconeogenesis',
#  'Purine catabolism',
#  'Nucleotide interconversion',
#  'Arginine and Proline Metabolism',
#  'Nucleotide salvage pathway',
#  'Purine synthesis',
#  'Keratan sulfate synthesis',
#  'Triacylglycerol synthesis',
#  'Alanine and aspartate metabolism',
#  'Methionine and cysteine metabolism',
#  'N-glycan degradation',
#  'Miscellaneous',
#  'Eicosanoid metabolism',
#  'Glutathione metabolism',
#  'Starch and sucrose metabolism',
#  'Pentose phosphate pathway',
#  'Urea cycle',
#  'Pyrimidine synthesis',
#  'Oxidative phosphorylation',
#  'Transport, lysosomal',
#  'Biotin metabolism',
#  'Vitamin A metabolism',
#  'N-glycan synthesis',
#  'Heme degradation',
#  'Pyrimidine catabolism',
#  'Transport, extracellular',
#  'ROS detoxification',
#  'O-glycan synthesis',
#  'D-alanine metabolism',
#  'Vitamin C metabolism',
#  'Fatty acid synthesis',
#  'Ubiquinone synthesis',
#  'Tetrahydrobiopterin metabolism',
#  'Keratan sulfate degradation',
#  'Fructose and mannose metabolism',
#  'Glyoxylate and dicarboxylate metabolism',
#  'Galactose metabolism',
#  'Folate metabolism',
#  'Blood group synthesis',
#  'Heparan sulfate degradation',
#  'Chondroitin sulfate degradation',
#  'Hyaluronan metabolism',
#  'Histidine metabolism',
#  'Inositol phosphate metabolism',
#  'NAD metabolism',
#  'Limonene and pinene degradation',
#  'Transport, mitochondrial',
#  'Vitamin B6 metabolism',
#  'Phenylalanine metabolism',
#  'Heme synthesis',
#  'CoA synthesis',
#  'Glycosphingolipid metabolism',
#  'Androgen and estrogen synthesis and metabolism',
#  'Vitamin B2 metabolism',
#  'Arachidonic acid metabolism',
#  'Thiamine metabolism',
#  'Cysteine Metabolism',
#  'Unassigned',
#  'CoA catabolism',
#  'Transport, peroxisomal',
#  'Transport, nuclear']

# %% [markdown]
# # Plotting meta reaction results

# %%
data = W[W['subsystem'] == "NAD metabolism"]
plot_differential_scores(data, title="TCA Cycle", c="#D3A991")

# %%
data = W[W['subsystem'] == "Citric acid cycle"]
plot_differential_scores(data, title="TCA Cycle", c="#D3A991")

# %%
data = W[W['subsystem'] == "Glycolysis/gluconeogenesis"]
plot_differential_scores(data, title='Glycolysis', c="#695D73")

# %%
data = W[W['subsystem'] == "Fatty acid oxidation"]
plot_differential_scores(data, "Fatty Acid Oxidation", c="#040772")

# %%
data = W[W['subsystem'].isin(amino_acid_metab)].copy()
data['adjusted_pval'] = data['adjusted_pval'].clip(1e-12)
plot_differential_scores(data, "Amino Acid Metabolism", c="#BF1E2E")

# %%
data = W[~W['subsystem'].isin(["Miscellaneous", "Unassigned"])]
data = data[~data['subsystem'].map(lambda x: "Transport" in x or "Exchange" in x or x == "Other")]
items, counts = np.unique(data['subsystem'], return_counts=True)
items = [items[i] for i in range(len(items)) if counts[i] > 5] #filter(n() > 5) %>%
data = data[data['subsystem'].isin(items)]

# %%
plt.figure(figsize=(12,12))
axs = plt.gca()
#Sorts the reactions for plotting
d = data[data['adjusted_pval'] < 0.05].groupby('subsystem')['cohens_d'].median().abs()
axs.scatter(d[d.argsort], d[d.argsort].index, alpha=0)
color = data['cohens_d'].map(lambda x: 'r' if x >= 0 else 'g')
alpha = data['adjusted_pval'].map(lambda x: 1.0 if x < 0.1 else 0.25)
axs.scatter(data['cohens_d'], data['subsystem'], c=color, alpha=alpha)
axs.set_xlabel("Cohen's d")
# Out:
# Text(0.5, 0, "Cohen's d")
