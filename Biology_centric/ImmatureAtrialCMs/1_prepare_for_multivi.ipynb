# %%
import scanpy as sc
import pandas as pd
import numpy as np
import anndata
import scipy
import os

from scipy.io import mmwrite, mmread
from scipy.sparse import csr_matrix

import sctk

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.8.0
# numpy               1.24.4
# pandas              1.5.3
# scanpy              1.9.3
# scipy               1.11.1
# sctk                NA
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.0.0
# anyio                       NA
# arrow                       1.2.3
# asttokens                   NA
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.12.1
# backcall                    0.2.0
# brotli                      1.0.9
# certifi                     2023.07.22
# cffi                        1.15.1
# charset_normalizer          3.2.0
# comm                        0.1.3
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.6.7
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   1.2.0
# fastjsonschema              NA
# fqdn                        NA
# h5py                        3.9.0
# idna                        3.4
# igraph                      0.10.6
# ipykernel                   6.25.0
# isoduration                 NA
# jedi                        0.18.2
# jinja2                      3.1.2
# joblib                      1.3.1
# json5                       NA
# jsonpointer                 2.0
# jsonschema                  4.18.4
# jsonschema_specifications   NA
# jupyter_events              0.6.3
# jupyter_server              2.7.0
# jupyterlab_server           2.24.0
# kiwisolver                  1.4.4
# leidenalg                   0.10.1
# llvmlite                    0.40.1
# markupsafe                  2.1.3
# matplotlib                  3.7.2
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.1
# numba                       0.57.1
# numpy_groupies              0.9.22
# overrides                   NA
# packaging                   23.1
# parso                       0.8.3
# patsy                       0.5.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                3.9.1
# plotly                      5.16.1
# prometheus_client           NA
# prompt_toolkit              3.0.39
# psutil                      5.9.5
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     12.0.1
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.15.1
# pyparsing                   3.0.9
# pythonjsonlogger            NA
# pytz                        2023.3
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# seaborn                     0.12.2
# send2trash                  NA
# six                         1.16.0
# sklearn                     1.3.0
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.0
# texttable                   1.6.7
# threadpoolctl               3.2.0
# tornado                     6.3.2
# traitlets                   5.9.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     1.26.16
# wcwidth                     0.2.6
# webcolors                   1.13
# websocket                   1.6.1
# yaml                        6.0
# zmq                         25.1.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.14.0
# jupyter_client      8.3.0
# jupyter_core        5.3.1
# jupyterlab          4.0.3
# notebook            7.0.0
# -----
# Python 3.11.4 | packaged by conda-forge | (main, Jun 10 2023, 18:08:17) [GCC 12.2.0]
# Linux-5.4.0-163-generic-x86_64-with-glibc2.27
# -----
# Session information updated at 2023-10-19 18:44
# </pre>
# </details>

# %%
sc.settings.set_figure_params(dpi=120)

# %% [markdown]
# # Variables

# %%
job_name="aCMs_AnyRegion" #  corresponds to name on input adata(s) .h5ad files. E.g. cell type or bespoke job like "aCMs_WholeSample"

# %%
path_to_RNA_object='/nfs/team205/heart/anndata_objects/Foetal/Feb28ObjectRaw.h5ad' # global object
path_to_ATAC_object='/nfs/team205/heart/anndata_objects/Foetal/multiome_ATAC/ArchR/project_output/PeakMatrix/Foetal_Peaks.h5ad' # global object

# %%
celltype_key = 'fine_grain'
celltypes_to_analyse = ['AtrialCardiomyocytesRight','AtrialCardiomyocytesLeft']

# %%
region_subset=False

if region_subset:
    region_key='region'
    regions_to_analyse = ['whole sample']

# %%
obs_to_keep=['sangerID', 'combinedID', 'donor', 
                       'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 
                       'scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'n_genes', 'n_counts',
                       'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts',
                       'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt',
                       'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo',
                       'pct_counts_ribo', 'HB_score', 'multiplexed',
                        'batch_key','region','FACSgate','sex','week','trimester',
                     'fine_grain','mid_grain','coarse_grain',
                     'heart_or_greatvessels','cycling','S_score','G2M_score','phase','stress_score','hb1_score']

# %%
RNA_var_to_keep=['gene_name_scRNA-0','gene_id']

# %%
paired_adata_out_path=os.path.join("/lustre/scratch126/cellgen/team205/heart/objects/fetal/RNA",f"{job_name}_paired.h5ad")
paired_adata_out_path
# Out:
# '/lustre/scratch126/cellgen/team205/heart/objects/fetal/RNA/aCMs_AnyRegion_paired.h5ad'

# %%
multiome_only=True

# %% [markdown]
# # Prepare paired anndata

# %%
# rna
adata_rna = sc.read_h5ad(path_to_RNA_object)

# subset cells
adata_rna = adata_rna[adata_rna.obs[celltype_key].isin(celltypes_to_analyse)]

# subset regions
if region_subset:
    adata_rna = adata_rna[adata_rna.obs[region_key].isin(regions_to_analyse)]

# add modality to .var
adata_rna.var['modality']='Gene Expression'

adata_rna
# Out:
# /tmp/ipykernel_211566/3076047041.py:12: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_rna.var['modality']='Gene Expression'
# AnnData object with n_obs × n_vars = 17302 × 36601
#     obs: 'latent_RT_efficiency', 'latent_cell_probability', 'latent_scale', 'sangerID', 'combinedID', 'donor', 'region', 'age', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'n_genes', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'HB_score', 'donor_by_library-prep', 'multiplexed', 'SOC | status', 'SOC | log_prob_singleton', 'SOC | log_prob_doublet', 'batch_key', '_scvi_batch', 'FACSgate', 'fine_grain', 'mid_grain', 'coarse_grain', 'sex', 'week', 'trimester', 'heart_or_greatvessels', 'cycling', 'S_score', 'G2M_score', 'phase', '_scvi_labels', 'stress_score', 'hb1_score'
#     var: 'gene_name_scRNA-0', 'gene_id', 'modality'
#     uns: 'FACSgate_colors', '_scvi_manager_uuid', '_scvi_uuid', 'age_colors', 'cell_or_nuclei_colors', 'coarse_grain_colors', 'cycling_colors', 'donor_colors', 'fine_grain_colors', 'heart_or_greatvessels_colors', 'hvg', 'kit_10x_colors', 'modality_colors', 'neighbors', 'phase_colors', 'region_colors', 'sex_colors', 'trimester_colors', 'umap', 'week_colors'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs', '_scvi_extra_continuous', '_scvi_extra_continuous_covs', 'latent_gene_encoding'
#     obsp: 'connectivities', 'distances'

# %%
pd.crosstab(adata_rna.obs[celltype_key],adata_rna.obs['region'])
# Out:
# region                     aorta  apex  atria  atrial septum  base  \
# fine_grain
# AtrialCardiomyocytesLeft       8    16    474            956   342
# AtrialCardiomyocytesRight    159     9    457            162   665
#
# region                     whole sample  heart without node  node  \
# fine_grain
# AtrialCardiomyocytesLeft           4017                 360   273
# AtrialCardiomyocytesRight          3738                 100  5389
#
# region                     outflow tract  pulmonary arches and branches
# fine_grain
# AtrialCardiomyocytesLeft               5                            155
# AtrialCardiomyocytesRight              6                             11

# %%
pd.crosstab(adata_rna.obs[celltype_key],adata_rna.obs['kit_10x'])
# Out:
# kit_10x                    3prime-v3  5prime-v2  Multiome-v1
# fine_grain
# AtrialCardiomyocytesLeft         358        443         5805
# AtrialCardiomyocytesRight        674        661         9361

# %%
pd.crosstab(adata_rna.obs[celltype_key],adata_rna.obs['cycling'])
# Out:
# cycling                      no   yes
# fine_grain
# AtrialCardiomyocytesLeft   4802  1804
# AtrialCardiomyocytesRight  7574  3122

# %%
# atac
# ie only Multiome data
adata_atac = sc.read_h5ad(path_to_ATAC_object)

# subset cells
adata_atac = adata_atac[adata_atac.obs[celltype_key].isin(celltypes_to_analyse)]
print(adata_atac.obs[celltype_key].value_counts())

# subset regions
if region_subset:
    adata_atac = adata_atac[adata_atac.obs[region_key].isin(regions_to_analyse)]

# add modality to .var
adata_atac.var['modality']='Peaks'

adata_atac
# Out:
# AtrialCardiomyocytesRight    8187
# AtrialCardiomyocytesLeft     4777
# Name: fine_grain, dtype: int64
# /tmp/ipykernel_211566/3253878154.py:14: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_atac.var['modality']='Peaks'
# AnnData object with n_obs × n_vars = 12964 × 508040
#     obs: 'sangerID', 'combinedID', 'donor', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'multiplexed', 'batch_key', 'region', 'FACSgate', 'sex', 'week', 'trimester', 'fine_grain', 'mid_grain', 'coarse_grain', 'heart_or_greatvessels'
#     var: 'seqnames', 'start', 'end', 'width', 'strand', 'score', 'replicateScoreQuantile', 'groupScoreQuantile', 'Reproducibility', 'GroupReplicate', 'distToGeneStart', 'nearestGene', 'peakType', 'distToTSS', 'nearestTSS', 'GC', 'idx', 'N', 'modality'

# %%
pd.crosstab(adata_atac.obs[celltype_key],adata_atac.obs['region'])
# Out:
# region                     aorta  atria  atrial septum  heart without node  \
# fine_grain
# AtrialCardiomyocytesLeft       2    430            668                 286
# AtrialCardiomyocytesRight     75    431            109                  80
#
# region                     node  pulmonary arches and branches  whole sample
# fine_grain
# AtrialCardiomyocytesLeft    245                            105          3041
# AtrialCardiomyocytesRight  4862                              7          2623

# %%
# shared barcodes, ie Multiome data (not all, since MultiomeRNA has a bit more data than MultiomeATAC)
barcodes_inter=list(set(adata_rna.obs_names).intersection(adata_atac.obs_names))
len(barcodes_inter)

# take shared cells
multiome_rna=adata_rna[barcodes_inter,:]
multiome_atac=adata_atac[barcodes_inter,:]

# concatenate
adata_paired=anndata.AnnData(
    X=scipy.sparse.hstack([multiome_rna.X,multiome_atac.X]).tocsr(), # concatenate sparse matrix and convert to Compressed Sparse Row format
    obs=multiome_rna.obs[obs_to_keep],
    var=pd.concat([multiome_rna.var[['modality']+RNA_var_to_keep], \
                   multiome_atac.var[['modality']]
                  ],axis=0)
)
adata_paired
# Out:
# AnnData object with n_obs × n_vars = 12964 × 544641
#     obs: 'sangerID', 'combinedID', 'donor', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'n_genes', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'HB_score', 'multiplexed', 'batch_key', 'region', 'FACSgate', 'sex', 'week', 'trimester', 'fine_grain', 'mid_grain', 'coarse_grain', 'heart_or_greatvessels', 'cycling', 'S_score', 'G2M_score', 'phase', 'stress_score', 'hb1_score'
#     var: 'modality', 'gene_name_scRNA-0', 'gene_id'

# %%
# modify modality columns in .obs
adata_paired.obs['modality'] = 'Multiome'
adata_paired.obs['modality'].value_counts()
# Out:
# Multiome    12964
# Name: modality, dtype: int64

# %%
adata_paired.obs
# Out:
#                                                               sangerID  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...   BHF_F_Hea11933666
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...   BHF_F_Hea11933668
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...  HCAHeartST13386009
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...  HCAHeartST13386009
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...    7089STDY13216927
# ...                                                                ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...    7089STDY13216920
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...   BHF_F_Hea13188317
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...   BHF_F_Hea11933668
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...   BHF_F_Hea11933669
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...    7089STDY13216927
#
#                                                                                combinedID  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...    BHF_F_Hea11933666_BHF_F_Hea11596619
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...    BHF_F_Hea11933668_BHF_F_Hea11596621
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...  HCAHeartST13386009_HCAHeartST13303419
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...  HCAHeartST13386009_HCAHeartST13303419
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...     7089STDY13216927_BHF_F_Hea13242534
# ...                                                                                   ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...     7089STDY13216920_BHF_F_Hea13242527
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...    BHF_F_Hea13188317_BHF_F_Hea13187619
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...    BHF_F_Hea11933668_BHF_F_Hea11596621
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...    BHF_F_Hea11933669_BHF_F_Hea11596622
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...     7089STDY13216927_BHF_F_Hea13242534
#
#                                                     donor facility  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...  Hst33   Sanger
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...  Hst33   Sanger
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...  Hst41   Sanger
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...  Hst41   Sanger
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...  Hst36   Sanger
# ...                                                   ...      ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...  Hst40   Sanger
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...  Hst41   Sanger
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...  Hst33   Sanger
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...  Hst33   Sanger
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...  Hst36   Sanger
#
#                                                    cell_or_nuclei  modality  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...         nuclei  Multiome
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...         nuclei  Multiome
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...         nuclei  Multiome
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...         nuclei  Multiome
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...         nuclei  Multiome
# ...                                                           ...       ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...         nuclei  Multiome
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...         nuclei  Multiome
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...         nuclei  Multiome
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...         nuclei  Multiome
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...         nuclei  Multiome
#
#                                                         kit_10x  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...  Multiome-v1
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...  Multiome-v1
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...  Multiome-v1
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...  Multiome-v1
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...  Multiome-v1
# ...                                                         ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...  Multiome-v1
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...  Multiome-v1
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...  Multiome-v1
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...  Multiome-v1
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...  Multiome-v1
#
#                                                     scrublet_score  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...        0.036105
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...        0.028430
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...        0.054002
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...        0.035455
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...        0.030818
# ...                                                            ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...        0.079812
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...        0.092437
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...        0.037171
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...        0.038835
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...        0.041042
#
#                                                     doublet_pval  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...      0.772012
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...      0.869914
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...      0.620244
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...      0.670376
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...      0.639032
# ...                                                          ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...      0.563518
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...      0.639402
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...      0.841468
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...      0.778765
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...      0.682458
#
#                                                     doublet_bh_pval  ...  \
# barcode                                                              ...
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...         0.913587  ...
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...         0.925448  ...
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...         0.733829  ...
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...         0.733829  ...
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...         0.841935  ...
# ...                                                             ...  ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...         0.722573  ...
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...         0.901964  ...
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...         0.925448  ...
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...         0.881283  ...
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...         0.841935  ...
#
#                                                                    fine_grain  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...   AtrialCardiomyocytesLeft
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...   AtrialCardiomyocytesLeft
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...   AtrialCardiomyocytesLeft
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...   AtrialCardiomyocytesLeft
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...  AtrialCardiomyocytesRight
# ...                                                                       ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...  AtrialCardiomyocytesRight
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...  AtrialCardiomyocytesRight
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...   AtrialCardiomyocytesLeft
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...  AtrialCardiomyocytesRight
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...  AtrialCardiomyocytesRight
#
#                                                                mid_grain  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...  AtrialCardiomyocytes
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...  AtrialCardiomyocytes
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...  AtrialCardiomyocytes
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...  AtrialCardiomyocytes
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...  AtrialCardiomyocytes
# ...                                                                  ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...  AtrialCardiomyocytes
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...  AtrialCardiomyocytes
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...  AtrialCardiomyocytes
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...  AtrialCardiomyocytes
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...  AtrialCardiomyocytes
#
#                                                       coarse_grain  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...  Cardiomyocytes
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...  Cardiomyocytes
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...  Cardiomyocytes
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...  Cardiomyocytes
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...  Cardiomyocytes
# ...                                                            ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...  Cardiomyocytes
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...  Cardiomyocytes
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...  Cardiomyocytes
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...  Cardiomyocytes
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...  Cardiomyocytes
#
#                                                     heart_or_greatvessels  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...                  heart
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...                  heart
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...                  heart
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...                  heart
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...                  heart
# ...                                                                   ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...                  heart
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...                  heart
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...                  heart
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...                  heart
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...                  heart
#
#                                                     cycling   S_score  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...       no -0.119442
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...       no -0.041229
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...       no -0.055126
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...       no -0.040533
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...      yes  0.197882
# ...                                                     ...       ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...      yes -0.014605
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...       no -0.084742
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...       no -0.059559
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...       no -0.090159
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...       no -0.041964
#
#                                                     G2M_score  phase  \
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...  -0.146085     G1
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...  -0.138849     G1
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...  -0.117691     G1
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...  -0.100181     G1
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...  -0.118771      S
# ...                                                       ...    ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...   0.002866    G2M
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...  -0.185395     G1
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...  -0.124683     G1
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...  -0.061663     G1
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...  -0.148276     G1
#
#                                                     stress_score  hb1_score
# barcode
# BHF_F_Hea11933666_BHF_F_Hea11596619_GCTTTACGTTG...     -0.420342  -0.254106
# BHF_F_Hea11933668_BHF_F_Hea11596621_CCTTGTTCAAT...     -0.364514  -0.265534
# HCAHeartST13386009_HCAHeartST13303419_GTTTACCGT...     -0.311239   0.444615
# HCAHeartST13386009_HCAHeartST13303419_GTCATGAGT...     -0.228039   0.719630
# 7089STDY13216927_BHF_F_Hea13242534_AGGTGAGGTTAG...     -0.299509  -0.173325
# ...                                                          ...        ...
# 7089STDY13216920_BHF_F_Hea13242527_AACGGTAAGTTA...     -0.297443  -0.144262
# BHF_F_Hea13188317_BHF_F_Hea13187619_GCTTAGTAGCT...     -0.481188  -0.147605
# BHF_F_Hea11933668_BHF_F_Hea11596621_TATTTGCTCCT...     -0.041850  -0.163431
# BHF_F_Hea11933669_BHF_F_Hea11596622_TAGTTTGAGGT...     -0.293251  -0.271267
# 7089STDY13216927_BHF_F_Hea13242534_GCTGTAAGTCGT...     -0.312991  -0.188113
#
# [12964 rows x 40 columns]

# %%
adata_paired.var
# Out:
#                                  modality gene_name_scRNA-0          gene_id
# MIR1302-2HG               Gene Expression       MIR1302-2HG  ENSG00000243485
# FAM138A                   Gene Expression           FAM138A  ENSG00000237613
# OR4F5                     Gene Expression             OR4F5  ENSG00000186092
# AL627309.1                Gene Expression        AL627309.1  ENSG00000238009
# AL627309.3                Gene Expression        AL627309.3  ENSG00000239945
# ...                                   ...               ...              ...
# chrX:155820072_155820572            Peaks               NaN              NaN
# chrX:155874490_155874990            Peaks               NaN              NaN
# chrX:155880548_155881048            Peaks               NaN              NaN
# chrX:155881064_155881564            Peaks               NaN              NaN
# chrX:155881618_155882118            Peaks               NaN              NaN
#
# [544641 rows x 3 columns]

# %%
adata_paired.X.data[:10]
# Out:
# array([1., 1., 1., 1., 1., 1., 2., 1., 2., 3.], dtype=float32)

# %%
# save
adata_paired.write(paired_adata_out_path)
print(f"saved to {paired_adata_out_path}")
# Out:
# saved to /lustre/scratch126/cellgen/team205/heart/objects/fetal/RNA/aCMs_AnyRegion_paired.h5ad

# %% [markdown]
# # Prepare unimodality data

# %%
# If there is an object of different modality e.g. scRNAseq then make that too
if multiome_only:
    print("only making a single multiome object...")
else:
    print("making unimodality data too")
    modality_col="scRNA" # define what you want to go into modality column
    unimodality_adata_out_path=os.path.join("/lustre/scratch126/cellgen/team205/heart/objects/fetal/RNA",f"{job_name}_unimodality.h5ad")

    # select single-cell data (3p and 5p)
    adata_unimodality = adata_rna[adata_rna.obs['kit_10x'].isin(['3prime-v3','5prime-v2'])]
    adata_unimodality.obs['kit_10x'].value_counts()

    # make adata
    adata_unimodality=anndata.AnnData(
        X=adata_scrna.X, # concatenate sparse matrix and convert to Compressed Sparse Row format
        obs=adata_scrna.obs[obs_to_keep],
        var=adata_scrna.var[['modality']+RNA_var_to_keep]
    )

    # modify modality columns in .obs
    adata_unimodality.obs['modality'] = modality_col
    adata_unimodality.obs['modality'].value_counts()

    adata_unimodality.write(unimodality_adata_out_path)
    print(f"saved to {unimodality_adata_out_path}")
# Out:
# only making a single multiome object...
