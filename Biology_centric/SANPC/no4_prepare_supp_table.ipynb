# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
import importlib.util
import sys
spec = importlib.util.spec_from_file_location("module.name", "/nfs/team205/kk18/function/python/utils.py")
utils = importlib.util.module_from_spec(spec)
sys.modules["module.name"] = utils
spec.loader.exec_module(utils)

# %%
table_dir = '/nfs/team205/heart/fetal_ms_figures/tables'

# %%
scenic_meta_path = '/nfs/team205/heart/fetal_ms_figures/tables/csvs/scenicplus_eRegulon_metadata_CMs_SANPC-highlighted.csv'

# %% [markdown]
# # Target: SANPC signatures

# %%
TF_TG_network_path = '/nfs/team205/heart/Vitro/TF_selection/foetal_SANPcell_vs_workingCM/TF-TG-network_target-SANPC-signatures.pkl'
TF_TF_network_path = '/nfs/team205/heart/Vitro/TF_selection/foetal_SANPcell_vs_workingCM/TF-TF-network_target-SANPC-signatures.pkl'
TF_info_path = '/nfs/team205/heart/Vitro/TF_selection/foetal_SANPcell_vs_workingCM/TF_selection_df_target-SANPC-signatures.csv'

# TF_TG_network
network = utils.read_pkl(TF_TG_network_path)
print(len(network.keys()))

# TF info
TF_info = pd.read_csv(TF_info_path)
print(TF_info.shape)
display(TF_info.head())

# grn table
grn = pd.DataFrame({'TF':network.keys(),'Targets':network.values()})
grn = grn.merge(TF_info,how='left',on='TF')
grn = grn[['TF','Targets','centaliry_eigenvector']]
print(grn.shape)
display(grn.head())

# save the daraframe
grn.to_csv(os.path.join(table_dir,'csvs/TF_TG_network_SANPC_target-SANPC-signatures.csv'))
# Out:
# 124
# (124, 6)
#         TF  direct_TF  TF_n_target_genes  TF_n_target_sig_regions  \
# 0     ATF1       True                1.0                      1.0
# 1    BACH2       True                2.0                      3.0
# 2  BHLHE40       True                2.0                      2.0
# 3     BNC2       True               18.0                      3.0
# 4    CLOCK       True                1.0                      1.0
#
#    TF_n_linked_region  centaliry_eigenvector
# 0                 0.0           0.000000e+00
# 1                 0.0           0.000000e+00
# 2                 0.0           2.393779e-15
# 3                 8.0           2.124538e-01
# 4                 0.0           0.000000e+00
# (124, 3)
#      TF                                            Targets  \
# 0   YY1                       [SSPN, MSMO1, ATP1B2, SNX24]
# 1  MITF                      [FNBP1L, TRIQK, SYNPO2, THRB]
# 2  NFIC  [CACNA2D3, FAT3, HCN1, PLCL1, KCNJ3, ICA1, GUL...
# ...

# %% [markdown]
# # Target: Ion channels

# %%
TF_TG_network_path = '/nfs/team205/heart/Vitro/TF_selection/foetal_SANPcell_vs_workingCM/TF-TG-network_target-IonChannels.pkl'
TF_TF_network_path = '/nfs/team205/heart/Vitro/TF_selection/foetal_SANPcell_vs_workingCM/TF-TF-network_target-IonChannels.pkl'
TF_info_path = '/nfs/team205/heart/Vitro/TF_selection/foetal_SANPcell_vs_workingCM/TF_selection_df_target-IonChannels.csv'

# TF_TG_network
network = utils.read_pkl(TF_TG_network_path)
print(len(network.keys()))

# TF info
TF_info = pd.read_csv(TF_info_path)
print(TF_info.shape)
display(TF_info.head())

# grn table
grn = pd.DataFrame({'TF':network.keys(),'Targets':network.values()})
grn = grn.merge(TF_info,how='left',on='TF')
grn = grn[['TF','Targets','centaliry_eigenvector']]
print(grn.shape)
display(grn.head())

# save the daraframe
grn.to_csv(os.path.join(table_dir,'csvs/TF_TG_network_SANPC_target-IonChannels.csv'))
# Out:
# 41
# (41, 6)
#       TF  direct_TF  TF_n_target_genes  TF_n_target_sig_regions  \
# 0   CREM       True                1.0                      1.0
# 1    FOS       True                6.0                      4.0
# 2  HMGA2       True                1.0                      0.0
# 3  MECP2       True                1.0                      1.0
# 4  MEF2C       True               23.0                      4.0
#
#    TF_n_linked_region  centaliry_eigenvector
# 0                 0.0           0.000000e+00
# 1                 1.0           1.362997e-09
# 2                 1.0           4.213053e-02
# 3                 0.0           0.000000e+00
# 4                 7.0           1.824737e-01
# (41, 3)
#       TF                                            Targets  \
# 0   RARB                                   [THRB, CACNA2D2]
# 1    FOS          [TBX18, CACNA1D, FOS, GLIS3, THRB, SHOX2]
# 2    SP4                                             [TBX3]
# ...

# %% [markdown]
# # Target: Axon guidances

# %%
TF_TG_network_path = '/nfs/team205/heart/Vitro/TF_selection/foetal_SANPcell_vs_workingCM/TF-TG-network_target-AxonGuidances.pkl'
TF_TF_network_path = '/nfs/team205/heart/Vitro/TF_selection/foetal_SANPcell_vs_workingCM/TF-TF-network_target-AxonGuidances.pkl'
TF_info_path = '/nfs/team205/heart/Vitro/TF_selection/foetal_SANPcell_vs_workingCM/TF_selection_df_target-AxonGuidances.csv'

# TF_TG_network
network = utils.read_pkl(TF_TG_network_path)
print(len(network.keys()))

# TF info
TF_info = pd.read_csv(TF_info_path)
print(TF_info.shape)
display(TF_info.head())

# grn table
grn = pd.DataFrame({'TF':network.keys(),'Targets':network.values()})
grn = grn.merge(TF_info,how='left',on='TF')
grn = grn[['TF','Targets','centaliry_eigenvector']]
print(grn.shape)
display(grn.head())

# save the daraframe
grn.to_csv(os.path.join(table_dir,'csvs/TF_TG_network_SANPC_target-AxonGuidances.csv'))
# Out:
# 33
# (33, 6)
#       TF  direct_TF  TF_n_target_genes  TF_n_target_sig_regions  \
# 0   BNC2       True                2.0                      0.0
# 1    FOS       True                8.0                      3.0
# 2  HMGA2       True                2.0                      1.0
# 3  MEF2C       True               16.0                      1.0
# 4   NFIB       True                3.0                      3.0
#
#    TF_n_linked_region  centaliry_eigenvector
# 0                 8.0           2.274036e-01
# 1                 1.0           1.343342e-09
# 2                 1.0           4.152300e-02
# 3                 7.0           1.798423e-01
# 4                 0.0           2.562222e-15
# (33, 3)
#        TF                                            Targets  \
# 0    NFIA                          [THRB, NFIA, TBX3, SMAD9]
# 1   SHOX2                               [ISL1, TBX18, SHOX2]
# 2   KLF13                                             [TBX3]
# ...
